# %%
import pandas as pd

# %% [markdown]
# ## Connect ot Graph Data Science

# %%
from graphdatascience import GraphDataScience

# Use Neo4j URI and credentials according to your setup
gds = GraphDataScience('neo4j://localhost', auth=('neo4j', 'neopharm'))

# %% [markdown]
# ## Staging for ETL
# 1. Clear the graph of any existing data and indexes
# 2. read the source data
# 3. create helper functions
# 4. Set Neo4j Indexes

# %%
# Clear last graph - All data and schema attributes
gds.run_cypher('MATCH(n) DETACH DELETE n')
gds.run_cypher('CALL apoc.schema.assert({},{})')
# Out:
#                  label          key           keys  unique   action
# 0           EXTRACT_TO    pathIndex    [pathIndex]   False  DROPPED
# 1        CALCULATED_TO    pathIndex    [pathIndex]   False  DROPPED
# 2            JOIN_FROM    pathIndex    [pathIndex]   False  DROPPED
# 3                Table      tableId      [tableId]    True  DROPPED
# 4               Schema    schema_Id    [schema_Id]    True  DROPPED
# 5             Subquery   subqueryId   [subqueryId]    True  DROPPED
# 6      StoredProcedure        SP_Id        [SP_Id]    True  DROPPED
# 7   Intermediate_Field        intId        [intId]    True  DROPPED
# 8     DestinationField       destId       [destId]    True  DROPPED
# 9     DestinationField  destfieldId  [destfieldId]    True  DROPPED
# 10   IntermediateField   intfieldId   [intfieldId]    True  DROPPED

# %%
# Create Indexes for table
gds.run_cypher('CREATE CONSTRAINT table_unique IF NOT EXISTS FOR (n:Table) REQUIRE n.tableId  IS UNIQUE')
gds.run_cypher('CREATE CONSTRAINT destination_field_unique IF NOT EXISTS FOR (n:DestinationField) REQUIRE n.destId  IS UNIQUE')
gds.run_cypher('CREATE CONSTRAINT intermediate_field_unique IF NOT EXISTS FOR (n:IntermediateField) REQUIRE n.intId  IS UNIQUE')
gds.run_cypher('CREATE CONSTRAINT schema_unique IF NOT EXISTS FOR (n:Schema) REQUIRE n.schema_Id  IS UNIQUE')

gds.run_cypher('CREATE CONSTRAINT dest_field_unique IF NOT EXISTS FOR (n:DestinationField) REQUIRE n.destfieldId  IS UNIQUE')
gds.run_cypher('CREATE CONSTRAINT int_field_unique IF NOT EXISTS FOR (n:IntermediateField) REQUIRE n.intfieldId  IS UNIQUE')
gds.run_cypher('CREATE CONSTRAINT subquery_unique IF NOT EXISTS FOR (n:Subquery) REQUIRE n.subqueryId  IS UNIQUE')
gds.run_cypher('CREATE CONSTRAINT sp_unique IF NOT EXISTS FOR (n:StoredProcedure) REQUIRE n.SP_Id  IS UNIQUE')

gds.run_cypher('CREATE INDEX extract_path IF NOT EXISTS FOR ()-[r:EXTRACT_TO]-() ON (r.pathIndex)')
gds.run_cypher('CREATE INDEX calculated_path IF NOT EXISTS FOR ()-[r:CALCULATED_TO ]-() ON (r.pathIndex)')
gds.run_cypher('CREATE INDEX join_path IF NOT EXISTS FOR ()-[r:JOIN_FROM ]-() ON (r.pathIndex)')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df = pd.read_csv('destination_field_2_0.csv', dtype=str)
df
# Out:
#                 table fieldID                    field_name           table.1  \
# 0    otp_po_cut_level  df_001             country_of_origin  otp_po_cut_level
# 1    otp_po_cut_level  df_002                        po_cut  otp_po_cut_level
# 2    otp_po_cut_level  df_003                         style  otp_po_cut_level
# 3    otp_po_cut_level  df_004                         color  otp_po_cut_level
# 4    otp_po_cut_level  df_005             style_description  otp_po_cut_level
# ..                ...     ...                           ...               ...
# 130  otp_po_cut_level  df_131   mdg_vendor_purchasing_block  otp_po_cut_level
# 131  otp_po_cut_level  df_132        mdg_factory_created_on  otp_po_cut_level
# 132  otp_po_cut_level  df_133  mdg_factory_purchasing_block  otp_po_cut_level
# 133  otp_po_cut_level  df_134                     fob_price  otp_po_cut_level
# 134  otp_po_cut_level  df_135   standard_duty_specific_rate  otp_po_cut_level
#
#      table_id        schema     Storedprocedured
# 0    Table_01  qma_datamart  sp_otp_po_cut_level
# 1    Table_01  qma_datamart  sp_otp_po_cut_level
# 2    Table_01  qma_datamart  sp_otp_po_cut_level
# 3    Table_01  qma_datamart  sp_otp_po_cut_level
# 4    Table_01  qma_datamart  sp_otp_po_cut_level
# ..        ...           ...                  ...
# 130  Table_01  qma_datamart  sp_otp_po_cut_level
# 131  Table_01  qma_datamart  sp_otp_po_cut_level
# 132  Table_01  qma_datamart  sp_otp_po_cut_level
# 133  Table_01  qma_datamart  sp_otp_po_cut_level
# 134  Table_01  qma_datamart  sp_otp_po_cut_level
#
# [135 rows x 7 columns]

# %%
sub_dict = df.loc[(df[f'fieldID'] != '?') & (df[f'field_name'] != '?') & (df[f'fieldID'].notna()),
                  ['fieldID', 'field_name', 'table', 'table_id', 'schema', 'Storedprocedured']].to_dict('records')
sub_dict
# Out:
# [{'fieldID': 'df_001',
#   'field_name': 'country_of_origin',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_002',
#   'field_name': 'po_cut',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_003',
#   'field_name': 'style',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_004',
#   'field_name': 'color',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_005',
#   'field_name': 'style_description',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_006',
#   'field_name': 'goods_description',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_007',
#   'field_name': 'po_issue_date',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_008',
#   'field_name': 'original_crd_at_origin',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_009',
#   'field_name': 'revised_crd_at_origin',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_010',
#   'field_name': 'actual_crd_at_origin',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_011',
#   'field_name': 'local_currency',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_012',
#   'field_name': 'season',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_013',
#   'field_name': 'sourcing_office',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_014',
#   'field_name': 'source_system',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_015',
#   'field_name': 'dc_code',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_016',
#   'field_name': 'po_type',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_017',
#   'field_name': 'purchasing_group',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_018',
#   'field_name': 'sbu',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_019',
#   'field_name': 'sub_sbu',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_020',
#   'field_name': 'product_line',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_021',
#   'field_name': 'purchasing_company',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_022',
#   'field_name': 'vendor_ffc',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_023',
#   'field_name': 'vendor_group_name',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_024',
#   'field_name': 'factory_ffc',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_025',
#   'field_name': 'delay_reason',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_026',
#   'field_name': 'shipment_terms',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_027',
#   'field_name': 'po_location',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_028',
#   'field_name': 'vendor_name',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_029',
#   'field_name': 'factory_name',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_030',
#   'field_name': 'report_order_qty_lum',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_031',
#   'field_name': 'order_amount_local_currency',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_032',
#   'field_name': 'shipped_qty_lum',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_033',
#   'field_name': 'shipped_amt_local_currency',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_034',
#   'field_name': 'booked_qty_lum',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_035',
#   'field_name': 'booked_amt_local_currency',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_036',
#   'field_name': 'effective_qty',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_037',
#   'field_name': 'issample',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_038',
#   'field_name': 'iscustomorder',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_039',
#   'field_name': 'managing_office',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_040',
#   'field_name': 'current_date',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_041',
#   'field_name': 'src_sys',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_042',
#   'field_name': 'misc3',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_043',
#   'field_name': 'misc26',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_044',
#   'field_name': 'misc33',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_045',
#   'field_name': 'purchasing_company_code',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_046',
#   'field_name': 'exch_rate_date',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_047',
#   'field_name': 'od_misc_flag',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_048',
#   'field_name': 'tbr_defect_flag',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_049',
#   'field_name': 'po_creation_date',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_050',
#   'field_name': 'shipment_id',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_051',
#   'field_name': 'hts_code',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_052',
#   'field_name': 'factory_designation',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_053',
#   'field_name': 'erp_factory_code',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_054',
#   'field_name': 'erp_vendor_code',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_055',
#   'field_name': 'po_season',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_056',
#   'field_name': 'revised_in_dc_date',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_057',
#   'field_name': 'ship_mode',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_058',
#   'field_name': 'po_acknowledgement_date',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_059',
#   'field_name': 'po_complete_status',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_060',
#   'field_name': 'greenlight_date',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_061',
#   'field_name': 'first_shipment_id',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_062',
#   'field_name': 'first_actual_crd',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_063',
#   'field_name': 'master_po',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_064',
#   'field_name': 'freight_paid_by',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_065',
#   'field_name': 'exit_cnty_port',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_066',
#   'field_name': 'ship_to_name',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_067',
#   'field_name': 'brand_requested_in_dc_date',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_068',
#   'field_name': 'original_requested_production_end_date',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_069',
#   'field_name': 'latest_confirmed_production_end_date',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_070',
#   'field_name': 'buy_month',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_071',
#   'field_name': 'requested_delivery_date',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_072',
#   'field_name': 'po_closure_eligibility',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_073',
#   'field_name': 'discharge_at_port_of_destination',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_074',
#   'field_name': 'season_cleaned',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_075',
#   'field_name': 'vf_est_dc_arrival_date',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_076',
#   'field_name': 'asn_released_to_3pl',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_077',
#   'field_name': 'container_number',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_078',
#   'field_name': 'brand',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_079',
#   'field_name': 'major_product_category_name',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_080',
#   'field_name': 'business_unit',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_081',
#   'field_name': 'brand2',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_082',
#   'field_name': 'market',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_083',
#   'field_name': 'product_supply_group',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_084',
#   'field_name': 'exchange_rate',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_085',
#   'field_name': 'certified_pocut_flag',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_086',
#   'field_name': 'certprintdate',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_087',
#   'field_name': 'table_names',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_088',
#   'field_name': 'order_amount_usd',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_089',
#   'field_name': 'shipped_amt_usd',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_090',
#   'field_name': 'unit_price',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_091',
#   'field_name': 'effective_crd',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_092',
#   'field_name': 'fob_price_usd',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_093',
#   'field_name': 'unit_price_average_in_usd',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_094',
#   'field_name': 'effective_crd_year',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_095',
#   'field_name': 'effective_crd_month',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_096',
#   'field_name': 'days_late',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_097',
#   'field_name': 'order_type_calculated',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_098',
#   'field_name': 'booked_amt_usd',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_099',
#   'field_name': 'effective_amt_usd',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_100',
#   'field_name': 'crc_code',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_101',
#   'field_name': 'crc_description',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_102',
#   'field_name': 'crc_owner',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_103',
#   'field_name': 'balance_qty',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_104',
#   'field_name': 'dc_name',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_105',
#   'field_name': 'destination_country',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_106',
#   'field_name': 'shipment_status',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_107',
#   'field_name': 'fr_release',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_108',
#   'field_name': 'shipment_id_closing_date',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_109',
#   'field_name': 'actual_ship_date',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_110',
#   'field_name': 'first_actual_ship_date',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_111',
#   'field_name': 'shipment_closed_by',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_112',
#   'field_name': 'hts_product_category',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_113',
#   'field_name': 'hts_product_type',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_114',
#   'field_name': 'costing_season',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_115',
#   'field_name': 'orders_to_be_produced_qty',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_116',
#   'field_name': 'orders_to_be_produced_amt_usd',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_117',
#   'field_name': 'actual_produced_qty',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_118',
#   'field_name': 'actual_produced_amt_usd',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_119',
#   'field_name': 'fob_duties_rate',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_120',
#   'field_name': 'payment_terms',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_121',
#   'field_name': 'vf_fiscal_year_original_crd',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_122',
#   'field_name': 'vf_fiscal_year_month_original_crd',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_123',
#   'field_name': 'standard_duty_rate',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_124',
#   'field_name': 'preferential_duty_rate',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_125',
#   'field_name': 'cbm_pc_brand_cat',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_126',
#   'field_name': 'freight_cost',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_127',
#   'field_name': 'applied_duty_rate',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_128',
#   'field_name': 'calculated_duty_amt',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_129',
#   'field_name': 'fully_landed_cost',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_130',
#   'field_name': 'mdg_vendor_created_on',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_131',
#   'field_name': 'mdg_vendor_purchasing_block',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_132',
#   'field_name': 'mdg_factory_created_on',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_133',
#   'field_name': 'mdg_factory_purchasing_block',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_134',
#   'field_name': 'fob_price',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'},
#  {'fieldID': 'df_135',
#   'field_name': 'standard_duty_specific_rate',
#   'table': 'otp_po_cut_level',
#   'table_id': 'Table_01',
#   'schema': 'qma_datamart',
#   'Storedprocedured': 'sp_otp_po_cut_level'}]

# %%
# Load nodes and draw location at relationships
gds.run_cypher('''
    UNWIND $dest_fields AS a
    WITH a.fieldID AS Dest_fieldID, 
         a.field_name AS Dest_field_name, 
         a.table AS table_name,
         a.table_id AS table_ID, 
         a.schema AS schema,
         a.Storedprocedured AS stored_procedure
    MERGE(n0:Table {tableId: table_ID}) SET n0.table_name=table_name
    MERGE(n1:DestinationField {destfieldId: Dest_fieldID}) SET n1.Dest_field_name=Dest_field_name
    MERGE(n2:StoredProcedure {SP_Id: stored_procedure}) SET n2.stored_procedure=stored_procedure
    MERGE(n3:Schema {schema_Id: schema}) SET n3.schema=schema
    
    MERGE(n0)<-[:LOCATED_AT]-(n1)
    MERGE(n2)<-[:CREATED_IN]-(n1)
    MERGE(n3)<-[:INSIDE_OF]-(n0)
   
    RETURN count(n0), count(n1), count(n2), count(n3)
    ''', params={'dest_fields':sub_dict})
# Out:
#    count(n0)  count(n1)  count(n2)  count(n3)
# 0        135        135        135        135

# %%
df = pd.read_csv('intermediate_field_2_0.csv', dtype=str)
df
# Out:
#     field_id              field_name                        table  table_id  \
# 0     if_001        avg_duty_fees_rt             #fob_duties_rate  Table_02
# 1     if_002        avg_duty_fees_rt             #fob_duties_rate  Table_02
# 2     if_003                 article  #standard_duty_rate_article  Table_03
# 3     if_004          main_duty_rate  #standard_duty_rate_article  Table_03
# 4     if_005                    name  #standard_duty_rate_article  Table_03
# ..       ...                     ...                          ...       ...
# 287   if_288                      bu                           z2  Table_46
# 288   if_289  major_product_category                           z2  Table_46
# 289   if_290                  market                           z2  Table_46
# 290   if_291    product_supply_group                           z2  Table_46
# 291   if_292                constant                       system  Table_41
#
#        schema
# 0        temp
# 1        temp
# 2        temp
# 3        temp
# 4        temp
# ..        ...
# 287  subquery
# 288  subquery
# 289  subquery
# 290  subquery
# 291    system
#
# [292 rows x 5 columns]

# %%
sub_dict = df.loc[(df[f'field_id'] != '?') & (df[f'field_name'] != '?') & (df[f'field_id'].notna()),
                  ['field_id', 'field_name', 'table', 'table_id', 'schema']].to_dict('records')
sub_dict
# Out:
# [{'field_id': 'if_001',
#   'field_name': 'avg_duty_fees_rt',
#   'table': '#fob_duties_rate',
#   'table_id': 'Table_02',
#   'schema': 'temp'},
#  {'field_id': 'if_002',
#   'field_name': 'avg_duty_fees_rt',
#   'table': '#fob_duties_rate',
#   'table_id': 'Table_02',
#   'schema': 'temp'},
#  {'field_id': 'if_003',
#   'field_name': 'article',
#   'table': '#standard_duty_rate_article',
#   'table_id': 'Table_03',
#   'schema': 'temp'},
#  {'field_id': 'if_004',
#   'field_name': 'main_duty_rate',
#   'table': '#standard_duty_rate_article',
#   'table_id': 'Table_03',
#   'schema': 'temp'},
#  {'field_id': 'if_005',
#   'field_name': 'name',
#   'table': '#standard_duty_rate_article',
#   'table_id': 'Table_03',
#   'schema': 'temp'},
#  {'field_id': 'if_006',
#   'field_name': 'hts_code',
#   'table': '#standard_duty_rate_hts_code',
#   'table_id': 'Table_04',
#   'schema': 'temp'},
#  {'field_id': 'if_007',
#   'field_name': 'main_duty_rate',
#   'table': '#standard_duty_rate_hts_code',
#   'table_id': 'Table_04',
#   'schema': 'temp'},
#  {'field_id': 'if_008',
#   'field_name': 'name',
#   'table': '#standard_duty_rate_hts_code',
#   'table_id': 'Table_04',
#   'schema': 'temp'},
#  {'field_id': 'if_009',
#   'field_name': 'full_date?',
#   'table': '?',
#   'table_id': 'Table_05',
#   'schema': 'subquery'},
#  {'field_id': 'if_010',
#   'field_name': 'pd_line',
#   'table': 'a',
#   'table_id': 'Table_06',
#   'schema': 'subquery'},
#  {'field_id': 'if_011',
#   'field_name': 'sbu',
#   'table': 'a',
#   'table_id': 'Table_06',
#   'schema': 'subquery'},
#  {'field_id': 'if_012',
#   'field_name': 'sub_sbu',
#   'table': 'a',
#   'table_id': 'Table_06',
#   'schema': 'subquery'},
#  {'field_id': 'if_013',
#   'field_name': 'cr.vf_fiscal_month2',
#   'table': 'calendar',
#   'table_id': 'Table_07',
#   'schema': 'gen_dimension'},
#  {'field_id': 'if_014',
#   'field_name': 'cr.vf_fiscal_year',
#   'table': 'calendar',
#   'table_id': 'Table_07',
#   'schema': 'gen_dimension'},
#  {'field_id': 'if_015',
#   'field_name': 'brand',
#   'table': 'cbb_mapping',
#   'table_id': 'Table_08',
#   'schema': 'qma_datamart'},
#  {'field_id': 'if_016',
#   'field_name': 'brand2',
#   'table': 'cbb_mapping',
#   'table_id': 'Table_08',
#   'schema': 'qma_datamart'},
#  {'field_id': 'if_017',
#   'field_name': 'bu',
#   'table': 'cbb_mapping',
#   'table_id': 'Table_08',
#   'schema': 'qma_datamart'},
#  {'field_id': 'if_018',
#   'field_name': 'major_product_category',
#   'table': 'cbb_mapping',
#   'table_id': 'Table_08',
#   'schema': 'qma_datamart'},
#  {'field_id': 'if_019',
#   'field_name': 'market',
#   'table': 'cbb_mapping',
#   'table_id': 'Table_08',
#   'schema': 'qma_datamart'},
#  {'field_id': 'if_020',
#   'field_name': 'product_supply_group',
#   'table': 'cbb_mapping',
#   'table_id': 'Table_08',
#   'schema': 'qma_datamart'},
#  {'field_id': 'if_021',
#   'field_name': 'fcurr',
#   'table': 'currency',
#   'table_id': 'Table_09',
#   'schema': 'gen_dimension'},
#  {'field_id': 'if_022',
#   'field_name': 'fiscal_month',
#   'table': 'currency',
#   'table_id': 'Table_09',
#   'schema': 'gen_dimension'},
#  {'field_id': 'if_023',
#   'field_name': 'kurst',
#   'table': 'currency',
#   'table_id': 'Table_09',
#   'schema': 'gen_dimension'},
#  {'field_id': 'if_024',
#   'field_name': 'tcurr',
#   'table': 'currency',
#   'table_id': 'Table_09',
#   'schema': 'gen_dimension'},
#  {'field_id': 'if_025',
#   'field_name': 'ukurs',
#   'table': 'currency',
#   'table_id': 'Table_09',
#   'schema': 'gen_dimension'},
#  {'field_id': 'if_026',
#   'field_name': 'misc2',
#   'table': 'dim_descode',
#   'table_id': 'Table_10',
#   'schema': 'spectrum_datalake'},
#  {'field_id': 'if_027',
#   'field_name': 'misc30',
#   'table': 'dim_descode',
#   'table_id': 'Table_10',
#   'schema': 'spectrum_datalake'},
#  {'field_id': 'if_028',
#   'field_name': 'misc4',
#   'table': 'dim_descode',
#   'table_id': 'Table_10',
#   'schema': 'spectrum_datalake'},
#  {'field_id': 'if_029',
#   'field_name': 'dc_name',
#   'table': 'dim_drbn_ctr',
#   'table_id': 'Table_11',
#   'schema': 'qma'},
#  {'field_id': 'if_030',
#   'field_name': 'iso_cnty',
#   'table': 'dim_drbn_ctr',
#   'table_id': 'Table_11',
#   'schema': 'qma'},
#  {'field_id': 'if_031',
#   'field_name': 'changeoperation',
#   'table': 'dim_fty_supr ',
#   'table_id': 'Table_12',
#   'schema': 'qma'},
#  {'field_id': 'if_032',
#   'field_name': 'fty_code',
#   'table': 'dim_fty_supr ',
#   'table_id': 'Table_12',
#   'schema': 'qma'},
#  {'field_id': 'if_033',
#   'field_name': 'src_sys',
#   'table': 'dim_fty_supr ',
#   'table_id': 'Table_12',
#   'schema': 'qma'},
#  {'field_id': 'if_034',
#   'field_name': 'vendor_ffc',
#   'table': 'dim_fty_supr ',
#   'table_id': 'Table_12',
#   'schema': 'qma'},
#  {'field_id': 'if_035',
#   'field_name': 'vendor_grp_name',
#   'table': 'dim_fty_supr ',
#   'table_id': 'Table_12',
#   'schema': 'qma'},
#  {'field_id': 'if_036',
#   'field_name': 'central_purchasing_block',
#   'table': 'dim_mdg_vendor_factory',
#   'table_id': 'Table_13',
#   'schema': 'qma'},
#  {'field_id': 'if_037',
#   'field_name': 'created_on',
#   'table': 'dim_mdg_vendor_factory',
#   'table_id': 'Table_13',
#   'schema': 'qma'},
#  {'field_id': 'if_038',
#   'field_name': 'ffc_code',
#   'table': 'dim_mdg_vendor_factory',
#   'table_id': 'Table_13',
#   'schema': 'qma'},
#  {'field_id': 'if_039',
#   'field_name': 'ffc_last_update desc',
#   'table': 'dim_mdg_vendor_factory',
#   'table_id': 'Table_13',
#   'schema': 'qma'},
#  {'field_id': 'if_040',
#   'field_name': 'mdg_code',
#   'table': 'dim_mdg_vendor_factory',
#   'table_id': 'Table_13',
#   'schema': 'qma'},
#  {'field_id': 'if_041',
#   'field_name': 'name1',
#   'table': 'dim_mdg_vendor_factory',
#   'table_id': 'Table_13',
#   'schema': 'qma'},
#  {'field_id': 'if_042',
#   'field_name': 'name2',
#   'table': 'dim_mdg_vendor_factory',
#   'table_id': 'Table_13',
#   'schema': 'qma'},
#  {'field_id': 'if_043',
#   'field_name': 'name3',
#   'table': 'dim_mdg_vendor_factory',
#   'table_id': 'Table_13',
#   'schema': 'qma'},
#  {'field_id': 'if_044',
#   'field_name': 'name4',
#   'table': 'dim_mdg_vendor_factory',
#   'table_id': 'Table_13',
#   'schema': 'qma'},
#  {'field_id': 'if_045',
#   'field_name': 'vendor_group_name',
#   'table': 'dim_mdg_vendor_factory',
#   'table_id': 'Table_13',
#   'schema': 'qma'},
#  {'field_id': 'if_046',
#   'field_name': 'vendor_type',
#   'table': 'dim_mdg_vendor_factory',
#   'table_id': 'Table_13',
#   'schema': 'qma'},
#  {'field_id': 'if_047',
#   'field_name': 'pg_code',
#   'table': 'dim_pch_grp',
#   'table_id': 'Table_14',
#   'schema': 'qma'},
#  {'field_id': 'if_048',
#   'field_name': 'pg_name',
#   'table': 'dim_pch_grp',
#   'table_id': 'Table_14',
#   'schema': 'qma'},
#  {'field_id': 'if_049',
#   'field_name': 'src_sys',
#   'table': 'dim_pch_grp',
#   'table_id': 'Table_14',
#   'schema': 'qma'},
#  {'field_id': 'if_050',
#   'field_name': 'scale_desc',
#   'table': 'dim_size_scale',
#   'table_id': 'Table_15',
#   'schema': 'qma'},
#  {'field_id': 'if_051',
#   'field_name': 'article',
#   'table': 'duties_rates_apac',
#   'table_id': 'Table_16',
#   'schema': 'qma'},
#  {'field_id': 'if_052',
#   'field_name': 'hts_code',
#   'table': 'duties_rates_apac',
#   'table_id': 'Table_16',
#   'schema': 'qma'},
#  {'field_id': 'if_053',
#   'field_name': 'import_country',
#   'table': 'duties_rates_apac',
#   'table_id': 'Table_16',
#   'schema': 'qma'},
#  {'field_id': 'if_054',
#   'field_name': 'main_duty_rate',
#   'table': 'duties_rates_apac',
#   'table_id': 'Table_16',
#   'schema': 'qma'},
#  {'field_id': 'if_055',
#   'field_name': 'country_of_origin',
#   'table': 'duties_rates_apac_preferential drap',
#   'table_id': 'Table_17',
#   'schema': 'qma'},
#  {'field_id': 'if_056',
#   'field_name': 'destination_country',
#   'table': 'duties_rates_apac_preferential drap',
#   'table_id': 'Table_17',
#   'schema': 'qma'},
#  {'field_id': 'if_057',
#   'field_name': 'preferential_rate',
#   'table': 'duties_rates_apac_preferential drap',
#   'table_id': 'Table_17',
#   'schema': 'qma'},
#  {'field_id': 'if_058',
#   'field_name': 'color',
#   'table': 'fact_po_dtl',
#   'table_id': 'Table_18',
#   'schema': 'qma'},
#  {'field_id': 'if_059',
#   'field_name': 'dimension',
#   'table': 'fact_po_dtl',
#   'table_id': 'Table_18',
#   'schema': 'qma'},
#  {'field_id': 'if_060',
#   'field_name': 'qty',
#   'table': 'fact_po_dtl',
#   'table_id': 'Table_18',
#   'schema': 'qma'},
#  {'field_id': 'if_061',
#   'field_name': 'unit_cost',
#   'table': 'fact_po_dtl',
#   'table_id': 'Table_18',
#   'schema': 'qma'},
#  {'field_id': 'if_062',
#   'field_name': 'latest_confirmed_production_end_date',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_063',
#   'field_name': 'lot',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_064',
#   'field_name': 'original_requested_production_end_date',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_065',
#   'field_name': 'payment_term',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_066',
#   'field_name': 'src_sys',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_067',
#   'field_name': 'ack_date',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_068',
#   'field_name': 'buy_month',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_069',
#   'field_name': 'cls_code',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_070',
#   'field_name': 'completed',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_071',
#   'field_name': 'confirmed_pd_date',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_072',
#   'field_name': 'created_date',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_073',
#   'field_name': 'currency',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_074',
#   'field_name': 'desc',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_075',
#   'field_name': 'done_flag',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_076',
#   'field_name': 'exit_cnty_port',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_077',
#   'field_name': 'exit_cnty_port33',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_078',
#   'field_name': 'freight_paid_by',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_079',
#   'field_name': 'fty_name',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_080',
#   'field_name': 'good_desc',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_081',
#   'field_name': 'green_light_date',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_082',
#   'field_name': 'hts_code',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_083',
#   'field_name': 'issue_date',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_084',
#   'field_name': 'late_exit_rsn',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_085',
#   'field_name': 'lot',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_086',
#   'field_name': 'misc26',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_087',
#   'field_name': 'misc3',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_088',
#   'field_name': 'misc33',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_089',
#   'field_name': 'notes',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_090',
#   'field_name': 'orig_date',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_091',
#   'field_name': 'orig_dc',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_092',
#   'field_name': 'pd_line',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_093',
#   'field_name': 'po_status',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_094',
#   'field_name': 'po_type',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_095',
#   'field_name': 'purchasing_company',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_096',
#   'field_name': 'purchasing_grp',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_097',
#   'field_name': 'rda_code',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_098',
#   'field_name': 'req_production_date',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_099',
#   'field_name': 'reqdelivery',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_100',
#   'field_name': 'revised_date',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_101',
#   'field_name': 'revised_dc_date',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_102',
#   'field_name': 'rfactory',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_103',
#   'field_name': 'sbu',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_104',
#   'field_name': 'season',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_105',
#   'field_name': 'season_cdf',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_106',
#   'field_name': 'season_cleaned',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_107',
#   'field_name': 'ship_no',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_108',
#   'field_name': 'ship_route',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_109',
#   'field_name': 'shipment_mode',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_110',
#   'field_name': 'shipment_term',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_111',
#   'field_name': 'source',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_112',
#   'field_name': 'source_sys',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_113',
#   'field_name': 'src_sys',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_114',
#   'field_name': 'store_no',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_115',
#   'field_name': 'style',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_116',
#   'field_name': 'sub_sbu',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_117',
#   'field_name': 'vendor_name ',
#   'table': 'fact_po_hdr',
#   'table_id': 'Table_19',
#   'schema': 'qma'},
#  {'field_id': 'if_118',
#   'field_name': 'actual_crd',
#   'table': 'fact_shp_dtl',
#   'table_id': 'Table_20',
#   'schema': 'qma'},
#  {'field_id': 'if_119',
#   'field_name': 'container',
#   'table': 'fact_shp_dtl',
#   'table_id': 'Table_20',
#   'schema': 'qma'},
#  {'field_id': 'if_120',
#   'field_name': 'qty',
#   'table': 'fact_shp_dtl',
#   'table_id': 'Table_20',
#   'schema': 'qma'},
#  {'field_id': 'if_121',
#   'field_name': 'ship_qty',
#   'table': 'fact_shp_dtl',
#   'table_id': 'Table_20',
#   'schema': 'qma'},
#  {'field_id': 'if_122',
#   'field_name': 'shipment',
#   'table': 'fact_shp_dtl',
#   'table_id': 'Table_20',
#   'schema': 'qma'},
#  {'field_id': 'if_123',
#   'field_name': 'src_sys',
#   'table': 'fact_shp_dtl',
#   'table_id': 'Table_20',
#   'schema': 'qma'},
#  {'field_id': 'if_124',
#   'field_name': 'rfr_release',
#   'table': 'fact_shp_hdr',
#   'table_id': 'Table_21',
#   'schema': 'qma'},
#  {'field_id': 'if_125',
#   'field_name': 'first_close_by',
#   'table': 'fact_shp_hdr',
#   'table_id': 'Table_21',
#   'schema': 'qma'},
#  {'field_id': 'if_126',
#   'field_name': 'shipment',
#   'table': 'fact_shp_hdr',
#   'table_id': 'Table_21',
#   'schema': 'qma'},
#  {'field_id': 'if_127',
#   'field_name': 'src_sys',
#   'table': 'fact_shp_hdr',
#   'table_id': 'Table_21',
#   'schema': 'qma'},
#  {'field_id': 'if_128',
#   'field_name': 'actual_date',
#   'table': 'fact_shp_hdr',
#   'table_id': 'Table_21',
#   'schema': 'qma'},
#  {'field_id': 'if_129',
#   'field_name': 'close_date',
#   'table': 'fact_shp_hdr',
#   'table_id': 'Table_21',
#   'schema': 'qma'},
#  {'field_id': 'if_130',
#   'field_name': 'closed_flag',
#   'table': 'fact_shp_hdr',
#   'table_id': 'Table_21',
#   'schema': 'qma'},
#  {'field_id': 'if_131',
#   'field_name': 'eta_city',
#   'table': 'fact_shp_hdr',
#   'table_id': 'Table_21',
#   'schema': 'qma'},
#  {'field_id': 'if_132',
#   'field_name': 'first_actual_ship_date',
#   'table': 'fact_shp_hdr',
#   'table_id': 'Table_21',
#   'schema': 'qma'},
#  {'field_id': 'if_133',
#   'field_name': 'first_shipment_id',
#   'table': 'fact_shp_hdr',
#   'table_id': 'Table_21',
#   'schema': 'qma'},
#  {'field_id': 'if_134',
#   'field_name': 'released',
#   'table': 'fact_shp_hdr',
#   'table_id': 'Table_21',
#   'schema': 'qma'},
#  {'field_id': 'if_135',
#   'field_name': 'shipment',
#   'table': 'fact_shp_hdr',
#   'table_id': 'Table_21',
#   'schema': 'qma'},
#  {'field_id': 'if_136',
#   'field_name': 'shipment_id',
#   'table': 'fact_shp_hdr',
#   'table_id': 'Table_21',
#   'schema': 'qma'},
#  {'field_id': 'if_137',
#   'field_name': 'src_sys',
#   'table': 'fact_shp_hdr',
#   'table_id': 'Table_21',
#   'schema': 'qma'},
#  {'field_id': 'if_138',
#   'field_name': 'central_purchasing_block',
#   'table': 'factory',
#   'table_id': 'Table_22',
#   'schema': 'subquery'},
#  {'field_id': 'if_139',
#   'field_name': 'created_on',
#   'table': 'factory',
#   'table_id': 'Table_22',
#   'schema': 'subquery'},
#  {'field_id': 'if_140',
#   'field_name': 'ffc_code',
#   'table': 'factory',
#   'table_id': 'Table_22',
#   'schema': 'subquery'},
#  {'field_id': 'if_141',
#   'field_name': 'fty_ffc',
#   'table': 'factory',
#   'table_id': 'Table_22',
#   'schema': 'subquery'},
#  {'field_id': 'if_142',
#   'field_name': 'fty_name',
#   'table': 'factory',
#   'table_id': 'Table_22',
#   'schema': 'subquery'},
#  {'field_id': 'if_143',
#   'field_name': 'mdg_code',
#   'table': 'factory',
#   'table_id': 'Table_22',
#   'schema': 'subquery'},
#  {'field_id': 'if_144',
#   'field_name': 'name1',
#   'table': 'factory',
#   'table_id': 'Table_22',
#   'schema': 'subquery'},
#  {'field_id': 'if_145',
#   'field_name': 'name2',
#   'table': 'factory',
#   'table_id': 'Table_22',
#   'schema': 'subquery'},
#  {'field_id': 'if_146',
#   'field_name': 'name3',
#   'table': 'factory',
#   'table_id': 'Table_22',
#   'schema': 'subquery'},
#  {'field_id': 'if_147',
#   'field_name': 'name4',
#   'table': 'factory',
#   'table_id': 'Table_22',
#   'schema': 'subquery'},
#  {'field_id': 'if_148',
#   'field_name': 'rk=1',
#   'table': 'factory',
#   'table_id': 'Table_22',
#   'schema': 'subquery'},
#  {'field_id': 'if_149',
#   'field_name': 'vendor_type',
#   'table': 'factory',
#   'table_id': 'Table_22',
#   'schema': 'subquery'},
#  {'field_id': 'if_150',
#   'field_name': 'factory_ffc',
#   'table': 'factory_mapping (mapping_ngcv12_factory)',
#   'table_id': 'Table_23',
#   'schema': 'qma_datamart'},
#  {'field_id': 'if_151',
#   'field_name': 'designation',
#   'table': 'ffc_factory_designation_status',
#   'table_id': 'Table_24',
#   'schema': 'qma'},
#  {'field_id': 'if_152',
#   'field_name': 'avg_duty_fees_rt',
#   'table': '#fob_duties_rate',
#   'table_id': 'Table_02',
#   'schema': 'temp'},
#  {'field_id': 'if_153',
#   'field_name': 'destination_country_name ',
#   'table': '#fob_duties_rate',
#   'table_id': 'Table_02',
#   'schema': 'temp'},
#  {'field_id': 'if_154',
#   'field_name': 'hts_6',
#   'table': '#fob_duties_rate',
#   'table_id': 'Table_02',
#   'schema': 'temp'},
#  {'field_id': 'if_155',
#   'field_name': 'origin_country_name ',
#   'table': '#fob_duties_rate',
#   'table_id': 'Table_02',
#   'schema': 'temp'},
#  {'field_id': 'if_156',
#   'field_name': 'processed_date',
#   'table': '#fob_duties_rate',
#   'table_id': 'Table_02',
#   'schema': 'temp'},
#  {'field_id': 'if_157',
#   'field_name': 'sales_market',
#   'table': '#fob_duties_rate',
#   'table_id': 'Table_02',
#   'schema': 'temp'},
#  {'field_id': 'if_158',
#   'field_name': 'cbm_factor',
#   'table': 'freight_cost_cbm_factor',
#   'table_id': 'Table_25',
#   'schema': 'qma'},
#  {'field_id': 'if_159',
#   'field_name': 'major_product_category',
#   'table': 'freight_cost_cbm_factor',
#   'table_id': 'Table_25',
#   'schema': 'qma'},
#  {'field_id': 'if_160',
#   'field_name': 'destination_country',
#   'table': 'freight_cost_contract_flc',
#   'table_id': 'Table_26',
#   'schema': 'qma'},
#  {'field_id': 'if_161',
#   'field_name': 'equipment',
#   'table': 'freight_cost_contract_flc',
#   'table_id': 'Table_26',
#   'schema': 'qma'},
#  {'field_id': 'if_162',
#   'field_name': 'final_ocean_cost_per_container',
#   'table': 'freight_cost_contract_flc',
#   'table_id': 'Table_26',
#   'schema': 'qma'},
#  {'field_id': 'if_163',
#   'field_name': 'origin_country',
#   'table': 'freight_cost_contract_flc',
#   'table_id': 'Table_26',
#   'schema': 'qma'},
#  {'field_id': 'if_164',
#   'field_name': 'actual_ship_date',
#   'table': 'fsh',
#   'table_id': 'Table_27',
#   'schema': 'subquery'},
#  {'field_id': 'if_165',
#   'field_name': 'closed_flag',
#   'table': 'fsh',
#   'table_id': 'Table_27',
#   'schema': 'subquery'},
#  {'field_id': 'if_166',
#   'field_name': 'first_actual_ship_date',
#   'table': 'fsh',
#   'table_id': 'Table_27',
#   'schema': 'subquery'},
#  {'field_id': 'if_167',
#   'field_name': 'fr_release',
#   'table': 'fsh',
#   'table_id': 'Table_27',
#   'schema': 'subquery'},
#  {'field_id': 'if_168',
#   'field_name': 'shipment_id_closing_date',
#   'table': 'fsh',
#   'table_id': 'Table_27',
#   'schema': 'subquery'},
#  {'field_id': 'if_169',
#   'field_name': 'certprintdate',
#   'table': 'infocenter_cpsc',
#   'table_id': 'Table_28',
#   'schema': 'spectrum_datalake'},
#  {'field_id': 'if_170',
#   'field_name': 'pono',
#   'table': 'infocenter_cpsc',
#   'table_id': 'Table_28',
#   'schema': 'spectrum_datalake'},
#  {'field_id': 'if_171',
#   'field_name': 'old_delay_category_1',
#   'table': 'mapping_crc_grouping',
#   'table_id': 'Table_29',
#   'schema': 'qma_datamart'},
#  {'field_id': 'if_172',
#   'field_name': 'old_delay_reason_code',
#   'table': 'mapping_crc_grouping',
#   'table_id': 'Table_29',
#   'schema': 'qma_datamart'},
#  {'field_id': 'if_173',
#   'field_name': 'hts',
#   'table': 'mapping_hts_desc',
#   'table_id': 'Table_30',
#   'schema': 'qma_datamart'},
#  {'field_id': 'if_174',
#   'field_name': 'product_category_hts',
#   'table': 'mapping_hts_desc',
#   'table_id': 'Table_30',
#   'schema': 'qma_datamart'},
#  {'field_id': 'if_175',
#   'field_name': 'product_type',
#   'table': 'mapping_hts_desc',
#   'table_id': 'Table_30',
#   'schema': 'qma_datamart'},
#  {'field_id': 'if_176',
#   'field_name': 'vendor_ffc',
#   'table': 'mapping_ngcv12_factory',
#   'table_id': 'Table_31',
#   'schema': 'qma_datamart'},
#  {'field_id': 'if_177',
#   'field_name': 'brand_cfs',
#   'table': 'mapping_unified_season_finance',
#   'table_id': 'Table_32',
#   'schema': 'qma_datamart'},
#  {'field_id': 'if_178',
#   'field_name': 'costing_season',
#   'table': 'mapping_unified_season_finance',
#   'table_id': 'Table_32',
#   'schema': 'qma_datamart'},
#  {'field_id': 'if_179',
#   'field_name': 'crd_calendar_year_cfs',
#   'table': 'mapping_unified_season_finance',
#   'table_id': 'Table_32',
#   'schema': 'qma_datamart'},
#  {'field_id': 'if_180',
#   'field_name': 'crd_month_cfs',
#   'table': 'mapping_unified_season_finance',
#   'table_id': 'Table_32',
#   'schema': 'qma_datamart'},
#  {'field_id': 'if_181',
#   'field_name': 'major_product_category_cfs',
#   'table': 'mapping_unified_season_finance',
#   'table_id': 'Table_32',
#   'schema': 'qma_datamart'},
#  {'field_id': 'if_182',
#   'field_name': 'managing_office_cfs',
#   'table': 'mapping_unified_season_finance',
#   'table_id': 'Table_32',
#   'schema': 'qma_datamart'},
#  {'field_id': 'if_183',
#   'field_name': 'brand',
#   'table': 'ngcv12_wd_wdt_sys21_product_prod',
#   'table_id': 'Table_33',
#   'schema': 'spectrum_datalake'},
#  {'field_id': 'if_184',
#   'field_name': 'make_code',
#   'table': 'ngcv12_wd_wdt_sys21_product_prod',
#   'table_id': 'Table_33',
#   'schema': 'spectrum_datalake'},
#  {'field_id': 'if_185',
#   'field_name': 'order_amount_lc',
#   'table': 'ORDER_AMOUNT_LC',
#   'table_id': 'Table_34',
#   'schema': 'qma_datamart'},
#  {'field_id': 'if_186',
#   'field_name': 'avg_duty_fees_rt',
#   'table': 'rt1 or rt2',
#   'table_id': 'Table_36',
#   'schema': 'qma'},
#  {'field_id': 'if_187',
#   'field_name': 'avg_duty_fees_rt',
#   'table': 'rt1 or rt2',
#   'table_id': 'Table_36',
#   'schema': 'qma'},
#  {'field_id': 'if_188',
#   'field_name': 'avg_duty_fees_rt',
#   'table': 'rt1 or rt2',
#   'table_id': 'Table_36',
#   'schema': 'qma'},
#  {'field_id': 'if_189',
#   'field_name': 'avg_duty_fees_rt',
#   'table': 'rt1 or rt2',
#   'table_id': 'Table_36',
#   'schema': 'qma'},
#  {'field_id': 'if_190',
#   'field_name': 'avg_duty_fees_rt',
#   'table': 'rt1 or rt2',
#   'table_id': 'Table_36',
#   'schema': 'qma'},
#  {'field_id': 'if_191',
#   'field_name': 'avg_duty_fees_rt',
#   'table': 'rt1 or rt2',
#   'table_id': 'Table_36',
#   'schema': 'qma'},
#  {'field_id': 'if_192',
#   'field_name': 'avg_duty_fees_rt',
#   'table': 'rt1 or rt2',
#   'table_id': 'Table_36',
#   'schema': 'qma'},
#  {'field_id': 'if_193',
#   'field_name': 'avg_duty_fees_rt',
#   'table': 'rt1 or rt2',
#   'table_id': 'Table_36',
#   'schema': 'qma'},
#  {'field_id': 'if_194',
#   'field_name': 'avg_duty_fees_rt',
#   'table': 'rt1 or rt2',
#   'table_id': 'Table_36',
#   'schema': 'qma'},
#  {'field_id': 'if_195',
#   'field_name': 'avg_duty_fees_rt',
#   'table': 'rt1 or rt2',
#   'table_id': 'Table_36',
#   'schema': 'qma'},
#  {'field_id': 'if_196',
#   'field_name': 'avg_duty_fees_rt',
#   'table': 'rt1 or rt2',
#   'table_id': 'Table_36',
#   'schema': 'qma'},
#  {'field_id': 'if_197',
#   'field_name': 'avg_duty_fees_rt',
#   'table': 'rt1 or rt2',
#   'table_id': 'Table_36',
#   'schema': 'qma'},
#  {'field_id': 'if_198',
#   'field_name': 'code',
#   'table': 'sp_country_master ',
#   'table_id': 'Table_38',
#   'schema': 'qma_datamart'},
#  {'field_id': 'if_199',
#   'field_name': 'code',
#   'table': 'sp_country_master',
#   'table_id': 'Table_37',
#   'schema': 'Store Procedure'},
#  {'field_id': 'if_200',
#   'field_name': 'main_duty_rate',
#   'table': 'sp_country_master',
#   'table_id': 'Table_37',
#   'schema': 'Store Procedure'},
#  {'field_id': 'if_201',
#   'field_name': 'name',
#   'table': 'sp_country_master',
#   'table_id': 'Table_37',
#   'schema': 'Store Procedure'},
#  {'field_id': 'if_202',
#   'field_name': 'name',
#   'table': 'sp_country_master mst',
#   'table_id': 'Table_39',
#   'schema': 'qma_datamart'},
#  {'field_id': 'if_203',
#   'field_name': 'managing_office',
#   'table': 'sp_managing_office_mapping',
#   'table_id': 'Table_40',
#   'schema': 'qma_datamart'},
#  {'field_id': 'if_204',
#   'field_name': 'current_date',
#   'table': 'system',
#   'table_id': 'Table_41',
#   'schema': 'system'},
#  {'field_id': 'if_205',
#   'field_name': 'is null',
#   'table': 'system',
#   'table_id': 'Table_41',
#   'schema': 'system'},
#  {'field_id': 'if_206',
#   'field_name': 'table_names',
#   'table': 'system',
#   'table_id': 'Table_41',
#   'schema': 'system'},
#  {'field_id': 'if_207',
#   'field_name': 'certprintdate',
#   'table': 't',
#   'table_id': 'Table_42',
#   'schema': 'subquery'},
#  {'field_id': 'if_208',
#   'field_name': 'actual_date',
#   'table': 't3',
#   'table_id': 'Table_43',
#   'schema': 'subquery'},
#  {'field_id': 'if_209',
#   'field_name': 'close_date',
#   'table': 't3',
#   'table_id': 'Table_43',
#   'schema': 'subquery'},
#  {'field_id': 'if_210',
#   'field_name': 'closed_flag',
#   'table': 't3',
#   'table_id': 'Table_43',
#   'schema': 'subquery'},
#  {'field_id': 'if_211',
#   'field_name': 'fr_release',
#   'table': 't3',
#   'table_id': 'Table_43',
#   'schema': 'subquery'},
#  {'field_id': 'if_212',
#   'field_name': 'central_purchasing_block',
#   'table': 'vendor',
#   'table_id': 'Table_44',
#   'schema': 'subquery'},
#  {'field_id': 'if_213',
#   'field_name': 'created_on',
#   'table': 'vendor',
#   'table_id': 'Table_44',
#   'schema': 'subquery'},
#  {'field_id': 'if_214',
#   'field_name': 'ffc_code',
#   'table': 'vendor',
#   'table_id': 'Table_44',
#   'schema': 'subquery'},
#  {'field_id': 'if_215',
#   'field_name': 'mdg_code',
#   'table': 'vendor',
#   'table_id': 'Table_44',
#   'schema': 'subquery'},
#  {'field_id': 'if_216',
#   'field_name': 'name1',
#   'table': 'vendor',
#   'table_id': 'Table_44',
#   'schema': 'subquery'},
#  {'field_id': 'if_217',
#   'field_name': 'name2',
#   'table': 'vendor',
#   'table_id': 'Table_44',
#   'schema': 'subquery'},
#  {'field_id': 'if_218',
#   'field_name': 'name3',
#   'table': 'vendor',
#   'table_id': 'Table_44',
#   'schema': 'subquery'},
#  {'field_id': 'if_219',
#   'field_name': 'name4',
#   'table': 'vendor',
#   'table_id': 'Table_44',
#   'schema': 'subquery'},
#  {'field_id': 'if_220',
#   'field_name': 'rk=1',
#   'table': 'vendor',
#   'table_id': 'Table_44',
#   'schema': 'subquery'},
#  {'field_id': 'if_221',
#   'field_name': 'vendor_ffc',
#   'table': 'vendor',
#   'table_id': 'Table_44',
#   'schema': 'subquery'},
#  {'field_id': 'if_222',
#   'field_name': 'vendor_group_name',
#   'table': 'vendor',
#   'table_id': 'Table_44',
#   'schema': 'subquery'},
#  {'field_id': 'if_223',
#   'field_name': 'vendor_grp_name',
#   'table': 'vendor',
#   'table_id': 'Table_44',
#   'schema': 'subquery'},
#  {'field_id': 'if_224',
#   'field_name': 'vendor_type',
#   'table': 'vendor',
#   'table_id': 'Table_44',
#   'schema': 'subquery'},
#  {'field_id': 'if_225',
#   'field_name': 'ack_date',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_226',
#   'field_name': 'actual_crd_at_origin',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_227',
#   'field_name': 'brand_requested_in_dc_date',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_228',
#   'field_name': 'color',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_229',
#   'field_name': 'completed',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_230',
#   'field_name': 'created_date',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_231',
#   'field_name': 'dc_code',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_232',
#   'field_name': 'delay_reason',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_233',
#   'field_name': 'dimension',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_234',
#   'field_name': 'done_flag',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_235',
#   'field_name': 'exit_cnty_port',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_236',
#   'field_name': 'first_actual_crd',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_237',
#   'field_name': 'first_shipment_id',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_238',
#   'field_name': 'freight_paid_by',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_239',
#   'field_name': 'fty_name',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_240',
#   'field_name': 'goods_description',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_241',
#   'field_name': 'green_light_date',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_242',
#   'field_name': 'hts_code',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_243',
#   'field_name': 'iscustomorder',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_244',
#   'field_name': 'issample',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_245',
#   'field_name': 'local_currency',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_246',
#   'field_name': 'master_po',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_247',
#   'field_name': 'misc22',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_248',
#   'field_name': 'misc24',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_249',
#   'field_name': 'misc26',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_250',
#   'field_name': 'misc3',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_251',
#   'field_name': 'misc30',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_252',
#   'field_name': 'misc33',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_253',
#   'field_name': 'order_amount_lc',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_254',
#   'field_name': 'original_crd_at_origin',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_255',
#   'field_name': 'po_cut',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_256',
#   'field_name': 'po_issue_date',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_257',
#   'field_name': 'po_location',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_258',
#   'field_name': 'po_season',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_259',
#   'field_name': 'po_type',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_260',
#   'field_name': 'product_line',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_261',
#   'field_name': 'purchasing_company',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_262',
#   'field_name': 'purchasing_group',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_263',
#   'field_name': 'rda_code',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_264',
#   'field_name': 'report_order_qty_lum',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_265',
#   'field_name': 'reqdelivery',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_266',
#   'field_name': 'revised_crd_at_origin',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_267',
#   'field_name': 'revised_dc_date',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_268',
#   'field_name': 'rfactory',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_269',
#   'field_name': 'sbu',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_270',
#   'field_name': 'season',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_271',
#   'field_name': 'season_cleaned',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_272',
#   'field_name': 'ship_route',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_273',
#   'field_name': 'ship_to_name',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_274',
#   'field_name': 'shipment',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_275',
#   'field_name': 'shipment_mode',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_276',
#   'field_name': 'shipment_terms',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_277',
#   'field_name': 'shipped_amt_lc',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_278',
#   'field_name': 'shipped_qty_lum',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_279',
#   'field_name': 'source_system',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_280',
#   'field_name': 'sourcing_office',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_281',
#   'field_name': 'src_sys',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_282',
#   'field_name': 'style',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_283',
#   'field_name': 'style_description',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_284',
#   'field_name': 'sub_sbu',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_285',
#   'field_name': 'vendor_name',
#   'table': 'z',
#   'table_id': 'Table_45',
#   'schema': 'subquery'},
#  {'field_id': 'if_286',
#   'field_name': 'brand',
#   'table': 'z2',
#   'table_id': 'Table_46',
#   'schema': 'subquery'},
#  {'field_id': 'if_287',
#   'field_name': 'brand2',
#   'table': 'z2',
#   'table_id': 'Table_46',
#   'schema': 'subquery'},
#  {'field_id': 'if_288',
#   'field_name': 'bu',
#   'table': 'z2',
#   'table_id': 'Table_46',
#   'schema': 'subquery'},
#  {'field_id': 'if_289',
#   'field_name': 'major_product_category',
#   'table': 'z2',
#   'table_id': 'Table_46',
#   'schema': 'subquery'},
#  {'field_id': 'if_290',
#   'field_name': 'market',
#   'table': 'z2',
#   'table_id': 'Table_46',
#   'schema': 'subquery'},
#  {'field_id': 'if_291',
#   'field_name': 'product_supply_group',
#   'table': 'z2',
#   'table_id': 'Table_46',
#   'schema': 'subquery'},
#  {'field_id': 'if_292',
#   'field_name': 'constant',
#   'table': 'system',
#   'table_id': 'Table_41',
#   'schema': 'system'}]

# %%
# Load nodes and draw location at relationships
gds.run_cypher('''
    UNWIND $int_fields AS a
    WITH a.field_id AS int_fieldID, 
         a.field_name AS int_field_name, 
         a.table AS table_name,
         a.table_id AS table_ID, 
         a.schema AS schema
    MERGE(n0:Table {tableId: table_ID}) SET n0.table_name=table_name
    MERGE(n1:IntermediateField {intfieldId: int_fieldID}) SET n1.int_field_name=int_field_name
    MERGE(n2:Schema {schema_Id: schema}) SET n2.schema=schema
    
    MERGE(n0)<-[:LOCATED_AT]-(n1)
    MERGE(n2)<-[:INSIDE_OF]-(n0)
   
    RETURN count(n0), count(n1), count(n2)
    ''', params={'int_fields':sub_dict})
# Out:
#    count(n0)  count(n1)  count(n2)
# 0        292        292        292

# %% [markdown]
# ## Ingest Relationships
# Relationships will consist of the freight forwarding steps as well as links representing connection between transportation segments and transfer between the inbound and output stage of the shipment

# %%
df = pd.read_csv('relationship_2_0.csv', dtype=str)
df['path_index'] = df['path_index'].str.lower()
df
# Out:
#                              :START_POSITION start_id  \
# 0                  sp_country_master \\ name   if_201
# 1                                z \\ po_cut   if_255
# 2                                 z \\ style   if_282
# 3                  otp_po_cut_level \\ style   df_003
# 4                  otp_po_cut_level \\ color   df_004
# ..                                       ...      ...
# 648               otp_po_cut_level \\ market   df_082
# 649             otp_po_cut_level \\ hts_code   df_051
# 650    otp_po_cut_level \\ country_of_origin   df_001
# 651  otp_po_cut_level \\ destination_country   df_105
# 652      otp_po_cut_level \\ fob_duties_rate   df_119
#
#                              :END_POSITION  end_id        type  \
# 0    otp_po_cut_level \\ country_of_origin  df_001     extract
# 1               otp_po_cut_level \\ po_cut  df_002     extract
# 2                otp_po_cut_level \\ style  df_003     extract
# 3                otp_po_cut_level \\ style  df_003  calculated
# 4                otp_po_cut_level \\ style  df_003  calculated
# ..                                     ...     ...         ...
# 648   #fob_duties_rate \\ avg_duty_fees_rt  if_001        join
# 649   #fob_duties_rate \\ avg_duty_fees_rt  if_001        join
# 650   #fob_duties_rate \\ avg_duty_fees_rt  if_001        join
# 651   #fob_duties_rate \\ avg_duty_fees_rt  if_001        join
# 652   #fob_duties_rate \\ avg_duty_fees_rt  if_001        join
#
#         stored_procedure cte_level         path_index
# 0    sp_otp_po_cut_level     first  country_of_origin
# 1    sp_otp_po_cut_level     first             po_cut
# 2    sp_otp_po_cut_level     first              style
# 3    sp_otp_po_cut_level     first              style
# 4    sp_otp_po_cut_level     first              style
# ..                   ...       ...                ...
# 648  sp_otp_po_cut_level     third    fob_duties_rate
# 649  sp_otp_po_cut_level     third    fob_duties_rate
# 650  sp_otp_po_cut_level     third    fob_duties_rate
# 651  sp_otp_po_cut_level     third    fob_duties_rate
# 652  sp_otp_po_cut_level     third    fob_duties_rate
#
# [653 rows x 8 columns]

# %%
#ingest extract field (case Intermediate -> extract -> Destination) 
sub_dict = df.loc[(df[f'start_id'].str.contains('if')) & (df[f'end_id'].str.contains('df')) & (df[f'type'] == 'extract'),
                  ['start_id', 'end_id','type', 'stored_procedure','cte_level', 'path_index']].to_dict('records')
sub_dict
# Out:
# [{'start_id': 'if_201',
#   'end_id': 'df_001',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'country_of_origin'},
#  {'start_id': 'if_255',
#   'end_id': 'df_002',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'po_cut'},
#  {'start_id': 'if_282',
#   'end_id': 'df_003',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'style'},
#  {'start_id': 'if_228',
#   'end_id': 'df_004',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'color'},
#  {'start_id': 'if_283',
#   'end_id': 'df_005',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'style_description'},
#  {'start_id': 'if_240',
#   'end_id': 'df_006',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'goods_description'},
#  {'start_id': 'if_256',
#   'end_id': 'df_007',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'po_issue_date'},
#  {'start_id': 'if_254',
#   'end_id': 'df_008',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'original_crd_at_origin'},
#  {'start_id': 'if_266',
#   'end_id': 'df_009',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'revised_crd_at_origin'},
#  {'start_id': 'if_245',
#   'end_id': 'df_011',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'local_currency'},
#  {'start_id': 'if_270',
#   'end_id': 'df_012',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'season'},
#  {'start_id': 'if_280',
#   'end_id': 'df_013',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'sourcing_office'},
#  {'start_id': 'if_279',
#   'end_id': 'df_014',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'source_system'},
#  {'start_id': 'if_231',
#   'end_id': 'df_015',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'dc_code'},
#  {'start_id': 'if_259',
#   'end_id': 'df_016',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'po_type'},
#  {'start_id': 'if_262',
#   'end_id': 'df_017',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'purchasing_group'},
#  {'start_id': 'if_269',
#   'end_id': 'df_018',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'sbu'},
#  {'start_id': 'if_011',
#   'end_id': 'df_018',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'sbu'},
#  {'start_id': 'if_011',
#   'end_id': 'df_018',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'sbu'},
#  {'start_id': 'if_284',
#   'end_id': 'df_019',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'sub_sbu'},
#  {'start_id': 'if_012',
#   'end_id': 'df_019',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'sub_sbu'},
#  {'start_id': 'if_012',
#   'end_id': 'df_019',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'sub_sbu'},
#  {'start_id': 'if_260',
#   'end_id': 'df_020',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'product_line'},
#  {'start_id': 'if_260',
#   'end_id': 'df_020',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'product_line'},
#  {'start_id': 'if_260',
#   'end_id': 'df_020',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'product_line'},
#  {'start_id': 'if_010',
#   'end_id': 'df_020',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'product_line'},
#  {'start_id': 'if_010',
#   'end_id': 'df_020',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'product_line'},
#  {'start_id': 'if_048',
#   'end_id': 'df_021',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'purchasing_company'},
#  {'start_id': 'if_232',
#   'end_id': 'df_025',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'delay_reason'},
#  {'start_id': 'if_276',
#   'end_id': 'df_026',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'shipment_terms'},
#  {'start_id': 'if_257',
#   'end_id': 'df_027',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'po_location'},
#  {'start_id': 'if_244',
#   'end_id': 'df_037',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'issample'},
#  {'start_id': 'if_244',
#   'end_id': 'df_037',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'issample'},
#  {'start_id': 'if_243',
#   'end_id': 'df_038',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'iscustomorder'},
#  {'start_id': 'if_243',
#   'end_id': 'df_038',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'iscustomorder'},
#  {'start_id': 'if_203',
#   'end_id': 'df_039',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'managing_office'},
#  {'start_id': 'if_204',
#   'end_id': 'df_040',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'current_date'},
#  {'start_id': 'if_281',
#   'end_id': 'df_041',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'src_sys'},
#  {'start_id': 'if_010',
#   'end_id': 'df_042',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'misc3'},
#  {'start_id': 'if_010',
#   'end_id': 'df_042',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'misc3'},
#  {'start_id': 'if_249',
#   'end_id': 'df_043',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'misc26'},
#  {'start_id': 'if_252',
#   'end_id': 'df_044',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'misc33'},
#  {'start_id': 'if_261',
#   'end_id': 'df_045',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'purchasing_company_code'},
#  {'start_id': 'if_230',
#   'end_id': 'df_049',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'po_creation_date'},
#  {'start_id': 'if_151',
#   'end_id': 'df_052',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'factory_designation'},
#  {'start_id': 'if_268',
#   'end_id': 'df_053',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'erp_factory_code'},
#  {'start_id': 'if_263',
#   'end_id': 'df_054',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'erp_vendor_code'},
#  {'start_id': 'if_258',
#   'end_id': 'df_055',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'po_season'},
#  {'start_id': 'if_267',
#   'end_id': 'df_056',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'revised_in_dc_date'},
#  {'start_id': 'if_275',
#   'end_id': 'df_057',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'ship_mode'},
#  {'start_id': 'if_225',
#   'end_id': 'df_058',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'po_acknowledgement_date'},
#  {'start_id': 'if_234',
#   'end_id': 'df_059',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'po_complete_status'},
#  {'start_id': 'if_246',
#   'end_id': 'df_063',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'master_po'},
#  {'start_id': 'if_238',
#   'end_id': 'df_064',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'freight_paid_by'},
#  {'start_id': 'if_235',
#   'end_id': 'df_065',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'exit_cnty_port'},
#  {'start_id': 'if_235',
#   'end_id': 'df_065',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'exit_cnty_port'},
#  {'start_id': 'if_273',
#   'end_id': 'df_066',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'ship_to_name'},
#  {'start_id': 'if_273',
#   'end_id': 'df_066',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'ship_to_name'},
#  {'start_id': 'if_227',
#   'end_id': 'df_067',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'brand_requested_in_dc_date'},
#  {'start_id': 'if_029',
#   'end_id': 'df_104',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'dc_name'},
#  {'start_id': 'if_165',
#   'end_id': 'df_106',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'shipment_status'},
#  {'start_id': 'if_165',
#   'end_id': 'df_106',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'shipment_status'},
#  {'start_id': 'if_165',
#   'end_id': 'df_106',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'shipment_status'},
#  {'start_id': 'if_167',
#   'end_id': 'df_107',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'fr_release'},
#  {'start_id': 'if_167',
#   'end_id': 'df_107',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'fr_release'},
#  {'start_id': 'if_167',
#   'end_id': 'df_107',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'fr_release'},
#  {'start_id': 'if_174',
#   'end_id': 'df_112',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'hts_product_category'},
#  {'start_id': 'if_175',
#   'end_id': 'df_113',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'hts_product_type'},
#  {'start_id': 'if_178',
#   'end_id': 'df_114',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'costing_season'},
#  {'start_id': 'if_186',
#   'end_id': 'df_119',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_186',
#   'end_id': 'df_119',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_186',
#   'end_id': 'df_119',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_186',
#   'end_id': 'df_119',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_186',
#   'end_id': 'df_119',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_186',
#   'end_id': 'df_119',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_186',
#   'end_id': 'df_119',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_186',
#   'end_id': 'df_119',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_186',
#   'end_id': 'df_119',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_186',
#   'end_id': 'df_119',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_186',
#   'end_id': 'df_119',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_186',
#   'end_id': 'df_119',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_065',
#   'end_id': 'df_120',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'payment_terms '},
#  {'start_id': 'if_014',
#   'end_id': 'df_121',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vf_fiscal_year_original_crd'},
#  {'start_id': 'if_013',
#   'end_id': 'df_122',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vf_fiscal_year_month_original_crd'},
#  {'start_id': 'if_007',
#   'end_id': 'df_123',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_007',
#   'end_id': 'df_123',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_007',
#   'end_id': 'df_123',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_007',
#   'end_id': 'df_123',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_004',
#   'end_id': 'df_123',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_004',
#   'end_id': 'df_123',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_004',
#   'end_id': 'df_123',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_057',
#   'end_id': 'df_124',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'preferential_duty_rate '},
#  {'start_id': 'if_158',
#   'end_id': 'df_125',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'cbm_pc_brand_cat '},
#  {'start_id': 'if_213',
#   'end_id': 'df_130',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'mdg_vendor_created_on '},
#  {'start_id': 'if_212',
#   'end_id': 'df_131',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'mdg_vendor_purchasing_block '},
#  {'start_id': 'if_139',
#   'end_id': 'df_132',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'mdg_factory_created_on '},
#  {'start_id': 'if_138',
#   'end_id': 'df_133',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'mdg_factory_purchasing_block '}]

# %%
# (n:FIELD)-[r:EXTRACT]-(n:FIELD) directly extract
gds.run_cypher('''
    UNWIND $relMaps AS relMap
    WITH relMap.start_id AS start_Id,
        relMap.end_id AS end_Id,
        relMap.stored_procedure AS stored_procedure,
        relMap.cte_level AS cte_level,
        relMap.path_index AS path_index
    MATCH(n1:IntermediateField {intfieldId: start_Id})
    MATCH(n2:DestinationField {destfieldId: end_Id})
    MERGE(n1)-[r:EXTRACT_TO {stored_procedure: stored_procedure, cte_level: cte_level}]->(n2)
    ON CREATE SET r.pathIndex = path_index
    RETURN count(r)
''', params={'relMaps':sub_dict})
# Out:
#    count(r)
# 0        97

# %%
#ingest extract field (case Intermediate -> extract -> Intermediate) 
sub_dict = df.loc[(df[f'start_id'].str.contains('if')) & (df[f'end_id'].str.contains('if')) & (df[f'type'] == 'extract'),
                  ['start_id', 'end_id','type', 'stored_procedure','cte_level', 'path_index']].to_dict('records')
sub_dict
# Out:
# [{'start_id': 'if_063',
#   'end_id': 'if_255',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'po_cut'},
#  {'start_id': 'if_115',
#   'end_id': 'if_282',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'style'},
#  {'start_id': 'if_058',
#   'end_id': 'if_228',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'color'},
#  {'start_id': 'if_074',
#   'end_id': 'if_283',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'style_description'},
#  {'start_id': 'if_080',
#   'end_id': 'if_240',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'goods_description'},
#  {'start_id': 'if_083',
#   'end_id': 'if_256',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'po_issue_date'},
#  {'start_id': 'if_090',
#   'end_id': 'if_254',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'original_crd_at_origin'},
#  {'start_id': 'if_100',
#   'end_id': 'if_266',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'revised_crd_at_origin'},
#  {'start_id': 'if_105',
#   'end_id': 'if_270',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'season'},
#  {'start_id': 'if_066',
#   'end_id': 'if_281',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_ffc'},
#  {'start_id': 'if_034',
#   'end_id': 'if_221',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_ffc'},
#  {'start_id': 'if_035',
#   'end_id': 'if_223',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_045',
#   'end_id': 'if_222',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_039',
#   'end_id': 'if_222',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_038',
#   'end_id': 'if_222',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_046',
#   'end_id': 'if_222',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_040',
#   'end_id': 'if_222',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_066',
#   'end_id': 'if_281',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'factory_ffc'},
#  {'start_id': 'if_110',
#   'end_id': 'if_276',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'shipment_terms'},
#  {'start_id': 'if_093',
#   'end_id': 'if_257',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'po_location'},
#  {'start_id': 'if_066',
#   'end_id': 'if_281',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_name'},
#  {'start_id': 'if_117',
#   'end_id': 'if_285',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_name'},
#  {'start_id': 'if_041',
#   'end_id': 'if_216',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_name'},
#  {'start_id': 'if_042',
#   'end_id': 'if_217',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_name'},
#  {'start_id': 'if_043',
#   'end_id': 'if_218',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_name'},
#  {'start_id': 'if_044',
#   'end_id': 'if_219',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_name'},
#  {'start_id': 'if_038',
#   'end_id': 'if_214',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_name'},
#  {'start_id': 'if_046',
#   'end_id': 'if_224',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_name'},
#  {'start_id': 'if_066',
#   'end_id': 'if_281',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'factory_name'},
#  {'start_id': 'if_079',
#   'end_id': 'if_239',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'factory_name'},
#  {'start_id': 'if_041',
#   'end_id': 'if_144',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'factory_name'},
#  {'start_id': 'if_042',
#   'end_id': 'if_145',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'factory_name'},
#  {'start_id': 'if_043',
#   'end_id': 'if_146',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'factory_name'},
#  {'start_id': 'if_044',
#   'end_id': 'if_147',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'factory_name'},
#  {'start_id': 'if_075',
#   'end_id': 'if_234',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'booked_qty_lum'},
#  {'start_id': 'if_075',
#   'end_id': 'if_234',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'booked_amt_local_currency'},
#  {'start_id': 'if_070',
#   'end_id': 'if_229',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'effective_qty'},
#  {'start_id': 'if_066',
#   'end_id': 'if_281',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'src_sys'},
#  {'start_id': 'if_066',
#   'end_id': 'if_281',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'misc3'},
#  {'start_id': 'if_115',
#   'end_id': 'if_282',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'tbr_defect_flag'},
#  {'start_id': 'if_059',
#   'end_id': 'if_233',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'tbr_defect_flag'},
#  {'start_id': 'if_072',
#   'end_id': 'if_230',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'po_creation_date'},
#  {'start_id': 'if_082',
#   'end_id': 'if_242',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'hts_code'},
#  {'start_id': 'if_102',
#   'end_id': 'if_268',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'erp_factory_code'},
#  {'start_id': 'if_097',
#   'end_id': 'if_263',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'erp_vendor_code'},
#  {'start_id': 'if_104',
#   'end_id': 'if_258',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'po_season'},
#  {'start_id': 'if_109',
#   'end_id': 'if_275',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'ship_mode'},
#  {'start_id': 'if_075',
#   'end_id': 'if_234',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'po_complete_status'},
#  {'start_id': 'if_107',
#   'end_id': 'if_246',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'master_po'},
#  {'start_id': 'if_078',
#   'end_id': 'if_238',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'freight_paid_by'},
#  {'start_id': 'if_091',
#   'end_id': 'if_227',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'brand_requested_in_dc_date'},
#  {'start_id': 'if_066',
#   'end_id': 'if_281',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'original_requested_production_end_date'},
#  {'start_id': 'if_066',
#   'end_id': 'if_281',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'latest_confirmed_production_end_date'},
#  {'start_id': 'if_066',
#   'end_id': 'if_281',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'buy_month'},
#  {'start_id': 'if_066',
#   'end_id': 'if_281',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'requested_delivery_date'},
#  {'start_id': 'if_066',
#   'end_id': 'if_281',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'po_closure_eligibility'},
#  {'start_id': 'if_106',
#   'end_id': 'if_271',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'season_cleaned'},
#  {'start_id': 'if_015',
#   'end_id': 'if_286',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'brand'},
#  {'start_id': 'if_018',
#   'end_id': 'if_289',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'major_product_category_name'},
#  {'start_id': 'if_017',
#   'end_id': 'if_288',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'business_unit '},
#  {'start_id': 'if_016',
#   'end_id': 'if_287',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'brand2 '},
#  {'start_id': 'if_019',
#   'end_id': 'if_290',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'market '},
#  {'start_id': 'if_020',
#   'end_id': 'if_291',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'product_supply_group '},
#  {'start_id': 'if_169',
#   'end_id': 'if_207',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'certified_pocut_flag'},
#  {'start_id': 'if_169',
#   'end_id': 'if_207',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'certprintdate'},
#  {'start_id': 'if_211',
#   'end_id': 'if_167',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'fr_release'},
#  {'start_id': 'if_211',
#   'end_id': 'if_167',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'fr_release'},
#  {'start_id': 'if_211',
#   'end_id': 'if_167',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'fr_release'},
#  {'start_id': 'if_209',
#   'end_id': 'if_168',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'shipment_id_closing_date'},
#  {'start_id': 'if_209',
#   'end_id': 'if_168',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'shipment_id_closing_date'},
#  {'start_id': 'if_209',
#   'end_id': 'if_168',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'shipment_id_closing_date'},
#  {'start_id': 'if_208',
#   'end_id': 'if_164',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'actual_ship_date'},
#  {'start_id': 'if_208',
#   'end_id': 'if_164',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'actual_ship_date'},
#  {'start_id': 'if_208',
#   'end_id': 'if_164',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'actual_ship_date'},
#  {'start_id': 'if_208',
#   'end_id': 'if_166',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'first_actual_ship_date'},
#  {'start_id': 'if_208',
#   'end_id': 'if_166',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'first_actual_ship_date'},
#  {'start_id': 'if_208',
#   'end_id': 'if_166',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'first_actual_ship_date'},
#  {'start_id': 'if_136',
#   'end_id': 'if_166',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'first_actual_ship_date'},
#  {'start_id': 'if_127',
#   'end_id': 'if_166',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'first_actual_ship_date'},
#  {'start_id': 'if_001',
#   'end_id': 'if_186',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_001',
#   'end_id': 'if_186',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_001',
#   'end_id': 'if_186',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_001',
#   'end_id': 'if_186',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_001',
#   'end_id': 'if_186',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_001',
#   'end_id': 'if_186',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_001',
#   'end_id': 'if_186',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_001',
#   'end_id': 'if_186',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_001',
#   'end_id': 'if_186',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_001',
#   'end_id': 'if_186',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_001',
#   'end_id': 'if_186',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_001',
#   'end_id': 'if_186',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_200',
#   'end_id': 'if_007',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_052',
#   'end_id': 'if_006',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_201',
#   'end_id': 'if_008',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_201',
#   'end_id': 'if_005',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_001',
#   'end_id': 'if_001',
#   'type': 'extract',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'fob_duties_rate'}]

# %%
# (n:FIELD)-[r:EXTRACT]-(n:FIELD) directly extract
gds.run_cypher('''
    UNWIND $relMaps AS relMap
    WITH relMap.start_id AS start_Id,
        relMap.end_id AS end_Id,
        relMap.stored_procedure AS stored_procedure,
        relMap.cte_level AS cte_level,
        relMap.path_index AS path_index
    MATCH(n1:IntermediateField {intfieldId: start_Id})
    MATCH(n2:IntermediateField {intfieldId: end_Id})
    MERGE(n1)-[r:EXTRACT_TO {stored_procedure: stored_procedure, cte_level: cte_level}]->(n2)
    ON CREATE SET r.pathIndex = path_index
    RETURN count(r)
''', params={'relMaps':sub_dict})
# Out:
#    count(r)
# 0        96

# %%
#ingest extract field Case inter -> calculated -> destination
sub_dict = df.loc[(df[f'start_id'].str.contains('if')) & (df[f'end_id'].str.contains('df')) & (df[f'type'] == 'calculated'),
                  ['start_id', 'end_id','type', 'stored_procedure','cte_level', 'path_index']].to_dict('records')
sub_dict
# Out:
# [{'start_id': 'if_226',
#   'end_id': 'df_010',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'actual_crd_at_origin'},
#  {'start_id': 'if_281',
#   'end_id': 'df_022',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_ffc'},
#  {'start_id': 'if_221',
#   'end_id': 'df_022',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_ffc'},
#  {'start_id': 'if_221',
#   'end_id': 'df_022',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_ffc'},
#  {'start_id': 'if_221',
#   'end_id': 'df_022',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_ffc'},
#  {'start_id': 'if_221',
#   'end_id': 'df_022',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_ffc'},
#  {'start_id': 'if_221',
#   'end_id': 'df_022',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_ffc'},
#  {'start_id': 'if_221',
#   'end_id': 'df_022',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_ffc'},
#  {'start_id': 'if_176',
#   'end_id': 'df_022',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_ffc'},
#  {'start_id': 'if_223',
#   'end_id': 'df_023',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_223',
#   'end_id': 'df_023',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_223',
#   'end_id': 'df_023',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_223',
#   'end_id': 'df_023',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_223',
#   'end_id': 'df_023',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_223',
#   'end_id': 'df_023',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_222',
#   'end_id': 'df_023',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_222',
#   'end_id': 'df_023',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_222',
#   'end_id': 'df_023',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_222',
#   'end_id': 'df_023',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_222',
#   'end_id': 'df_023',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_281',
#   'end_id': 'df_024',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'factory_ffc'},
#  {'start_id': 'if_141',
#   'end_id': 'df_024',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'factory_ffc'},
#  {'start_id': 'if_150',
#   'end_id': 'df_024',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'factory_ffc'},
#  {'start_id': 'if_281',
#   'end_id': 'df_028',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_name'},
#  {'start_id': 'if_223',
#   'end_id': 'df_028',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_name'},
#  {'start_id': 'if_285',
#   'end_id': 'df_028',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_name'},
#  {'start_id': 'if_216',
#   'end_id': 'df_028',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_name'},
#  {'start_id': 'if_217',
#   'end_id': 'df_028',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_name'},
#  {'start_id': 'if_218',
#   'end_id': 'df_028',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_name'},
#  {'start_id': 'if_219',
#   'end_id': 'df_028',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_name'},
#  {'start_id': 'if_224',
#   'end_id': 'df_028',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_name'},
#  {'start_id': 'if_220',
#   'end_id': 'df_028',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_name'},
#  {'start_id': 'if_281',
#   'end_id': 'df_029',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'factory_name'},
#  {'start_id': 'if_142',
#   'end_id': 'df_029',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'factory_name'},
#  {'start_id': 'if_239',
#   'end_id': 'df_029',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'factory_name'},
#  {'start_id': 'if_144',
#   'end_id': 'df_029',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'factory_name'},
#  {'start_id': 'if_145',
#   'end_id': 'df_029',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'factory_name'},
#  {'start_id': 'if_146',
#   'end_id': 'df_029',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'factory_name'},
#  {'start_id': 'if_147',
#   'end_id': 'df_029',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'factory_name'},
#  {'start_id': 'if_185',
#   'end_id': 'df_031',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'order_amount_local_currency'},
#  {'start_id': 'if_278',
#   'end_id': 'df_032',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'shipped_qty_lum'},
#  {'start_id': 'if_277',
#   'end_id': 'df_033',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'shipped_amt_local_currency'},
#  {'start_id': 'if_234',
#   'end_id': 'df_034',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'booked_qty_lum'},
#  {'start_id': 'if_278',
#   'end_id': 'df_034',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'booked_qty_lum'},
#  {'start_id': 'if_278',
#   'end_id': 'df_034',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'booked_qty_lum'},
#  {'start_id': 'if_278',
#   'end_id': 'df_034',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'booked_qty_lum'},
#  {'start_id': 'if_264',
#   'end_id': 'df_034',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'booked_qty_lum'},
#  {'start_id': 'if_264',
#   'end_id': 'df_034',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'booked_qty_lum'},
#  {'start_id': 'if_264',
#   'end_id': 'df_034',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'booked_qty_lum'},
#  {'start_id': 'if_234',
#   'end_id': 'df_035',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'booked_amt_local_currency'},
#  {'start_id': 'if_278',
#   'end_id': 'df_035',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'booked_amt_local_currency'},
#  {'start_id': 'if_278',
#   'end_id': 'df_035',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'booked_amt_local_currency'},
#  {'start_id': 'if_278',
#   'end_id': 'df_035',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'booked_amt_local_currency'},
#  {'start_id': 'if_253',
#   'end_id': 'df_035',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'booked_amt_local_currency'},
#  {'start_id': 'if_253',
#   'end_id': 'df_035',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'booked_amt_local_currency'},
#  {'start_id': 'if_229',
#   'end_id': 'df_036',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'effective_qty'},
#  {'start_id': 'if_278',
#   'end_id': 'df_036',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'effective_qty'},
#  {'start_id': 'if_278',
#   'end_id': 'df_036',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'effective_qty'},
#  {'start_id': 'if_278',
#   'end_id': 'df_036',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'effective_qty'},
#  {'start_id': 'if_264',
#   'end_id': 'df_036',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'effective_qty'},
#  {'start_id': 'if_264',
#   'end_id': 'df_036',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'effective_qty'},
#  {'start_id': 'if_264',
#   'end_id': 'df_036',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'effective_qty'},
#  {'start_id': 'if_281',
#   'end_id': 'df_042',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'misc3'},
#  {'start_id': 'if_260',
#   'end_id': 'df_042',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'misc3'},
#  {'start_id': 'if_260',
#   'end_id': 'df_042',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'misc3'},
#  {'start_id': 'if_260',
#   'end_id': 'df_042',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'misc3'},
#  {'start_id': 'if_250',
#   'end_id': 'df_042',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'misc3'},
#  {'start_id': 'if_226',
#   'end_id': 'df_046',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'exch_rate_date'},
#  {'start_id': 'if_266',
#   'end_id': 'df_046',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'exch_rate_date'},
#  {'start_id': 'if_047',
#   'end_id': 'df_047',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'od_misc_flag'},
#  {'start_id': 'if_049',
#   'end_id': 'df_047',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'od_misc_flag'},
#  {'start_id': 'if_284',
#   'end_id': 'df_048',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'tbr_defect_flag'},
#  {'start_id': 'if_279',
#   'end_id': 'df_048',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'tbr_defect_flag'},
#  {'start_id': 'if_282',
#   'end_id': 'df_048',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'tbr_defect_flag'},
#  {'start_id': 'if_269',
#   'end_id': 'df_048',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'tbr_defect_flag'},
#  {'start_id': 'if_233',
#   'end_id': 'df_048',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'tbr_defect_flag'},
#  {'start_id': 'if_274',
#   'end_id': 'df_050',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'shipment_id'},
#  {'start_id': 'if_242',
#   'end_id': 'df_051',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'hts_code'},
#  {'start_id': 'if_241',
#   'end_id': 'df_060',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'greenlight_date'},
#  {'start_id': 'if_237',
#   'end_id': 'df_061',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'first_shipment_id'},
#  {'start_id': 'if_236',
#   'end_id': 'df_062',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'first_actual_crd'},
#  {'start_id': 'if_281',
#   'end_id': 'df_068',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'original_requested_production_end_date'},
#  {'start_id': 'if_247',
#   'end_id': 'df_068',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'original_requested_production_end_date'},
#  {'start_id': 'if_064',
#   'end_id': 'df_068',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'original_requested_production_end_date'},
#  {'start_id': 'if_063',
#   'end_id': 'df_068',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'original_requested_production_end_date'},
#  {'start_id': 'if_281',
#   'end_id': 'df_069',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'latest_confirmed_production_end_date'},
#  {'start_id': 'if_251',
#   'end_id': 'df_069',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'latest_confirmed_production_end_date'},
#  {'start_id': 'if_062',
#   'end_id': 'df_069',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'latest_confirmed_production_end_date'},
#  {'start_id': 'if_281',
#   'end_id': 'df_070',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'buy_month'},
#  {'start_id': 'if_248',
#   'end_id': 'df_070',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'buy_month'},
#  {'start_id': 'if_281',
#   'end_id': 'df_071',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'requested_delivery_date'},
#  {'start_id': 'if_265',
#   'end_id': 'df_071',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'requested_delivery_date'},
#  {'start_id': 'if_281',
#   'end_id': 'df_072',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'po_closure_eligibility'},
#  {'start_id': 'if_272',
#   'end_id': 'df_072',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'po_closure_eligibility'},
#  {'start_id': 'if_205',
#   'end_id': 'df_073',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'discharge_at_port_of_destination'},
#  {'start_id': 'if_271',
#   'end_id': 'df_074',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'season_cleaned'},
#  {'start_id': 'if_131',
#   'end_id': 'df_075',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vf_est_dc_arrival_date'},
#  {'start_id': 'if_134',
#   'end_id': 'df_076',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'asn_released_to_3pl'},
#  {'start_id': 'if_126',
#   'end_id': 'df_076',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'asn_released_to_3pl'},
#  {'start_id': 'if_127',
#   'end_id': 'df_076',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'asn_released_to_3pl'},
#  {'start_id': 'if_119',
#   'end_id': 'df_077',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'container_number'},
#  {'start_id': 'if_122',
#   'end_id': 'df_077',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'container_number'},
#  {'start_id': 'if_123',
#   'end_id': 'df_077',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'container_number'},
#  {'start_id': 'if_126',
#   'end_id': 'df_077',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'container_number'},
#  {'start_id': 'if_286',
#   'end_id': 'df_078',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'brand'},
#  {'start_id': 'if_289',
#   'end_id': 'df_079',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'major_product_category_name'},
#  {'start_id': 'if_288',
#   'end_id': 'df_080',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'business_unit '},
#  {'start_id': 'if_287',
#   'end_id': 'df_081',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'brand2 '},
#  {'start_id': 'if_290',
#   'end_id': 'df_082',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'market '},
#  {'start_id': 'if_291',
#   'end_id': 'df_083',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'product_supply_group '},
#  {'start_id': 'if_025',
#   'end_id': 'df_084',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'exchange_rate'},
#  {'start_id': 'if_022',
#   'end_id': 'df_084',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'exchange_rate'},
#  {'start_id': 'if_021',
#   'end_id': 'df_084',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'exchange_rate'},
#  {'start_id': 'if_024',
#   'end_id': 'df_084',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'exchange_rate'},
#  {'start_id': 'if_023',
#   'end_id': 'df_084',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'exchange_rate'},
#  {'start_id': 'if_292',
#   'end_id': 'df_084',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'exchange_rate'},
#  {'start_id': 'if_207',
#   'end_id': 'df_085',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'certified_pocut_flag'},
#  {'start_id': 'if_207',
#   'end_id': 'df_085',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'certified_pocut_flag'},
#  {'start_id': 'if_207',
#   'end_id': 'df_085',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'certified_pocut_flag'},
#  {'start_id': 'if_207',
#   'end_id': 'df_086',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'certprintdate'},
#  {'start_id': 'if_207',
#   'end_id': 'df_086',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'certprintdate'},
#  {'start_id': 'if_207',
#   'end_id': 'df_086',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'certprintdate'},
#  {'start_id': 'if_206',
#   'end_id': 'df_087',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'table_names'},
#  {'start_id': 'if_172',
#   'end_id': 'df_100',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'crc_code'},
#  {'start_id': 'if_171',
#   'end_id': 'df_100',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'crc_code'},
#  {'start_id': 'if_172',
#   'end_id': 'df_101',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'crc_description'},
#  {'start_id': 'if_171',
#   'end_id': 'df_101',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'crc_description'},
#  {'start_id': 'if_075',
#   'end_id': 'df_103',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'balance_qty'},
#  {'start_id': 'if_063',
#   'end_id': 'df_103',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'balance_qty'},
#  {'start_id': 'if_168',
#   'end_id': 'df_108',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'shipment_id_closing_date'},
#  {'start_id': 'if_168',
#   'end_id': 'df_108',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'shipment_id_closing_date'},
#  {'start_id': 'if_168',
#   'end_id': 'df_108',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'shipment_id_closing_date'},
#  {'start_id': 'if_164',
#   'end_id': 'df_109',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'actual_ship_date'},
#  {'start_id': 'if_164',
#   'end_id': 'df_109',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'actual_ship_date'},
#  {'start_id': 'if_164',
#   'end_id': 'df_109',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'actual_ship_date'},
#  {'start_id': 'if_128',
#   'end_id': 'df_109',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'actual_ship_date'},
#  {'start_id': 'if_166',
#   'end_id': 'df_110',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'first_actual_ship_date'},
#  {'start_id': 'if_166',
#   'end_id': 'df_110',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'first_actual_ship_date'},
#  {'start_id': 'if_166',
#   'end_id': 'df_110',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'first_actual_ship_date'},
#  {'start_id': 'if_166',
#   'end_id': 'df_110',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'first_actual_ship_date'},
#  {'start_id': 'if_166',
#   'end_id': 'df_110',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'first_actual_ship_date'},
#  {'start_id': 'if_128',
#   'end_id': 'df_110',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'first_actual_ship_date'},
#  {'start_id': 'if_127',
#   'end_id': 'df_111',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'shipment_closed_by'},
#  {'start_id': 'if_125',
#   'end_id': 'df_111',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'shipment_closed_by'},
#  {'start_id': 'if_162',
#   'end_id': 'df_126',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'freight_cost '}]

# %%
# (n:FIELD)-[r:CALCULATED_TO]-(n:FIELD) involved calculation
gds.run_cypher('''
    UNWIND $relMaps AS relMap
    WITH relMap.start_id AS start_Id,
        relMap.end_id AS end_Id,
        relMap.stored_procedure AS stored_procedure,
        relMap.cte_level AS cte_level,
        relMap.path_index AS path_index
    MATCH(n1:IntermediateField {intfieldId: start_Id})
    MATCH(n2:DestinationField {destfieldId: end_Id})
    MERGE(n1)-[r:CALCULATED_TO {stored_procedure: stored_procedure, cte_level: cte_level}]->(n2)
    ON CREATE SET r.pathIndex = path_index
    RETURN count(r)
''', params={'relMaps':sub_dict})
# Out:
#    count(r)
# 0       145

# %%
#ingest extract field Case inter -> calculated -> inter
sub_dict = df.loc[(df[f'start_id'].str.contains('if')) & (df[f'end_id'].str.contains('if')) & (df[f'type'] == 'calculated'),
                  ['start_id', 'end_id','type', 'stored_procedure','cte_level', 'path_index']].to_dict('records')
sub_dict
# Out:
# [{'start_id': 'if_118',
#   'end_id': 'if_226',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'actual_crd_at_origin'},
#  {'start_id': 'if_073',
#   'end_id': 'if_245',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'local_currency'},
#  {'start_id': 'if_111',
#   'end_id': 'if_280',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'sourcing_office'},
#  {'start_id': 'if_112',
#   'end_id': 'if_279',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'source_system'},
#  {'start_id': 'if_114',
#   'end_id': 'if_231',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'dc_code'},
#  {'start_id': 'if_094',
#   'end_id': 'if_259',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'po_type'},
#  {'start_id': 'if_096',
#   'end_id': 'if_262',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'purchasing_group'},
#  {'start_id': 'if_103',
#   'end_id': 'if_269',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'sbu'},
#  {'start_id': 'if_026',
#   'end_id': 'if_011',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'sbu'},
#  {'start_id': 'if_096',
#   'end_id': 'if_011',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'sbu'},
#  {'start_id': 'if_116',
#   'end_id': 'if_284',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'sub_sbu'},
#  {'start_id': 'if_027',
#   'end_id': 'if_012',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'sub_sbu'},
#  {'start_id': 'if_183',
#   'end_id': 'if_012',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'sub_sbu'},
#  {'start_id': 'if_066',
#   'end_id': 'if_260',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'product_line'},
#  {'start_id': 'if_069',
#   'end_id': 'if_260',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'product_line'},
#  {'start_id': 'if_092',
#   'end_id': 'if_260',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'product_line'},
#  {'start_id': 'if_028',
#   'end_id': 'if_010',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'product_line'},
#  {'start_id': 'if_184',
#   'end_id': 'if_010',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'product_line'},
#  {'start_id': 'if_084',
#   'end_id': 'if_232',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'delay_reason'},
#  {'start_id': 'if_046',
#   'end_id': 'if_220',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_name'},
#  {'start_id': 'if_046',
#   'end_id': 'if_148',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'factory_name'},
#  {'start_id': 'if_115',
#   'end_id': 'if_278',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'booked_qty_lum'},
#  {'start_id': 'if_050',
#   'end_id': 'if_278',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'booked_qty_lum'},
#  {'start_id': 'if_121',
#   'end_id': 'if_278',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'booked_qty_lum'},
#  {'start_id': 'if_115',
#   'end_id': 'if_264',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'booked_qty_lum'},
#  {'start_id': 'if_050',
#   'end_id': 'if_264',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'booked_qty_lum'},
#  {'start_id': 'if_120',
#   'end_id': 'if_264',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'booked_qty_lum'},
#  {'start_id': 'if_115',
#   'end_id': 'if_278',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'booked_amt_local_currency'},
#  {'start_id': 'if_050',
#   'end_id': 'if_278',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'booked_amt_local_currency'},
#  {'start_id': 'if_121',
#   'end_id': 'if_278',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'booked_amt_local_currency'},
#  {'start_id': 'if_060',
#   'end_id': 'if_253',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'booked_amt_local_currency'},
#  {'start_id': 'if_061',
#   'end_id': 'if_253',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'booked_amt_local_currency'},
#  {'start_id': 'if_115',
#   'end_id': 'if_278',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'effective_qty'},
#  {'start_id': 'if_050',
#   'end_id': 'if_278',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'effective_qty'},
#  {'start_id': 'if_121',
#   'end_id': 'if_278',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'effective_qty'},
#  {'start_id': 'if_115',
#   'end_id': 'if_264',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'effective_qty'},
#  {'start_id': 'if_050',
#   'end_id': 'if_264',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'effective_qty'},
#  {'start_id': 'if_120',
#   'end_id': 'if_264',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'effective_qty'},
#  {'start_id': 'if_066',
#   'end_id': 'if_244',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'issample'},
#  {'start_id': 'if_094',
#   'end_id': 'if_244',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'issample'},
#  {'start_id': 'if_066',
#   'end_id': 'if_243',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'iscustomorder'},
#  {'start_id': 'if_094',
#   'end_id': 'if_243',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'iscustomorder'},
#  {'start_id': 'if_066',
#   'end_id': 'if_260',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'misc3'},
#  {'start_id': 'if_069',
#   'end_id': 'if_260',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'misc3'},
#  {'start_id': 'if_092',
#   'end_id': 'if_260',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'misc3'},
#  {'start_id': 'if_087',
#   'end_id': 'if_250',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'misc3'},
#  {'start_id': 'if_028',
#   'end_id': 'if_010',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'misc3'},
#  {'start_id': 'if_184',
#   'end_id': 'if_010',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'misc3'},
#  {'start_id': 'if_086',
#   'end_id': 'if_249',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'misc26'},
#  {'start_id': 'if_088',
#   'end_id': 'if_252',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'misc33'},
#  {'start_id': 'if_095',
#   'end_id': 'if_261',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'purchasing_company_code'},
#  {'start_id': 'if_118',
#   'end_id': 'if_226',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'exch_rate_date'},
#  {'start_id': 'if_116',
#   'end_id': 'if_284',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'tbr_defect_flag'},
#  {'start_id': 'if_112',
#   'end_id': 'if_279',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'tbr_defect_flag'},
#  {'start_id': 'if_103',
#   'end_id': 'if_269',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'tbr_defect_flag'},
#  {'start_id': 'if_126',
#   'end_id': 'if_274',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'shipment_id'},
#  {'start_id': 'if_101',
#   'end_id': 'if_267',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'revised_in_dc_date'},
#  {'start_id': 'if_067',
#   'end_id': 'if_225',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'po_acknowledgement_date'},
#  {'start_id': 'if_081',
#   'end_id': 'if_241',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'greenlight_date'},
#  {'start_id': 'if_126',
#   'end_id': 'if_237',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'first_shipment_id'},
#  {'start_id': 'if_118',
#   'end_id': 'if_236',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'first_actual_crd'},
#  {'start_id': 'if_076',
#   'end_id': 'if_235',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'exit_cnty_port'},
#  {'start_id': 'if_077',
#   'end_id': 'if_235',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'exit_cnty_port'},
#  {'start_id': 'if_114',
#   'end_id': 'if_273',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'ship_to_name'},
#  {'start_id': 'if_089',
#   'end_id': 'if_273',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'ship_to_name'},
#  {'start_id': 'if_098',
#   'end_id': 'if_247',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'original_requested_production_end_date'},
#  {'start_id': 'if_071',
#   'end_id': 'if_251',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'latest_confirmed_production_end_date'},
#  {'start_id': 'if_068',
#   'end_id': 'if_248',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'buy_month'},
#  {'start_id': 'if_099',
#   'end_id': 'if_265',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'requested_delivery_date'},
#  {'start_id': 'if_108',
#   'end_id': 'if_272',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'po_closure_eligibility'},
#  {'start_id': 'if_210',
#   'end_id': 'if_165',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'shipment_status'},
#  {'start_id': 'if_210',
#   'end_id': 'if_165',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'shipment_status'},
#  {'start_id': 'if_210',
#   'end_id': 'if_165',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'shipment_status'},
#  {'start_id': 'if_054',
#   'end_id': 'if_004',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_051',
#   'end_id': 'if_003',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_037',
#   'end_id': 'if_213',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'mdg_vendor_created_on '},
#  {'start_id': 'if_036',
#   'end_id': 'if_212',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'mdg_vendor_purchasing_block '},
#  {'start_id': 'if_037',
#   'end_id': 'if_139',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'mdg_factory_created_on '},
#  {'start_id': 'if_036',
#   'end_id': 'if_138',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'mdg_factory_purchasing_block '},
#  {'start_id': 'if_130',
#   'end_id': 'if_210',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'shipment_status'},
#  {'start_id': 'if_124',
#   'end_id': 'if_211',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'fr_release'},
#  {'start_id': 'if_129',
#   'end_id': 'if_209',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'shipment_id_closing_date'},
#  {'start_id': 'if_128',
#   'end_id': 'if_208',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'actual_ship_date'},
#  {'start_id': 'if_132',
#   'end_id': 'if_208',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'first_actual_ship_date'}]

# %%
# (n:FIELD)-[r:CALCULATED_TO]-(n:FIELD) involved calculation
gds.run_cypher('''
    UNWIND $relMaps AS relMap
    WITH relMap.start_id AS start_Id,
        relMap.end_id AS end_Id,
        relMap.stored_procedure AS stored_procedure,
        relMap.cte_level AS cte_level,
        relMap.path_index AS path_index
    MATCH(n1:IntermediateField {intfieldId: start_Id})
    MATCH(n2:IntermediateField {intfieldId: end_Id})
    MERGE(n1)-[r:CALCULATED_TO {stored_procedure: stored_procedure, cte_level: cte_level}]->(n2)
    ON CREATE SET r.pathIndex = path_index
    RETURN count(r)
''', params={'relMaps':sub_dict})
# Out:
#    count(r)
# 0        84

# %%
#ingest extract field Case destination-> calculated -> destination
sub_dict = df.loc[(df[f'start_id'].str.contains('df')) & (df[f'end_id'].str.contains('df')) & (df[f'type'] == 'calculated'),
                  ['start_id', 'end_id','type', 'stored_procedure','cte_level', 'path_index']].to_dict('records')
sub_dict
# Out:
# [{'start_id': 'df_003',
#   'end_id': 'df_003',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'style'},
#  {'start_id': 'df_004',
#   'end_id': 'df_003',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'style'},
#  {'start_id': 'df_041',
#   'end_id': 'df_003',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'style'},
#  {'start_id': 'df_012',
#   'end_id': 'df_012',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'season'},
#  {'start_id': 'df_041',
#   'end_id': 'df_012',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'season'},
#  {'start_id': 'df_030',
#   'end_id': 'df_030',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'report_order_qty_lum'},
#  {'start_id': 'df_041',
#   'end_id': 'df_055',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'po_season'},
#  {'start_id': 'df_055',
#   'end_id': 'df_055',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'po_season'},
#  {'start_id': 'df_066',
#   'end_id': 'df_066',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'ship_to_name'},
#  {'start_id': 'df_104',
#   'end_id': 'df_066',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'ship_to_name'},
#  {'start_id': 'df_041',
#   'end_id': 'df_068',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'original_requested_production_end_date'},
#  {'start_id': 'df_068',
#   'end_id': 'df_068',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'original_requested_production_end_date'},
#  {'start_id': 'df_002',
#   'end_id': 'df_068',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'original_requested_production_end_date'},
#  {'start_id': 'df_041',
#   'end_id': 'df_069',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'latest_confirmed_production_end_date'},
#  {'start_id': 'df_069',
#   'end_id': 'df_069',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'latest_confirmed_production_end_date'},
#  {'start_id': 'df_014',
#   'end_id': 'df_070',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'buy_month'},
#  {'start_id': 'df_007',
#   'end_id': 'df_070',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'buy_month'},
#  {'start_id': 'df_049',
#   'end_id': 'df_070',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'buy_month'},
#  {'start_id': 'df_041',
#   'end_id': 'df_070',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'buy_month'},
#  {'start_id': 'df_074',
#   'end_id': 'df_074',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'season_cleaned'},
#  {'start_id': 'df_041',
#   'end_id': 'df_076',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'asn_released_to_3pl'},
#  {'start_id': 'df_050',
#   'end_id': 'df_076',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'asn_released_to_3pl'},
#  {'start_id': 'df_050',
#   'end_id': 'df_077',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'container_number'},
#  {'start_id': 'df_041',
#   'end_id': 'df_077',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'container_number'},
#  {'start_id': 'df_046',
#   'end_id': 'df_084',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'exchange_rate'},
#  {'start_id': 'df_011',
#   'end_id': 'df_084',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'exchange_rate'},
#  {'start_id': 'df_031',
#   'end_id': 'df_088',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'order_amount_usd'},
#  {'start_id': 'df_084',
#   'end_id': 'df_088',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'order_amount_usd'},
#  {'start_id': 'df_033',
#   'end_id': 'df_089',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'shipped_amt_usd'},
#  {'start_id': 'df_084',
#   'end_id': 'df_089',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'shipped_amt_usd'},
#  {'start_id': 'df_030',
#   'end_id': 'df_090',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'unit_price'},
#  {'start_id': 'df_088',
#   'end_id': 'df_090',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'unit_price'},
#  {'start_id': 'df_010',
#   'end_id': 'df_091',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'effective_crd'},
#  {'start_id': 'df_009',
#   'end_id': 'df_091',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'effective_crd'},
#  {'start_id': 'df_134',
#   'end_id': 'df_092',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'fob_price_usd'},
#  {'start_id': 'df_084',
#   'end_id': 'df_092',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'fob_price_usd'},
#  {'start_id': 'df_030',
#   'end_id': 'df_093',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'unit_price_average_in_usd'},
#  {'start_id': 'df_088',
#   'end_id': 'df_093',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'unit_price_average_in_usd'},
#  {'start_id': 'df_091',
#   'end_id': 'df_094',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'effective_crd_year'},
#  {'start_id': 'df_091',
#   'end_id': 'df_095',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'effective_crd_month'},
#  {'start_id': 'df_010',
#   'end_id': 'df_096',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'days_late'},
#  {'start_id': 'df_009',
#   'end_id': 'df_096',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'days_late'},
#  {'start_id': 'df_037',
#   'end_id': 'df_097',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'order_type_calculated'},
#  {'start_id': 'df_038',
#   'end_id': 'df_097',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'order_type_calculated'},
#  {'start_id': 'df_035',
#   'end_id': 'df_098',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'booked_amt_usd'},
#  {'start_id': 'df_084',
#   'end_id': 'df_098',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'booked_amt_usd'},
#  {'start_id': 'df_089',
#   'end_id': 'df_099',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'effective_amt_usd'},
#  {'start_id': 'df_088',
#   'end_id': 'df_099',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'effective_amt_usd'},
#  {'start_id': 'df_025',
#   'end_id': 'df_100',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'crc_code'},
#  {'start_id': 'df_025',
#   'end_id': 'df_101',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'crc_description'},
#  {'start_id': 'df_100',
#   'end_id': 'df_102',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'crc_owner'},
#  {'start_id': 'df_032',
#   'end_id': 'df_103',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'balance_qty'},
#  {'start_id': 'df_030',
#   'end_id': 'df_103',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'balance_qty'},
#  {'start_id': 'df_032',
#   'end_id': 'df_103',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'balance_qty'},
#  {'start_id': 'df_002',
#   'end_id': 'df_103',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'balance_qty'},
#  {'start_id': 'df_015',
#   'end_id': 'df_104',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'dc_name'},
#  {'start_id': 'df_091',
#   'end_id': 'df_115',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'orders_to_be_produced_qty'},
#  {'start_id': 'df_034',
#   'end_id': 'df_115',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'orders_to_be_produced_qty'},
#  {'start_id': 'df_032',
#   'end_id': 'df_115',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'orders_to_be_produced_qty'},
#  {'start_id': 'df_091',
#   'end_id': 'df_116',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'orders_to_be_produced_amt_usd'},
#  {'start_id': 'df_098',
#   'end_id': 'df_116',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'orders_to_be_produced_amt_usd'},
#  {'start_id': 'df_089',
#   'end_id': 'df_116',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'orders_to_be_produced_amt_usd'},
#  {'start_id': 'df_010',
#   'end_id': 'df_117',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'actual_produced_qty'},
#  {'start_id': 'df_032',
#   'end_id': 'df_117',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'actual_produced_qty'},
#  {'start_id': 'df_010',
#   'end_id': 'df_118',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'actual_produced_amt_usd'},
#  {'start_id': 'df_089',
#   'end_id': 'df_118',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'actual_produced_amt_usd'},
#  {'start_id': 'df_125',
#   'end_id': 'df_126',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'freight_cost '},
#  {'start_id': 'df_036',
#   'end_id': 'df_126',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'freight_cost '},
#  {'start_id': 'df_124',
#   'end_id': 'df_127',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'applied_duty_rate '},
#  {'start_id': 'df_123',
#   'end_id': 'df_127',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'applied_duty_rate '},
#  {'start_id': 'df_124',
#   'end_id': 'df_128',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'calculated_duty_amt '},
#  {'start_id': 'df_099',
#   'end_id': 'df_128',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'calculated_duty_amt '},
#  {'start_id': 'df_135',
#   'end_id': 'df_128',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'calculated_duty_amt '},
#  {'start_id': 'df_036',
#   'end_id': 'df_128',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'calculated_duty_amt '},
#  {'start_id': 'df_123',
#   'end_id': 'df_128',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'calculated_duty_amt '},
#  {'start_id': 'df_135',
#   'end_id': 'df_128',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'calculated_duty_amt '},
#  {'start_id': 'df_124',
#   'end_id': 'df_129',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'fully_landed_cost '},
#  {'start_id': 'df_099',
#   'end_id': 'df_129',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'fully_landed_cost '},
#  {'start_id': 'df_126',
#   'end_id': 'df_129',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'fully_landed_cost '},
#  {'start_id': 'df_135',
#   'end_id': 'df_129',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'fully_landed_cost '},
#  {'start_id': 'df_036',
#   'end_id': 'df_129',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'fully_landed_cost '},
#  {'start_id': 'df_123',
#   'end_id': 'df_129',
#   'type': 'calculated',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'fully_landed_cost '}]

# %%
# (n:FIELD)-[r:CALCULATED_TO]-(n:FIELD) involved calculation
gds.run_cypher('''
    UNWIND $relMaps AS relMap
    WITH relMap.start_id AS start_Id,
        relMap.end_id AS end_Id,
        relMap.stored_procedure AS stored_procedure,
        relMap.cte_level AS cte_level,
        relMap.path_index AS path_index
    MATCH(n1:DestinationField {destfieldId: start_Id})
    MATCH(n2:DestinationField {destfieldId: end_Id})
    MERGE(n1)-[r:CALCULATED_TO {stored_procedure: stored_procedure, cte_level: cte_level}]->(n2)
    ON CREATE SET r.pathIndex = path_index
    RETURN count(r)
''', params={'relMaps':sub_dict})
# Out:
#    count(r)
# 0        82

# %%
#ingest extract field inter -> join -> dest
sub_dict = df.loc[(df[f'start_id'].str.contains('if')) & (df[f'end_id'].str.contains('df')) & (df[f'type'] == 'join'),
                  ['start_id', 'end_id','type', 'stored_procedure','cte_level', 'path_index']].to_dict('records')
sub_dict
# Out:
# [{'start_id': 'if_063',
#   'end_id': 'df_003',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'style'},
#  {'start_id': 'if_063',
#   'end_id': 'df_012',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'season'},
#  {'start_id': 'if_214',
#   'end_id': 'df_023',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_224',
#   'end_id': 'df_023',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_214',
#   'end_id': 'df_028',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_name'},
#  {'start_id': 'if_215',
#   'end_id': 'df_028',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vendor_name'},
#  {'start_id': 'if_140',
#   'end_id': 'df_029',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'factory_name'},
#  {'start_id': 'if_149',
#   'end_id': 'df_029',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'factory_name'},
#  {'start_id': 'if_148',
#   'end_id': 'df_029',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'factory_name'},
#  {'start_id': 'if_143',
#   'end_id': 'df_029',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'factory_name'},
#  {'start_id': 'if_063',
#   'end_id': 'df_055',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'po_season'},
#  {'start_id': 'if_063',
#   'end_id': 'df_069',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'latest_confirmed_production_end_date'},
#  {'start_id': 'if_030',
#   'end_id': 'df_104',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'dc_name'},
#  {'start_id': 'if_199',
#   'end_id': 'df_104',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'dc_name'},
#  {'start_id': 'if_202',
#   'end_id': 'df_105',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'destination_country'},
#  {'start_id': 'if_030',
#   'end_id': 'df_105',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'destination_country'},
#  {'start_id': 'if_199',
#   'end_id': 'df_105',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'destination_country'},
#  {'start_id': 'if_126',
#   'end_id': 'df_109',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'actual_ship_date'},
#  {'start_id': 'if_127',
#   'end_id': 'df_109',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'actual_ship_date'},
#  {'start_id': 'if_133',
#   'end_id': 'df_110',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'first_actual_ship_date'},
#  {'start_id': 'if_128',
#   'end_id': 'df_110',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'first_actual_ship_date'},
#  {'start_id': 'if_127',
#   'end_id': 'df_110',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'first_actual_ship_date'},
#  {'start_id': 'if_127',
#   'end_id': 'df_111',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'shipment_closed_by'},
#  {'start_id': 'if_126',
#   'end_id': 'df_111',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'shipment_closed_by'},
#  {'start_id': 'if_173',
#   'end_id': 'df_112',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'hts_product_category'},
#  {'start_id': 'if_173',
#   'end_id': 'df_113',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'hts_product_type'},
#  {'start_id': 'if_182',
#   'end_id': 'df_114',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'costing_season'},
#  {'start_id': 'if_177',
#   'end_id': 'df_114',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'costing_season'},
#  {'start_id': 'if_181',
#   'end_id': 'df_114',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'costing_season'},
#  {'start_id': 'if_179',
#   'end_id': 'df_114',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'costing_season'},
#  {'start_id': 'if_180',
#   'end_id': 'df_114',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'costing_season'},
#  {'start_id': 'if_063',
#   'end_id': 'df_120',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'payment_terms '},
#  {'start_id': 'if_066',
#   'end_id': 'df_120',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'payment_terms '},
#  {'start_id': 'if_009',
#   'end_id': 'df_121',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vf_fiscal_year_original_crd'},
#  {'start_id': 'if_009',
#   'end_id': 'df_122',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'vf_fiscal_year_month_original_crd'},
#  {'start_id': 'if_006',
#   'end_id': 'df_123',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_006',
#   'end_id': 'df_123',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_006',
#   'end_id': 'df_123',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_006',
#   'end_id': 'df_123',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_008',
#   'end_id': 'df_123',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_008',
#   'end_id': 'df_123',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_008',
#   'end_id': 'df_123',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_003',
#   'end_id': 'df_123',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_005',
#   'end_id': 'df_123',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_005',
#   'end_id': 'df_123',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_005',
#   'end_id': 'df_123',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_056',
#   'end_id': 'df_124',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'preferential_duty_rate '},
#  {'start_id': 'if_055',
#   'end_id': 'df_124',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'preferential_duty_rate '},
#  {'start_id': 'if_057',
#   'end_id': 'df_124',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'preferential_duty_rate '},
#  {'start_id': 'if_159',
#   'end_id': 'df_125',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'cbm_pc_brand_cat '},
#  {'start_id': 'if_198',
#   'end_id': 'df_126',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'freight_cost '},
#  {'start_id': 'if_163',
#   'end_id': 'df_126',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'freight_cost '},
#  {'start_id': 'if_160',
#   'end_id': 'df_126',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'freight_cost '},
#  {'start_id': 'if_161',
#   'end_id': 'df_126',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'first',
#   'path_index': 'freight_cost '}]

# %%
# (n:FIELD)-[r:CALCULATED_TO]-(n:FIELD) join from
gds.run_cypher('''
    UNWIND $relMaps AS relMap
    WITH relMap.start_id AS start_Id,
        relMap.end_id AS end_Id,
        relMap.stored_procedure AS stored_procedure,
        relMap.cte_level AS cte_level,
        relMap.path_index AS path_index
    MATCH(n1:IntermediateField {intfieldId: start_Id})
    MATCH(n2:DestinationField {destfieldId: end_Id})
    MERGE(n2)-[r:JOIN_FROM {stored_procedure: stored_procedure, cte_level: cte_level}]->(n1)
    ON CREATE SET r.pathIndex = path_index
    RETURN count(r)
''', params={'relMaps':sub_dict})
# Out:
#    count(r)
# 0        54

# %%
#ingest extract field destination -> join -> inter
sub_dict = df.loc[(df[f'start_id'].str.contains('df')) & (df[f'end_id'].str.contains('if')) & (df[f'type'] == 'join'),
                  ['start_id', 'end_id','type', 'stored_procedure','cte_level', 'path_index']].to_dict('records')
sub_dict
# Out:
# [{'start_id': 'df_002',
#   'end_id': 'if_207',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'certified_pocut_flag'},
#  {'start_id': 'df_002',
#   'end_id': 'if_207',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'certprintdate'},
#  {'start_id': 'df_082',
#   'end_id': 'if_001',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'df_051',
#   'end_id': 'if_001',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'df_001',
#   'end_id': 'if_001',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'df_105',
#   'end_id': 'if_001',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'df_119',
#   'end_id': 'if_001',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'fob_duties_rate'}]

# %%
# (n:FIELD)-[r:CALCULATED_TO]-(n:FIELD) join from
gds.run_cypher('''
    UNWIND $relMaps AS relMap
    WITH relMap.start_id AS start_Id,
        relMap.end_id AS end_Id,
        relMap.stored_procedure AS stored_procedure,
        relMap.cte_level AS cte_level,
        relMap.path_index AS path_index
    MATCH(n1:DestinationField {destfieldId: start_Id})
    MATCH(n2:IntermediateField {intfieldId: end_Id})
    MERGE(n2)-[r:JOIN_FROM {stored_procedure: stored_procedure, cte_level: cte_level}]->(n1)
    ON CREATE SET r.pathIndex = path_index
    RETURN count(r)
''', params={'relMaps':sub_dict})
# Out:
#    count(r)
# 0         7

# %%
#ingest extract field destination -> join -> inter
sub_dict = df.loc[(df[f'start_id'].str.contains('if')) & (df[f'end_id'].str.contains('if')) & (df[f'type'] == 'join'),
                  ['start_id', 'end_id','type', 'stored_procedure','cte_level', 'path_index']].to_dict('records')
sub_dict
# Out:
# [{'start_id': 'if_263',
#   'end_id': 'if_221',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_ffc'},
#  {'start_id': 'if_032',
#   'end_id': 'if_221',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_ffc'},
#  {'start_id': 'if_281',
#   'end_id': 'if_221',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_ffc'},
#  {'start_id': 'if_033',
#   'end_id': 'if_221',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_ffc'},
#  {'start_id': 'if_031',
#   'end_id': 'if_221',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_ffc'},
#  {'start_id': 'if_263',
#   'end_id': 'if_223',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_032',
#   'end_id': 'if_223',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_281',
#   'end_id': 'if_223',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_033',
#   'end_id': 'if_223',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_031',
#   'end_id': 'if_223',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'vendor_group_name'},
#  {'start_id': 'if_038',
#   'end_id': 'if_140',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'factory_name'},
#  {'start_id': 'if_046',
#   'end_id': 'if_149',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'factory_name'},
#  {'start_id': 'if_040',
#   'end_id': 'if_143',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'factory_name'},
#  {'start_id': 'if_170',
#   'end_id': 'if_207',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'certified_pocut_flag'},
#  {'start_id': 'if_170',
#   'end_id': 'if_207',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'certprintdate'},
#  {'start_id': 'if_199',
#   'end_id': 'if_007',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_053',
#   'end_id': 'if_007',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_201',
#   'end_id': 'if_007',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_199',
#   'end_id': 'if_006',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_053',
#   'end_id': 'if_006',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_201',
#   'end_id': 'if_006',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_199',
#   'end_id': 'if_008',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_053',
#   'end_id': 'if_008',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_053',
#   'end_id': 'if_004',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_199',
#   'end_id': 'if_004',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_199',
#   'end_id': 'if_005',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_053',
#   'end_id': 'if_005',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'second',
#   'path_index': 'standard_duty_rate '},
#  {'start_id': 'if_126',
#   'end_id': 'if_210',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'shipment_status'},
#  {'start_id': 'if_127',
#   'end_id': 'if_210',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'shipment_status'},
#  {'start_id': 'if_126',
#   'end_id': 'if_211',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'fr_release'},
#  {'start_id': 'if_127',
#   'end_id': 'if_211',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'fr_release'},
#  {'start_id': 'if_126',
#   'end_id': 'if_209',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'shipment_id_closing_date'},
#  {'start_id': 'if_127',
#   'end_id': 'if_209',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'shipment_id_closing_date'},
#  {'start_id': 'if_126',
#   'end_id': 'if_208',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'actual_ship_date'},
#  {'start_id': 'if_127',
#   'end_id': 'if_208',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'actual_ship_date'},
#  {'start_id': 'if_126',
#   'end_id': 'if_208',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'first_actual_ship_date'},
#  {'start_id': 'if_127',
#   'end_id': 'if_208',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'first_actual_ship_date'},
#  {'start_id': 'if_157',
#   'end_id': 'if_001',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_155',
#   'end_id': 'if_001',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_153',
#   'end_id': 'if_001',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_154',
#   'end_id': 'if_001',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_001',
#   'end_id': 'if_001',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'fob_duties_rate'},
#  {'start_id': 'if_156',
#   'end_id': 'if_001',
#   'type': 'join',
#   'stored_procedure': 'sp_otp_po_cut_level',
#   'cte_level': 'third',
#   'path_index': 'fob_duties_rate'}]

# %%
# (n:FIELD)-[r:CALCULATED_TO]-(n:FIELD) join from
gds.run_cypher('''
    UNWIND $relMaps AS relMap
    WITH relMap.start_id AS start_Id,
        relMap.end_id AS end_Id,
        relMap.stored_procedure AS stored_procedure,
        relMap.cte_level AS cte_level,
        relMap.path_index AS path_index
    MATCH(n1:IntermediateField {intfieldId: start_Id})
    MATCH(n2:IntermediateField {intfieldId: end_Id})
    MERGE(n2)-[r:JOIN_FROM {stored_procedure: stored_procedure, cte_level: cte_level}]->(n1)
    ON CREATE SET r.pathIndex = path_index
    RETURN count(r)
''', params={'relMaps':sub_dict})
# Out:
#    count(r)
# 0        43

# %%
#ingest extract field dest -> join -> dest
sub_dict = df.loc[(df[f'start_id'].str.contains('df')) & (df[f'end_id'].str.contains('df')) & (df[f'type'] == 'join'),
                  ['start_id', 'end_id','type', 'stored_procedure','cte_level', 'path_index']].to_dict('records')

# (n:FIELD)-[r:CALCULATED_TO]-(n:FIELD) join from
gds.run_cypher('''
    UNWIND $relMaps AS relMap
    WITH relMap.start_id AS start_Id,
        relMap.end_id AS end_Id,
        relMap.stored_procedure AS stored_procedure,
        relMap.cte_level AS cte_level,
        relMap.path_index AS path_index
    MATCH(n1:DestinationField {destfieldId: start_Id})
    MATCH(n2:DestinationField {destfieldId: end_Id})
    MERGE(n2)-[r:JOIN_FROM {stored_procedure: stored_procedure, cte_level: cte_level}]->(n1)
    ON CREATE SET r.pathIndex = path_index
    RETURN count(r)
''', params={'relMaps':sub_dict})
# Out:
#    count(r)
# 0        45
