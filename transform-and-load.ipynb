# %% [markdown]
# # Cargo 2000 Case Study Graph Import
#
# <img src="img/logistics-diagram.png" alt="summary" width="1000"/>

# %%
import pandas as pd
from faker import Faker

# %% [markdown]
# ## Connect ot Graph Data Science

# %%
from graphdatascience import GraphDataScience

# Use Neo4j URI and credentials according to your setup
gds = GraphDataScience('neo4j://localhost', auth=('neo4j', 'neopharm'))

# %% [markdown]
# ## Staging for ETL
# 1. Clear the graph of any existing data and indexes
# 2. read the source data
# 3. create helper functions
# 4. Set Neo4j Indexes

# %%
# Clear last graph - All data and schema attributes
gds.run_cypher('MATCH(n) DETACH DELETE n')
gds.run_cypher('CALL apoc.schema.assert({},{})')
# Out:
# Empty DataFrame
# Columns: [label, key, keys, unique, action]
# Index: []

# %%
df = pd.read_csv('https://s-cube-network.eu/c2k-files/c2k_data_comma.csv', dtype=str)

# %%
LEGS = [1,2,3]
SEGMENTS = [1,2,3]
GOINGS = ['i','o']
SERVICES = ['rcs', 'dlv']

# %%
# Helper functions
def get_last_i1_rcf_place(row):
    for s in [3,2,1]:
        if row[f'i1_rcf_{s}_place'] != '?':
            return row[f'i1_rcf_{s}_place']
    raise Exception("cannot find last rcf place")

def get_last_outbound_rcf_place(row):
    for s in [3,2,1]:
        if row[f'o_rcf_{s}_place'] != '?':
            return row[f'o_rcf_{s}_place']
    raise Exception("cannot find last rcf place")

def get_path_indexes(row):
    res = {'o': []}
    end = str(get_last_outbound_rcf_place(row))
    for i in LEGS:
        start = str(row[f'i{i}_dep_1_place'])
        if start != '?':
            ind = start + '-' + end
            res[f'i{i}'] = ind
            res['o'].append(ind)
    return res

# %%
# assign last inbound & outbound rcf place
df['last_o_rcf_place'] = df.apply(get_last_outbound_rcf_place, axis =1)
df['last_i_rcf_place'] = df.apply(get_last_i1_rcf_place, axis =1)
# assign path index
df['path_indexes'] = df.apply(get_path_indexes, axis=1)
df
# Out:
#         nr i1_legid i1_rcs_p i1_rcs_e i1_dep_1_p i1_dep_1_e i1_dep_1_place  \
# 0        0     5182      199      218        210        215            609
# 1        1     6523      844      584         90        297            700
# 2        2     5878     4380     4119         90        280            456
# 3        3     1275      759      169        240        777            173
# 4        4     8117     1597     1485        150        241            411
# ...    ...      ...      ...      ...        ...        ...            ...
# 3938  3939     4225      122       19        240        278            815
# 3939  3940    14017     2028      413        270       1825            605
# 3940  3941     4660     1356      178        240       1359            815
# 3941  3942     6472     2692     1856         90        867            700
# 3942   NaN      NaN      NaN      NaN        NaN        NaN            NaN
#
#      i1_rcf_1_p i1_rcf_1_e i1_rcf_1_place  ... o_rcf_3_p o_rcf_3_e  \
# 0           935        736            256  ...         ?         ?
# 1          1935       1415            431  ...         ?         ?
# 2           905        547            700  ...         ?         ?
# 3           340        577            349  ...         ?         ?
# 4           585        612            128  ...         ?         ?
# ...         ...        ...            ...  ...       ...       ...
# 3938        830        761            174  ...         ?         ?
# 3939       2610       2535            349  ...         ?         ?
# 3940        760        716            609  ...         ?         ?
# 3941       1060       1049            113  ...         ?         ?
# 3942        NaN        NaN            NaN  ...       NaN       NaN
#
#      o_rcf_3_place o_dlv_p o_dlv_e o_hops legs last_o_rcf_place  \
# 0                ?     780     434      1    2              411
# 1                ?    3870     445      1    2              256
# 2                ?     550    1520      1    1              349
# 3                ?    3780     159      1    1              700
# 4                ?    4140    4797      2    1              411
# ...            ...     ...     ...    ...  ...              ...
# 3938             ?    1665    1300      2    3              293
# 3939             ?    3780     807      2    1              113
# 3940             ?    5100    4381      2    1              737
# 3941             ?    3780     945      2    2              635
# 3942           NaN     NaN     NaN    NaN  NaN              NaN
#
#      last_i_rcf_place                                       path_indexes
# 0                 256  {'o': ['609-411', '431-411'], 'i1': '609-411',...
# 1                 431  {'o': ['700-256', '257-256'], 'i1': '700-256',...
# 2                 700                {'o': ['456-349'], 'i1': '456-349'}
# 3                 671                {'o': ['173-700'], 'i1': '173-700'}
# 4                 166                {'o': ['411-411'], 'i1': '411-411'}
# ...               ...                                                ...
# 3938              174  {'o': ['815-293', '671-293', '671-293'], 'i1':...
# 3939              597                {'o': ['605-113'], 'i1': '605-113'}
# 3940              609                {'o': ['815-737'], 'i1': '815-737'}
# 3941              113  {'o': ['700-635', '456-635'], 'i1': '700-635',...
# 3942              NaN  {'o': ['nan-nan', 'nan-nan', 'nan-nan'], 'i1':...
#
# [3943 rows x 101 columns]

# %%
df['path_indexes']
# Out:
# 0       {'o': ['609-411', '431-411'], 'i1': '609-411',...
# 1       {'o': ['700-256', '257-256'], 'i1': '700-256',...
# 2                     {'o': ['456-349'], 'i1': '456-349'}
# 3                     {'o': ['173-700'], 'i1': '173-700'}
# 4                     {'o': ['411-411'], 'i1': '411-411'}
#                               ...
# 3938    {'o': ['815-293', '671-293', '671-293'], 'i1':...
# 3939                  {'o': ['605-113'], 'i1': '605-113'}
# 3940                  {'o': ['815-737'], 'i1': '815-737'}
# 3941    {'o': ['700-635', '456-635'], 'i1': '700-635',...
# 3942    {'o': ['nan-nan', 'nan-nan', 'nan-nan'], 'i1':...
# Name: path_indexes, Length: 3943, dtype: object

# %%
# Create Indexes
gds.run_cypher('CREATE CONSTRAINT airport_unique IF NOT EXISTS FOR (n:Airport) REQUIRE n.airportId  IS UNIQUE')

gds.run_cypher('CREATE CONSTRAINT airport_entry_unique IF NOT EXISTS FOR (n:EntryPoint) REQUIRE n.airportId  IS UNIQUE')

gds.run_cypher('CREATE INDEX check_in_shipment_id IF NOT EXISTS FOR ()-[r:RECEPTION]-() ON (r.shipmentId)')
gds.run_cypher('CREATE INDEX check_in_path IF NOT EXISTS FOR ()-[r:RECEPTION]-() ON (r.pathIndex)')
gds.run_cypher('CREATE CONSTRAINT airport_departure_checkpoint_unique IF NOT EXISTS FOR (n:DepartureWarehouse) REQUIRE n.airportId  IS UNIQUE')

gds.run_cypher('CREATE INDEX confirm_shipment_id IF NOT EXISTS FOR ()-[r:DEPARTURE]-() ON (r.shipmentId)')
gds.run_cypher('CREATE INDEX confirm_path IF NOT EXISTS FOR ()-[r:DEPARTURE]-() ON (r.pathIndex)')
gds.run_cypher('CREATE CONSTRAINT airport_departure_unique IF NOT EXISTS FOR (n:DeparturePoint) REQUIRE n.airportId  IS UNIQUE')

gds.run_cypher('CREATE INDEX depart_shipment_id IF NOT EXISTS FOR ()-[r:TRANSPORT]-() ON (r.shipmentId)')
gds.run_cypher('CREATE INDEX depart_path IF NOT EXISTS FOR ()-[r:TRANSPORT]-() ON (r.pathIndex)')
gds.run_cypher('CREATE CONSTRAINT airport_arrival_unique IF NOT EXISTS FOR (n:ArrivalWarehouse) REQUIRE n.airportId  IS UNIQUE')

gds.run_cypher('CREATE INDEX deliver_shipment_id IF NOT EXISTS FOR ()-[r:DELIVERY]-() ON (r.shipmentId)')
gds.run_cypher('CREATE INDEX deliver_path IF NOT EXISTS FOR ()-[r:DELIVERY]-() ON (r.pathIndex)')
gds.run_cypher('CREATE CONSTRAINT airport_destination_unique  IF NOT EXISTS FOR (n:Destination) REQUIRE n.airportId  IS UNIQUE')
gds.run_cypher('CREATE CONSTRAINT airport_transfer_unique  IF NOT EXISTS FOR (n:TransferPoint) REQUIRE n.airportId  IS UNIQUE')

gds.run_cypher('CREATE INDEX transfer_shipment_id IF NOT EXISTS FOR ()-[r:TRANSFER]-() ON (r.shipmentId)')
gds.run_cypher('CREATE INDEX transfer_path IF NOT EXISTS FOR ()-[r:TRANSFER]-() ON (r.pathIndex)')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Ingest Nodes
# Nodes will consist of Airports and freight forwarding checkpoints

# %%
# Load nodes and draw location at relationships
cols = df.columns.tolist()

airport_ids = set()
for col in cols:
    if 'place' in col:
        airport_ids.update([int(i) for i in df.loc[(df[col] != '?') & (df[col].notna()), col].unique().tolist()])

# Creating Names for the airports will help with human readability
Faker.seed(0)
fake = Faker()
def single_name_city():
   n = fake.city()
   while ' ' in n: # multi word names are a bit of a mouthful
       n = fake.city()
   return n

airports = [{'id':airport_id , 'name':single_name_city()} for airport_id in airport_ids]

# %%
airports
# Out:
# [{'id': 514, 'name': 'Changchester'},
#  {'id': 515, 'name': 'Hullport'},
#  {'id': 520, 'name': 'Howardborough'},
#  {'id': 524, 'name': 'Ramoshaven'},
#  {'id': 527, 'name': 'Bryanside'},
#  {'id': 528, 'name': 'Davismouth'},
#  {'id': 530, 'name': 'Rodriguezside'},
#  {'id': 535, 'name': 'Jasmineside'},
#  {'id': 538, 'name': 'Lisaside'},
#  {'id': 543, 'name': 'Seanfurt'},
#  {'id': 548, 'name': 'Barbaraport'},
#  {'id': 550, 'name': 'Jonesberg'},
#  {'id': 555, 'name': 'Masseyhaven'},
#  {'id': 556, 'name': 'Aimeebury'},
#  {'id': 561, 'name': 'Rileymouth'},
#  {'id': 563, 'name': 'Kellerstad'},
#  {'id': 567, 'name': 'Meganbury'},
#  {'id': 571, 'name': 'Lauramouth'},
#  {'id': 575, 'name': 'Cabreraville'},
#  {'id': 576, 'name': 'Chadland'},
#  {'id': 579, 'name': 'Michaelburgh'},
#  {'id': 580, 'name': 'Gonzalezstad'},
#  {'id': 583, 'name': 'Masseyshire'},
#  {'id': 584, 'name': 'Alyssaville'},
#  {'id': 588, 'name': 'Wadetown'},
#  {'id': 593, 'name': 'Maldonadoshire'},
#  {'id': 594, 'name': 'Deborahfurt'},
#  {'id': 597, 'name': 'Erictown'},
#  {'id': 602, 'name': 'Harmonmouth'},
#  {'id': 603, 'name': 'Bellport'},
#  {'id': 605, 'name': 'Brittanyberg'},
#  {'id': 609, 'name': 'Paulchester'},
#  {'id': 610, 'name': 'Grayshire'},
#  {'id': 100, 'name': 'Johnsonshire'},
#  {'id': 101, 'name': 'Bartonton'},
#  {'id': 614, 'name': 'Odonnelltown'},
#  {'id': 103, 'name': 'Herringchester'},
#  {'id': 102, 'name': 'Aarontown'},
#  {'id': 618, 'name': 'Burtontown'},
#  {'id': 108, 'name': 'Robinville'},
#  {'id': 620, 'name': 'Dennishaven'},
#  {'id': 622, 'name': 'Darinberg'},
#  {'id': 112, 'name': 'Melissaton'},
#  {'id': 113, 'name': 'Staceyshire'},
#  {'id': 626, 'name': 'Bowmanstad'},
#  {'id': 628, 'name': 'Alanberg'},
#  {'id': 117, 'name': 'Mathewstad'},
#  {'id': 118, 'name': 'Michaelside'},
#  {'id': 631, 'name': 'Robertville'},
#  {'id': 635, 'name': 'Wellsmouth'},
#  {'id': 123, 'name': 'Johnsonmouth'},
#  {'id': 127, 'name': 'Drakeland'},
#  {'id': 128, 'name': 'Shanefort'},
#  {'id': 641, 'name': 'Goodwinborough'},
#  {'id': 129, 'name': 'Hernandezfurt'},
#  {'id': 643, 'name': 'Richfort'},
#  {'id': 640, 'name': 'Marthafort'},
#  {'id': 134, 'name': 'Lisaton'},
#  {'id': 647, 'name': 'Jenniferfort'},
#  {'id': 136, 'name': 'Schmitthaven'},
#  {'id': 649, 'name': 'Santanahaven'},
#  {'id': 140, 'name': 'Amandachester'},
#  {'id': 654, 'name': 'Brucefurt'},
#  {'id': 144, 'name': 'Williamview'},
#  {'id': 658, 'name': 'Cameronview'},
#  {'id': 148, 'name': 'Kendrafurt'},
#  {'id': 149, 'name': 'Brownberg'},
#  {'id': 662, 'name': 'Brianton'},
#  {'id': 663, 'name': 'Butlerfort'},
#  {'id': 151, 'name': 'Johnsonmouth'},
#  {'id': 153, 'name': 'Ellisville'},
#  {'id': 152, 'name': 'Osbornetown'},
#  {'id': 667, 'name': 'Rodriguezton'},
#  {'id': 154, 'name': 'Mendezmouth'},
#  {'id': 671, 'name': 'Scotttown'},
#  {'id': 159, 'name': 'Hunterville'},
#  {'id': 673, 'name': 'Livingstonville'},
#  {'id': 162, 'name': 'Brownchester'},
#  {'id': 166, 'name': 'Jordanchester'},
#  {'id': 678, 'name': 'Christianland'},
#  {'id': 680, 'name': 'Gregorybury'},
#  {'id': 169, 'name': 'Chadberg'},
#  {'id': 173, 'name': 'Jasmineview'},
#  {'id': 174, 'name': 'Matthewport'},
#  {'id': 685, 'name': 'Sharonside'},
#  {'id': 687, 'name': 'Jackland'},
#  {'id': 690, 'name': 'Hurstberg'},
#  {'id': 179, 'name': 'Robertton'},
#  {'id': 691, 'name': 'Andreaberg'},
#  {'id': 178, 'name': 'Evansstad'},
#  {'id': 694, 'name': 'Scottstad'},
#  {'id': 695, 'name': 'Stephanieland'},
#  {'id': 184, 'name': 'Hebertburgh'},
#  {'id': 698, 'name': 'Reynoldsbury'},
#  {'id': 187, 'name': 'Petersonhaven'},
#  {'id': 700, 'name': 'Davisfort'},
#  {'id': 699, 'name': 'Crystaltown'},
#  {'id': 192, 'name': 'Wallaceview'},
#  {'id': 704, 'name': 'Justinborough'},
#  {'id': 706, 'name': 'Amandaville'},
#  {'id': 196, 'name': 'Callahanport'},
#  {'id': 710, 'name': 'Figueroaview'},
#  {'id': 711, 'name': 'Scottshire'},
#  {'id': 201, 'name': 'Crystalchester'},
#  {'id': 714, 'name': 'Trevorton'},
#  {'id': 206, 'name': 'Evansfort'},
#  {'id': 718, 'name': 'Myerstown'},
#  {'id': 721, 'name': 'Morganport'},
#  {'id': 722, 'name': 'Jameschester'},
#  {'id': 211, 'name': 'Moranfurt'},
#  {'id': 727, 'name': 'Hernandezberg'},
#  {'id': 216, 'name': 'Davidburgh'},
#  {'id': 732, 'name': 'Baileyfurt'},
#  {'id': 221, 'name': 'Romanfurt'},
#  {'id': 734, 'name': 'Johnsonland'},
#  {'id': 737, 'name': 'Robertton'},
#  {'id': 226, 'name': 'Carpenterfort'},
#  {'id': 228, 'name': 'Janetborough'},
#  {'id': 742, 'name': 'Josephton'},
#  {'id': 233, 'name': 'Amandamouth'},
#  {'id': 746, 'name': 'Anthonyton'},
#  {'id': 236, 'name': 'Jacobborough'},
#  {'id': 749, 'name': 'Emilyport'},
#  {'id': 750, 'name': 'Zacharyfurt'},
#  {'id': 238, 'name': 'Timothybury'},
#  {'id': 752, 'name': 'Alexanderland'},
#  {'id': 753, 'name': 'Hensonborough'},
#  {'id': 240, 'name': 'Salazarchester'},
#  {'id': 243, 'name': 'Williamsburgh'},
#  {'id': 748, 'name': 'Sarahmouth'},
#  {'id': 245, 'name': 'Rodriguezport'},
#  {'id': 757, 'name': 'Palmermouth'},
#  {'id': 247, 'name': 'Josephtown'},
#  {'id': 761, 'name': 'Jeffreybury'},
#  {'id': 252, 'name': 'Brandiberg'},
#  {'id': 766, 'name': 'Tracyport'},
#  {'id': 256, 'name': 'Lambfort'},
#  {'id': 257, 'name': 'Janetland'},
#  {'id': 770, 'name': 'Derrickfurt'},
#  {'id': 771, 'name': 'Patrickton'},
#  {'id': 261, 'name': 'Carlton'},
#  {'id': 262, 'name': 'Teresachester'},
#  {'id': 774, 'name': 'Jessicachester'},
#  {'id': 265, 'name': 'Smithview'},
#  {'id': 778, 'name': 'Maloneshire'},
#  {'id': 270, 'name': 'Davisport'},
#  {'id': 783, 'name': 'Francisfurt'},
#  {'id': 274, 'name': 'Josephfort'},
#  {'id': 787, 'name': 'Smithhaven'},
#  {'id': 276, 'name': 'Andreaton'},
#  {'id': 789, 'name': 'Sarahton'},
#  {'id': 790, 'name': 'Fosterville'},
#  {'id': 275, 'name': 'Reedton'},
#  {'id': 786, 'name': 'Erinshire'},
#  {'id': 281, 'name': 'Wandaborough'},
#  {'id': 794, 'name': 'Paulview'},
#  {'id': 798, 'name': 'Lindabury'},
#  {'id': 286, 'name': 'Franciscoberg'},
#  {'id': 800, 'name': 'Meghantown'},
#  {'id': 287, 'name': 'Kellyport'},
#  {'id': 290, 'name': 'Troyfurt'},
#  {'id': 805, 'name': 'Archertown'},
#  {'id': 293, 'name': 'Browningview'},
#  {'id': 295, 'name': 'Ramirezburgh'},
#  {'id': 296, 'name': 'Fischerview'},
#  {'id': 809, 'name': 'Justinchester'},
#  {'id': 299, 'name': 'Sophiaside'},
#  {'id': 812, 'name': 'Veronicaborough'},
#  {'id': 815, 'name': 'Moodytown'},
#  {'id': 304, 'name': 'Wardton'},
#  {'id': 308, 'name': 'Fieldsbury'},
#  {'id': 313, 'name': 'Smithbury'},
#  {'id': 316, 'name': 'Millermouth'},
#  {'id': 317, 'name': 'Waltersview'},
#  {'id': 320, 'name': 'Samuelstad'},
#  {'id': 325, 'name': 'Christophertown'},
#  {'id': 326, 'name': 'Smithview'},
#  {'id': 327, 'name': 'Rowefurt'},
#  {'id': 332, 'name': 'Lynnfurt'},
#  {'id': 335, 'name': 'Mccallberg'},
#  {'id': 339, 'name': 'Adamborough'},
#  {'id': 341, 'name': 'Sarahtown'},
#  {'id': 346, 'name': 'Philipberg'},
#  {'id': 349, 'name': 'Richardberg'},
#  {'id': 353, 'name': 'Thorntonton'},
#  {'id': 356, 'name': 'Kimberlyhaven'},
#  {'id': 361, 'name': 'Lutzberg'},
#  {'id': 366, 'name': 'Tranton'},
#  {'id': 371, 'name': 'Lisaland'},
#  {'id': 372, 'name': 'Aaronland'},
#  {'id': 377, 'name': 'Rogersfurt'},
#  {'id': 382, 'name': 'Vanessaville'},
#  {'id': 386, 'name': 'Normaborough'},
#  {'id': 388, 'name': 'Buckburgh'},
#  {'id': 391, 'name': 'Samanthaland'},
#  {'id': 395, 'name': 'Brownstad'},
#  {'id': 398, 'name': 'Emilyshire'},
#  {'id': 400, 'name': 'Gutierreztown'},
#  {'id': 403, 'name': 'Langborough'},
#  {'id': 407, 'name': 'Brownville'},
#  {'id': 409, 'name': 'Gilberttown'},
#  {'id': 411, 'name': 'Stephenside'},
#  {'id': 413, 'name': 'Alvarezton'},
#  {'id': 416, 'name': 'Gibbsview'},
#  {'id': 420, 'name': 'Michaelville'},
#  {'id': 422, 'name': 'Donaldsonberg'},
#  {'id': 423, 'name': 'Susantown'},
#  {'id': 426, 'name': 'Morganside'},
#  {'id': 431, 'name': 'Sonyafort'},
#  {'id': 436, 'name': 'Williamsbury'},
#  {'id': 441, 'name': 'Markbury'},
#  {'id': 445, 'name': 'Jeremychester'},
#  {'id': 448, 'name': 'Coxshire'},
#  {'id': 451, 'name': 'Higginsburgh'},
#  {'id': 452, 'name': 'Williamton'},
#  {'id': 455, 'name': 'Frenchchester'},
#  {'id': 456, 'name': 'Bradleymouth'},
#  {'id': 461, 'name': 'Tammychester'},
#  {'id': 464, 'name': 'Sanchezfurt'},
#  {'id': 468, 'name': 'Sandersshire'},
#  {'id': 470, 'name': 'Amyfort'},
#  {'id': 472, 'name': 'Michellefurt'},
#  {'id': 476, 'name': 'Simonfurt'},
#  {'id': 477, 'name': 'Middletonmouth'},
#  {'id': 481, 'name': 'Martinmouth'},
#  {'id': 482, 'name': 'Jenkinsshire'},
#  {'id': 484, 'name': 'Kathleenville'},
#  {'id': 485, 'name': 'Michaelstad'},
#  {'id': 488, 'name': 'Mccoyton'},
#  {'id': 490, 'name': 'Kennethton'},
#  {'id': 493, 'name': 'Andreaton'},
#  {'id': 495, 'name': 'Adamsborough'},
#  {'id': 500, 'name': 'Dennisville'},
#  {'id': 502, 'name': 'Gabrielchester'},
#  {'id': 504, 'name': 'Fordland'},
#  {'id': 508, 'name': 'Gardnerside'},
#  {'id': 511, 'name': 'Jennifermouth'}]

# %%
# Load nodes and draw location at relationships
gds.run_cypher('''
    UNWIND $airports AS a
    WITH a.id AS airportId, a.name AS name
    MERGE(n0:Airport {airportId: airportId}) SET n0.name=name
    MERGE(n1:EntryPoint {airportId: airportId}) SET n1.name=name
    MERGE(n2:DepartureWarehouse{airportId: airportId}) SET n2.name=name
    MERGE(n3:DeparturePoint {airportId: airportId}) SET n3.name=name
    MERGE(n4:ArrivalWarehouse {airportId: airportId}) SET n4.name=name
    MERGE(n5:TransferPoint {airportId: airportId}) SET n5.name=name
    MERGE(n6:Destination {airportId: airportId}) SET n6.name=name

    MERGE(n0)<-[:LOCATED_AT]-(n1)
    MERGE(n0)<-[:LOCATED_AT]-(n2)
    MERGE(n0)<-[:LOCATED_AT]-(n3)
    MERGE(n0)<-[:LOCATED_AT]-(n4)
    MERGE(n0)<-[:LOCATED_AT]-(n5)
    MERGE(n0)<-[:LOCATED_AT]-(n6)
    RETURN count(n0), count(n1), count(n2), count(n3), count(n4), count(n5), count(n6)
    ''', params={'airports':airports})
# Out:
#    count(n0)  count(n1)  count(n2)  count(n3)  count(n4)  count(n5)  count(n6)
# 0        237        237        237        237        237        237        237

# %% [markdown]
# ## Ingest Relationships
# Relationships will consist of the freight forwarding steps as well as links representing connection between transportation segments and transfer between the inbound and output stage of the shipment

# %%
LEGS
# Out:
# [1, 2, 3]

# %%
# (n:EntryPoint)-[r:RECEPTION]-(m:DepartureWarehouse) RCS inbound
for l in LEGS:
    sub_dict = df.loc[(df[f'i{l}_legid'] != '?') & (df[f'i{l}_legid'].notna()),
                      ['nr', f'i{l}_legid', f'i{l}_rcs_p', f'i{l}_rcs_e', f'i{l}_dep_1_place', 'path_indexes']].to_dict('records')
    res = gds.run_cypher(f'''
        UNWIND $relMaps AS relMap
        WITH toInteger(relMap.nr) AS shipmentId,
            toInteger(relMap.i{l}_dep_1_place) AS airportId,
            toInteger(relMap.i{l}_legid) AS legId,
            toInteger(relMap.i{l}_rcs_e) AS effectiveMinutes,
            toInteger(relMap.i{l}_rcs_p) AS plannedMinutes,
            relMap.path_indexes.i{l} AS pathIndex
        MATCH(n1:EntryPoint {{airportId: airportId}})
        MATCH(n2:DepartureWarehouse {{airportId: airportId}})
        MERGE(n1)-[r:RECEPTION {{shipmentId: shipmentId, legId: legId, legNumber: $legNumber}}]->(n2)
        ON CREATE SET r.plannedMinutes=plannedMinutes,
        r.effectiveMinutes=effectiveMinutes,
        r.pathIndex = pathIndex
        RETURN count(r)
    ''', params={'relMaps':sub_dict, 'legNumber':l})
    print(res)
# Out:
#    count(r)
# 0      3942
#    count(r)
# 0      2624
#    count(r)
# 0      1366

# %%
sub_dict = df.loc[(df[f'o_legid'] != '?') & (df[f'o_legid'].notna()),
                  ['nr', 'o_legid', 'o_rcs_p', 'o_rcs_e', 'o_dep_1_place', 'path_indexes']].to_dict('records')
sub_dict
# Out:
# [{'nr': '0',
#   'o_legid': '10121',
#   'o_rcs_p': '9919',
#   'o_rcs_e': '7559',
#   'o_dep_1_place': '256',
#   'path_indexes': {'o': ['609-411', '431-411'],
#    'i1': '609-411',
#    'i2': '431-411'}},
#  {'nr': '1',
#   'o_legid': '626',
#   'o_rcs_p': '3030',
#   'o_rcs_e': '3016',
#   'o_dep_1_place': '431',
#   'path_indexes': {'o': ['700-256', '257-256'],
#    'i1': '700-256',
#    'i2': '257-256'}},
#  {'nr': '2',
#   'o_legid': '12691',
#   'o_rcs_p': '1433',
#   'o_rcs_e': '642',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['456-349'], 'i1': '456-349'}},
#  {'nr': '3',
#   'o_legid': '12932',
#   'o_rcs_p': '3963',
#   'o_rcs_e': '3176',
#   'o_dep_1_place': '671',
#   'path_indexes': {'o': ['173-700'], 'i1': '173-700'}},
#  {'nr': '4',
#   'o_legid': '12805',
#   'o_rcs_p': '152',
#   'o_rcs_e': '179',
#   'o_dep_1_place': '166',
#   'path_indexes': {'o': ['411-411'], 'i1': '411-411'}},
#  {'nr': '5',
#   'o_legid': '6430',
#   'o_rcs_p': '136',
#   'o_rcs_e': '29',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['815-597', '128-597'],
#    'i1': '815-597',
#    'i2': '128-597'}},
#  {'nr': '6',
#   'o_legid': '2544',
#   'o_rcs_p': '329',
#   'o_rcs_e': '81',
#   'o_dep_1_place': '391',
#   'path_indexes': {'o': ['815-281', '815-281', '610-281'],
#    'i1': '815-281',
#    'i2': '815-281',
#    'i3': '610-281'}},
#  {'nr': '7',
#   'o_legid': '6753',
#   'o_rcs_p': '119',
#   'o_rcs_e': '19',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['783-597', '815-597'],
#    'i1': '783-597',
#    'i2': '815-597'}},
#  {'nr': '8',
#   'o_legid': '5570',
#   'o_rcs_p': '933',
#   'o_rcs_e': '1074',
#   'o_dep_1_place': '485',
#   'path_indexes': {'o': ['815-149'], 'i1': '815-149'}},
#  {'nr': '9',
#   'o_legid': '13468',
#   'o_rcs_p': '495',
#   'o_rcs_e': '336',
#   'o_dep_1_place': '555',
#   'path_indexes': {'o': ['690-356'], 'i1': '690-356'}},
#  {'nr': '10',
#   'o_legid': '13961',
#   'o_rcs_p': '1580',
#   'o_rcs_e': '1088',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['281-413', '308-413'],
#    'i1': '281-413',
#    'i2': '308-413'}},
#  {'nr': '11',
#   'o_legid': '11830',
#   'o_rcs_p': '730',
#   'o_rcs_e': '591',
#   'o_dep_1_place': '485',
#   'path_indexes': {'o': ['377-281'], 'i1': '377-281'}},
#  {'nr': '12',
#   'o_legid': '4744',
#   'o_rcs_p': '238',
#   'o_rcs_e': '59',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['281-485', '281-485', '614-485'],
#    'i1': '281-485',
#    'i2': '281-485',
#    'i3': '614-485'}},
#  {'nr': '13',
#   'o_legid': '600',
#   'o_rcs_p': '395',
#   'o_rcs_e': '40',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['445-413', '413-413'],
#    'i1': '445-413',
#    'i2': '413-413'}},
#  {'nr': '14',
#   'o_legid': '3390',
#   'o_rcs_p': '405',
#   'o_rcs_e': '133',
#   'o_dep_1_place': '349',
#   'path_indexes': {'o': ['456-149', '671-149', '468-149'],
#    'i1': '456-149',
#    'i2': '671-149',
#    'i3': '468-149'}},
#  {'nr': '15',
#   'o_legid': '11725',
#   'o_rcs_p': '37994',
#   'o_rcs_e': '36949',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['753-700'], 'i1': '753-700'}},
#  {'nr': '16',
#   'o_legid': '4551',
#   'o_rcs_p': '2931',
#   'o_rcs_e': '2589',
#   'o_dep_1_place': '548',
#   'path_indexes': {'o': ['349-128', '349-128'],
#    'i1': '349-128',
#    'i2': '349-128'}},
#  {'nr': '17',
#   'o_legid': '2421',
#   'o_rcs_p': '927',
#   'o_rcs_e': '390',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['815-411', '485-411'],
#    'i1': '815-411',
#    'i2': '485-411'}},
#  {'nr': '18',
#   'o_legid': '1321',
#   'o_rcs_p': '3180',
#   'o_rcs_e': '1730',
#   'o_dep_1_place': '153',
#   'path_indexes': {'o': ['815-538'], 'i1': '815-538'}},
#  {'nr': '19',
#   'o_legid': '2033',
#   'o_rcs_p': '1317',
#   'o_rcs_e': '1283',
#   'o_dep_1_place': '441',
#   'path_indexes': {'o': ['236-349', '134-349'],
#    'i1': '236-349',
#    'i2': '134-349'}},
#  {'nr': '20',
#   'o_legid': '11277',
#   'o_rcs_p': '606',
#   'o_rcs_e': '52',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['579-409', '579-409'],
#    'i1': '579-409',
#    'i2': '579-409'}},
#  {'nr': '21',
#   'o_legid': '10003',
#   'o_rcs_p': '82',
#   'o_rcs_e': '16',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['391-485'], 'i1': '391-485'}},
#  {'nr': '22',
#   'o_legid': '11117',
#   'o_rcs_p': '139',
#   'o_rcs_e': '34',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['332-403', '614-403', '349-403'],
#    'i1': '332-403',
#    'i2': '614-403',
#    'i3': '349-403'}},
#  {'nr': '23',
#   'o_legid': '9042',
#   'o_rcs_p': '4583',
#   'o_rcs_e': '4312',
#   'o_dep_1_place': '778',
#   'path_indexes': {'o': ['746-757', '349-757'],
#    'i1': '746-757',
#    'i2': '349-757'}},
#  {'nr': '24',
#   'o_legid': '5171',
#   'o_rcs_p': '989',
#   'o_rcs_e': '343',
#   'o_dep_1_place': '391',
#   'path_indexes': {'o': ['815-783', '628-783', '233-783'],
#    'i1': '815-783',
#    'i2': '628-783',
#    'i3': '233-783'}},
#  {'nr': '25',
#   'o_legid': '324',
#   'o_rcs_p': '1233',
#   'o_rcs_e': '380',
#   'o_dep_1_place': '456',
#   'path_indexes': {'o': ['349-667', '128-667', '398-667'],
#    'i1': '349-667',
#    'i2': '128-667',
#    'i3': '398-667'}},
#  {'nr': '26',
#   'o_legid': '8957',
#   'o_rcs_p': '860',
#   'o_rcs_e': '525',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['485-431'], 'i1': '485-431'}},
#  {'nr': '27',
#   'o_legid': '9817',
#   'o_rcs_p': '814',
#   'o_rcs_e': '78',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['476-527'], 'i1': '476-527'}},
#  {'nr': '28',
#   'o_legid': '5820',
#   'o_rcs_p': '2741',
#   'o_rcs_e': '2591',
#   'o_dep_1_place': '413',
#   'path_indexes': {'o': ['349-391', '700-391'],
#    'i1': '349-391',
#    'i2': '700-391'}},
#  {'nr': '29',
#   'o_legid': '3618',
#   'o_rcs_p': '1045',
#   'o_rcs_e': '36',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['753-671'], 'i1': '753-671'}},
#  {'nr': '30',
#   'o_legid': '12166',
#   'o_rcs_p': '1545',
#   'o_rcs_e': '1244',
#   'o_dep_1_place': '809',
#   'path_indexes': {'o': ['815-134', '128-134', '128-134'],
#    'i1': '815-134',
#    'i2': '128-134',
#    'i3': '128-134'}},
#  {'nr': '31',
#   'o_legid': '4319',
#   'o_rcs_p': '114',
#   'o_rcs_e': '31',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['476-752', '476-752'],
#    'i1': '476-752',
#    'i2': '476-752'}},
#  {'nr': '32',
#   'o_legid': '9552',
#   'o_rcs_p': '16955',
#   'o_rcs_e': '16424',
#   'o_dep_1_place': '299',
#   'path_indexes': {'o': ['398-561', '411-561'],
#    'i1': '398-561',
#    'i2': '411-561'}},
#  {'nr': '33',
#   'o_legid': '6793',
#   'o_rcs_p': '1438',
#   'o_rcs_e': '256',
#   'o_dep_1_place': '485',
#   'path_indexes': {'o': ['815-635', '476-635', '128-635'],
#    'i1': '815-635',
#    'i2': '476-635',
#    'i3': '128-635'}},
#  {'nr': '34',
#   'o_legid': '7418',
#   'o_rcs_p': '1290',
#   'o_rcs_e': '355',
#   'o_dep_1_place': '308',
#   'path_indexes': {'o': ['671-256'], 'i1': '671-256'}},
#  {'nr': '35',
#   'o_legid': '13507',
#   'o_rcs_p': '7282',
#   'o_rcs_e': '6225',
#   'o_dep_1_place': '485',
#   'path_indexes': {'o': ['815-700', '134-700'],
#    'i1': '815-700',
#    'i2': '134-700'}},
#  {'nr': '36',
#   'o_legid': '14151',
#   'o_rcs_p': '1315',
#   'o_rcs_e': '929',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['548-206'], 'i1': '548-206'}},
#  {'nr': '37',
#   'o_legid': '5014',
#   'o_rcs_p': '1048',
#   'o_rcs_e': '163',
#   'o_dep_1_place': '597',
#   'path_indexes': {'o': ['700-134', '700-134', '349-134'],
#    'i1': '700-134',
#    'i2': '700-134',
#    'i3': '349-134'}},
#  {'nr': '38',
#   'o_legid': '1206',
#   'o_rcs_p': '4654',
#   'o_rcs_e': '4545',
#   'o_dep_1_place': '556',
#   'path_indexes': {'o': ['597-339', '441-339', '468-339'],
#    'i1': '597-339',
#    'i2': '441-339',
#    'i3': '468-339'}},
#  {'nr': '39',
#   'o_legid': '7066',
#   'o_rcs_p': '2920',
#   'o_rcs_e': '2875',
#   'o_dep_1_place': '371',
#   'path_indexes': {'o': ['555-761', '308-761', '555-761'],
#    'i1': '555-761',
#    'i2': '308-761',
#    'i3': '555-761'}},
#  {'nr': '40',
#   'o_legid': '7655',
#   'o_rcs_p': '390',
#   'o_rcs_e': '104',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['798-678'], 'i1': '798-678'}},
#  {'nr': '41',
#   'o_legid': '13298',
#   'o_rcs_p': '132',
#   'o_rcs_e': '103',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['256-527'], 'i1': '256-527'}},
#  {'nr': '42',
#   'o_legid': '8022',
#   'o_rcs_p': '14735',
#   'o_rcs_e': '14618',
#   'o_dep_1_place': '555',
#   'path_indexes': {'o': ['727-371', '256-371', '690-371'],
#    'i1': '727-371',
#    'i2': '256-371',
#    'i3': '690-371'}},
#  {'nr': '43',
#   'o_legid': '12677',
#   'o_rcs_p': '2974',
#   'o_rcs_e': '1028',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['476-700', '456-700', '548-700'],
#    'i1': '476-700',
#    'i2': '456-700',
#    'i3': '548-700'}},
#  {'nr': '44',
#   'o_legid': '7494',
#   'o_rcs_p': '1540',
#   'o_rcs_e': '1525',
#   'o_dep_1_place': '233',
#   'path_indexes': {'o': ['308-749'], 'i1': '308-749'}},
#  {'nr': '45',
#   'o_legid': '9872',
#   'o_rcs_p': '180',
#   'o_rcs_e': '111',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['281-313'], 'i1': '281-313'}},
#  {'nr': '46',
#   'o_legid': '10223',
#   'o_rcs_p': '1374',
#   'o_rcs_e': '685',
#   'o_dep_1_place': '413',
#   'path_indexes': {'o': ['128-700'], 'i1': '128-700'}},
#  {'nr': '47',
#   'o_legid': '6924',
#   'o_rcs_p': '364',
#   'o_rcs_e': '175',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['485-413', '166-413'],
#    'i1': '485-413',
#    'i2': '166-413'}},
#  {'nr': '48',
#   'o_legid': '7406',
#   'o_rcs_p': '670',
#   'o_rcs_e': '11',
#   'o_dep_1_place': '308',
#   'path_indexes': {'o': ['671-597', '671-597'],
#    'i1': '671-597',
#    'i2': '671-597'}},
#  {'nr': '49',
#   'o_legid': '9408',
#   'o_rcs_p': '43',
#   'o_rcs_e': '21',
#   'o_dep_1_place': '614',
#   'path_indexes': {'o': ['411-815', '815-815', '815-815'],
#    'i1': '411-815',
#    'i2': '815-815',
#    'i3': '815-815'}},
#  {'nr': '50',
#   'o_legid': '6543',
#   'o_rcs_p': '1156',
#   'o_rcs_e': '459',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['431-597', '128-597', '485-597'],
#    'i1': '431-597',
#    'i2': '128-597',
#    'i3': '485-597'}},
#  {'nr': '51',
#   'o_legid': '3255',
#   'o_rcs_p': '14221',
#   'o_rcs_e': '13324',
#   'o_dep_1_place': '256',
#   'path_indexes': {'o': ['431-108'], 'i1': '431-108'}},
#  {'nr': '52',
#   'o_legid': '7155',
#   'o_rcs_p': '379',
#   'o_rcs_e': '62',
#   'o_dep_1_place': '233',
#   'path_indexes': {'o': ['456-398'], 'i1': '456-398'}},
#  {'nr': '53',
#   'o_legid': '10962',
#   'o_rcs_p': '146',
#   'o_rcs_e': '65',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['597-128'], 'i1': '597-128'}},
#  {'nr': '54',
#   'o_legid': '424',
#   'o_rcs_p': '1548',
#   'o_rcs_e': '663',
#   'o_dep_1_place': '476',
#   'path_indexes': {'o': ['663-727', '815-727', '671-727'],
#    'i1': '663-727',
#    'i2': '815-727',
#    'i3': '671-727'}},
#  {'nr': '55',
#   'o_legid': '8732',
#   'o_rcs_p': '930',
#   'o_rcs_e': '870',
#   'o_dep_1_place': '524',
#   'path_indexes': {'o': ['134-695', '815-695', '128-695'],
#    'i1': '134-695',
#    'i2': '815-695',
#    'i3': '128-695'}},
#  {'nr': '56',
#   'o_legid': '6358',
#   'o_rcs_p': '185',
#   'o_rcs_e': '113',
#   'o_dep_1_place': '527',
#   'path_indexes': {'o': ['761-571', '815-571', '815-571'],
#    'i1': '761-571',
#    'i2': '815-571',
#    'i3': '815-571'}},
#  {'nr': '57',
#   'o_legid': '1062',
#   'o_rcs_p': '1028',
#   'o_rcs_e': '451',
#   'o_dep_1_place': '770',
#   'path_indexes': {'o': ['809-361', '798-361', '798-361'],
#    'i1': '809-361',
#    'i2': '798-361',
#    'i3': '798-361'}},
#  {'nr': '58',
#   'o_legid': '6405',
#   'o_rcs_p': '1190',
#   'o_rcs_e': '854',
#   'o_dep_1_place': '485',
#   'path_indexes': {'o': ['815-700', '700-700'],
#    'i1': '815-700',
#    'i2': '700-700'}},
#  {'nr': '59',
#   'o_legid': '6078',
#   'o_rcs_p': '2863',
#   'o_rcs_e': '1096',
#   'o_dep_1_place': '233',
#   'path_indexes': {'o': ['815-609', '286-609', '308-609'],
#    'i1': '815-609',
#    'i2': '286-609',
#    'i3': '308-609'}},
#  {'nr': '60',
#   'o_legid': '4688',
#   'o_rcs_p': '1145',
#   'o_rcs_e': '84',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['609-609', '411-609', '391-609'],
#    'i1': '609-609',
#    'i2': '411-609',
#    'i3': '391-609'}},
#  {'nr': '61',
#   'o_legid': '5981',
#   'o_rcs_p': '94',
#   'o_rcs_e': '86',
#   'o_dep_1_place': '727',
#   'path_indexes': {'o': ['411-101', '476-101', '411-101'],
#    'i1': '411-101',
#    'i2': '476-101',
#    'i3': '411-101'}},
#  {'nr': '62',
#   'o_legid': '6342',
#   'o_rcs_p': '2444',
#   'o_rcs_e': '1567',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['281-628', '538-628'],
#    'i1': '281-628',
#    'i2': '538-628'}},
#  {'nr': '63',
#   'o_legid': '12949',
#   'o_rcs_p': '1539',
#   'o_rcs_e': '1639',
#   'o_dep_1_place': '481',
#   'path_indexes': {'o': ['671-413', '671-413'],
#    'i1': '671-413',
#    'i2': '671-413'}},
#  {'nr': '64',
#   'o_legid': '11106',
#   'o_rcs_p': '1344',
#   'o_rcs_e': '304',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['614-609', '431-609', '233-609'],
#    'i1': '614-609',
#    'i2': '431-609',
#    'i3': '233-609'}},
#  {'nr': '65',
#   'o_legid': '7582',
#   'o_rcs_p': '1064',
#   'o_rcs_e': '148',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['614-678'], 'i1': '614-678'}},
#  {'nr': '66',
#   'o_legid': '8185',
#   'o_rcs_p': '950',
#   'o_rcs_e': '338',
#   'o_dep_1_place': '349',
#   'path_indexes': {'o': ['700-403'], 'i1': '700-403'}},
#  {'nr': '67',
#   'o_legid': '13634',
#   'o_rcs_p': '817',
#   'o_rcs_e': '10',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['101-809', '579-809', '815-809'],
#    'i1': '101-809',
#    'i2': '579-809',
#    'i3': '815-809'}},
#  {'nr': '68',
#   'o_legid': '1178',
#   'o_rcs_p': '1481',
#   'o_rcs_e': '600',
#   'o_dep_1_place': '456',
#   'path_indexes': {'o': ['128-411'], 'i1': '128-411'}},
#  {'nr': '69',
#   'o_legid': '6097',
#   'o_rcs_p': '700',
#   'o_rcs_e': '476',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['485-431'], 'i1': '485-431'}},
#  {'nr': '70',
#   'o_legid': '5340',
#   'o_rcs_p': '93',
#   'o_rcs_e': '25',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['281-238', '485-238'],
#    'i1': '281-238',
#    'i2': '485-238'}},
#  {'nr': '71',
#   'o_legid': '7633',
#   'o_rcs_p': '1592',
#   'o_rcs_e': '1279',
#   'o_dep_1_place': '413',
#   'path_indexes': {'o': ['700-635', '236-635'],
#    'i1': '700-635',
#    'i2': '236-635'}},
#  {'nr': '72',
#   'o_legid': '4840',
#   'o_rcs_p': '515',
#   'o_rcs_e': '445',
#   'o_dep_1_place': '809',
#   'path_indexes': {'o': ['128-371', '571-371'],
#    'i1': '128-371',
#    'i2': '571-371'}},
#  {'nr': '73',
#   'o_legid': '4836',
#   'o_rcs_p': '295',
#   'o_rcs_e': '105',
#   'o_dep_1_place': '179',
#   'path_indexes': {'o': ['609-597', '628-597'],
#    'i1': '609-597',
#    'i2': '628-597'}},
#  {'nr': '74',
#   'o_legid': '2676',
#   'o_rcs_p': '1176',
#   'o_rcs_e': '311',
#   'o_dep_1_place': '456',
#   'path_indexes': {'o': ['128-128'], 'i1': '128-128'}},
#  {'nr': '75',
#   'o_legid': '11054',
#   'o_rcs_p': '100',
#   'o_rcs_e': '71',
#   'o_dep_1_place': '134',
#   'path_indexes': {'o': ['409-610'], 'i1': '409-610'}},
#  {'nr': '76',
#   'o_legid': '8706',
#   'o_rcs_p': '257',
#   'o_rcs_e': '156',
#   'o_dep_1_place': '609',
#   'path_indexes': {'o': ['815-485', '815-485', '366-485'],
#    'i1': '815-485',
#    'i2': '815-485',
#    'i3': '366-485'}},
#  {'nr': '77',
#   'o_legid': '10542',
#   'o_rcs_p': '46',
#   'o_rcs_e': '33',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['233-485'], 'i1': '233-485'}},
#  {'nr': '78',
#   'o_legid': '3550',
#   'o_rcs_p': '5041',
#   'o_rcs_e': '4266',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['441-426'], 'i1': '441-426'}},
#  {'nr': '79',
#   'o_legid': '7750',
#   'o_rcs_p': '13176',
#   'o_rcs_e': '12116',
#   'o_dep_1_place': '233',
#   'path_indexes': {'o': ['753-257', '789-257', '753-257'],
#    'i1': '753-257',
#    'i2': '789-257',
#    'i3': '753-257'}},
#  {'nr': '80',
#   'o_legid': '9193',
#   'o_rcs_p': '1962',
#   'o_rcs_e': '1677',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['809-128'], 'i1': '809-128'}},
#  {'nr': '81',
#   'o_legid': '7036',
#   'o_rcs_p': '280',
#   'o_rcs_e': '265',
#   'o_dep_1_place': '371',
#   'path_indexes': {'o': ['281-265', '555-265'],
#    'i1': '281-265',
#    'i2': '555-265'}},
#  {'nr': '82',
#   'o_legid': '23',
#   'o_rcs_p': '47',
#   'o_rcs_e': '7',
#   'o_dep_1_place': '431',
#   'path_indexes': {'o': ['721-815', '371-815'],
#    'i1': '721-815',
#    'i2': '371-815'}},
#  {'nr': '83',
#   'o_legid': '3558',
#   'o_rcs_p': '278',
#   'o_rcs_e': '45',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['700-770', '206-770', '476-770'],
#    'i1': '700-770',
#    'i2': '206-770',
#    'i3': '476-770'}},
#  {'nr': '84',
#   'o_legid': '2049',
#   'o_rcs_p': '4162',
#   'o_rcs_e': '3045',
#   'o_dep_1_place': '597',
#   'path_indexes': {'o': ['349-635'], 'i1': '349-635'}},
#  {'nr': '85',
#   'o_legid': '1145',
#   'o_rcs_p': '1491',
#   'o_rcs_e': '585',
#   'o_dep_1_place': '456',
#   'path_indexes': {'o': ['721-411', '778-411', '349-411'],
#    'i1': '721-411',
#    'i2': '778-411',
#    'i3': '349-411'}},
#  {'nr': '86',
#   'o_legid': '5637',
#   'o_rcs_p': '1995',
#   'o_rcs_e': '1051',
#   'o_dep_1_place': '485',
#   'path_indexes': {'o': ['815-628'], 'i1': '815-628'}},
#  {'nr': '87',
#   'o_legid': '13263',
#   'o_rcs_p': '15137',
#   'o_rcs_e': '14028',
#   'o_dep_1_place': '349',
#   'path_indexes': {'o': ['609-317', '700-317'],
#    'i1': '609-317',
#    'i2': '700-317'}},
#  {'nr': '88',
#   'o_legid': '4936',
#   'o_rcs_p': '404',
#   'o_rcs_e': '156',
#   'o_dep_1_place': '216',
#   'path_indexes': {'o': ['128-243'], 'i1': '128-243'}},
#  {'nr': '89',
#   'o_legid': '10471',
#   'o_rcs_p': '28',
#   'o_rcs_e': '23',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['476-774', '614-774', '349-774'],
#    'i1': '476-774',
#    'i2': '614-774',
#    'i3': '349-774'}},
#  {'nr': '90',
#   'o_legid': '14047',
#   'o_rcs_p': '1364',
#   'o_rcs_e': '1135',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['308-798', '628-798', '548-798'],
#    'i1': '308-798',
#    'i2': '628-798',
#    'i3': '548-798'}},
#  {'nr': '91',
#   'o_legid': '3270',
#   'o_rcs_p': '8852',
#   'o_rcs_e': '8386',
#   'o_dep_1_place': '441',
#   'path_indexes': {'o': ['128-579', '236-579', '236-579'],
#    'i1': '128-579',
#    'i2': '236-579',
#    'i3': '236-579'}},
#  {'nr': '92',
#   'o_legid': '4019',
#   'o_rcs_p': '1121',
#   'o_rcs_e': '55',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['597-609'], 'i1': '597-609'}},
#  {'nr': '93',
#   'o_legid': '10319',
#   'o_rcs_p': '7088',
#   'o_rcs_e': '7168',
#   'o_dep_1_place': '243',
#   'path_indexes': {'o': ['233-403', '349-403', '327-403'],
#    'i1': '233-403',
#    'i2': '349-403',
#    'i3': '327-403'}},
#  {'nr': '94',
#   'o_legid': '12291',
#   'o_rcs_p': '5486',
#   'o_rcs_e': '2184',
#   'o_dep_1_place': '349',
#   'path_indexes': {'o': ['700-136', '431-136', '597-136'],
#    'i1': '700-136',
#    'i2': '431-136',
#    'i3': '597-136'}},
#  {'nr': '95',
#   'o_legid': '1087',
#   'o_rcs_p': '721',
#   'o_rcs_e': '216',
#   'o_dep_1_place': '770',
#   'path_indexes': {'o': ['671-809', '456-809', '609-809'],
#    'i1': '671-809',
#    'i2': '456-809',
#    'i3': '609-809'}},
#  {'nr': '96',
#   'o_legid': '2459',
#   'o_rcs_p': '1041',
#   'o_rcs_e': '207',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['128-538', '815-538'],
#    'i1': '128-538',
#    'i2': '815-538'}},
#  {'nr': '97',
#   'o_legid': '10656',
#   'o_rcs_p': '3195',
#   'o_rcs_e': '633',
#   'o_dep_1_place': '153',
#   'path_indexes': {'o': ['299-113', '299-113', '815-113'],
#    'i1': '299-113',
#    'i2': '299-113',
#    'i3': '815-113'}},
#  {'nr': '98',
#   'o_legid': '10489',
#   'o_rcs_p': '190',
#   'o_rcs_e': '127',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['281-485', '753-485'],
#    'i1': '281-485',
#    'i2': '753-485'}},
#  {'nr': '99',
#   'o_legid': '13854',
#   'o_rcs_p': '1591',
#   'o_rcs_e': '357',
#   'o_dep_1_place': '398',
#   'path_indexes': {'o': ['233-495', '698-495', '233-495'],
#    'i1': '233-495',
#    'i2': '698-495',
#    'i3': '233-495'}},
#  {'nr': '100',
#   'o_legid': '7990',
#   'o_rcs_p': '235',
#   'o_rcs_e': '22',
#   'o_dep_1_place': '609',
#   'path_indexes': {'o': ['671-256', '815-256'],
#    'i1': '671-256',
#    'i2': '815-256'}},
#  {'nr': '101',
#   'o_legid': '13707',
#   'o_rcs_p': '1285',
#   'o_rcs_e': '901',
#   'o_dep_1_place': '485',
#   'path_indexes': {'o': ['815-349'], 'i1': '815-349'}},
#  {'nr': '102',
#   'o_legid': '11805',
#   'o_rcs_p': '11189',
#   'o_rcs_e': '10209',
#   'o_dep_1_place': '256',
#   'path_indexes': {'o': ['609-691', '485-691'],
#    'i1': '609-691',
#    'i2': '485-691'}},
#  {'nr': '103',
#   'o_legid': '7260',
#   'o_rcs_p': '1654',
#   'o_rcs_e': '1122',
#   'o_dep_1_place': '349',
#   'path_indexes': {'o': ['128-468', '468-468', '671-468'],
#    'i1': '128-468',
#    'i2': '468-468',
#    'i3': '671-468'}},
#  {'nr': '104',
#   'o_legid': '13182',
#   'o_rcs_p': '2039',
#   'o_rcs_e': '1804',
#   'o_dep_1_place': '671',
#   'path_indexes': {'o': ['815-561'], 'i1': '815-561'}},
#  {'nr': '105',
#   'o_legid': '6701',
#   'o_rcs_p': '308',
#   'o_rcs_e': '138',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['166-332', '101-332', '281-332'],
#    'i1': '166-332',
#    'i2': '101-332',
#    'i3': '281-332'}},
#  {'nr': '106',
#   'o_legid': '6455',
#   'o_rcs_p': '932',
#   'o_rcs_e': '47',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['520-800', '281-800', '485-800'],
#    'i1': '520-800',
#    'i2': '281-800',
#    'i3': '485-800'}},
#  {'nr': '107',
#   'o_legid': '1791',
#   'o_rcs_p': '242',
#   'o_rcs_e': '167',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['411-610', '113-610', '700-610'],
#    'i1': '411-610',
#    'i2': '113-610',
#    'i3': '700-610'}},
#  {'nr': '108',
#   'o_legid': '13469',
#   'o_rcs_p': '1088',
#   'o_rcs_e': '261',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['815-700'], 'i1': '815-700'}},
#  {'nr': '109',
#   'o_legid': '10603',
#   'o_rcs_p': '1300',
#   'o_rcs_e': '637',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['456-257'], 'i1': '456-257'}},
#  {'nr': '110',
#   'o_legid': '8702',
#   'o_rcs_p': '2593',
#   'o_rcs_e': '1416',
#   'o_dep_1_place': '411',
#   'path_indexes': {'o': ['671-128', '456-128'],
#    'i1': '671-128',
#    'i2': '456-128'}},
#  {'nr': '111',
#   'o_legid': '532',
#   'o_rcs_p': '1149',
#   'o_rcs_e': '344',
#   'o_dep_1_place': '391',
#   'path_indexes': {'o': ['166-671'], 'i1': '166-671'}},
#  {'nr': '112',
#   'o_legid': '13436',
#   'o_rcs_p': '904',
#   'o_rcs_e': '444',
#   'o_dep_1_place': '485',
#   'path_indexes': {'o': ['815-128', '815-128'],
#    'i1': '815-128',
#    'i2': '815-128'}},
#  {'nr': '113',
#   'o_legid': '8796',
#   'o_rcs_p': '1123',
#   'o_rcs_e': '155',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['614-257'], 'i1': '614-257'}},
#  {'nr': '114',
#   'o_legid': '11515',
#   'o_rcs_p': '1240',
#   'o_rcs_e': '1164',
#   'o_dep_1_place': '800',
#   'path_indexes': {'o': ['366-571', '366-571', '441-571'],
#    'i1': '366-571',
#    'i2': '366-571',
#    'i3': '441-571'}},
#  {'nr': '115',
#   'o_legid': '1562',
#   'o_rcs_p': '2883',
#   'o_rcs_e': '688',
#   'o_dep_1_place': '576',
#   'path_indexes': {'o': ['609-257', '698-257', '485-257'],
#    'i1': '609-257',
#    'i2': '698-257',
#    'i3': '485-257'}},
#  {'nr': '116',
#   'o_legid': '14157',
#   'o_rcs_p': '3495',
#   'o_rcs_e': '3223',
#   'o_dep_1_place': '548',
#   'path_indexes': {'o': ['695-327', '349-327', '128-327'],
#    'i1': '695-327',
#    'i2': '349-327',
#    'i3': '128-327'}},
#  {'nr': '117',
#   'o_legid': '13273',
#   'o_rcs_p': '877',
#   'o_rcs_e': '192',
#   'o_dep_1_place': '571',
#   'path_indexes': {'o': ['441-687'], 'i1': '441-687'}},
#  {'nr': '118',
#   'o_legid': '5793',
#   'o_rcs_p': '1068',
#   'o_rcs_e': '687',
#   'o_dep_1_place': '527',
#   'path_indexes': {'o': ['815-174', '456-174', '815-174'],
#    'i1': '815-174',
#    'i2': '456-174',
#    'i3': '815-174'}},
#  {'nr': '119',
#   'o_legid': '9595',
#   'o_rcs_p': '1239',
#   'o_rcs_e': '780',
#   'o_dep_1_place': '299',
#   'path_indexes': {'o': ['663-113'], 'i1': '663-113'}},
#  {'nr': '120',
#   'o_legid': '9884',
#   'o_rcs_p': '401',
#   'o_rcs_e': '237',
#   'o_dep_1_place': '187',
#   'path_indexes': {'o': ['671-700'], 'i1': '671-700'}},
#  {'nr': '121',
#   'o_legid': '7069',
#   'o_rcs_p': '4470',
#   'o_rcs_e': '4425',
#   'o_dep_1_place': '371',
#   'path_indexes': {'o': ['815-761', '555-761'],
#    'i1': '815-761',
#    'i2': '555-761'}},
#  {'nr': '122',
#   'o_legid': '10611',
#   'o_rcs_p': '8562',
#   'o_rcs_e': '7978',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['445-395'], 'i1': '445-395'}},
#  {'nr': '123',
#   'o_legid': '1456',
#   'o_rcs_p': '395',
#   'o_rcs_e': '53',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['579-413'], 'i1': '579-413'}},
#  {'nr': '124',
#   'o_legid': '8197',
#   'o_rcs_p': '1720',
#   'o_rcs_e': '264',
#   'o_dep_1_place': '349',
#   'path_indexes': {'o': ['671-476', '750-476', '548-476'],
#    'i1': '671-476',
#    'i2': '750-476',
#    'i3': '548-476'}},
#  {'nr': '125',
#   'o_legid': '10266',
#   'o_rcs_p': '65',
#   'o_rcs_e': '66',
#   'o_dep_1_place': '403',
#   'path_indexes': {'o': ['128-800', '700-800', '815-800'],
#    'i1': '128-800',
#    'i2': '700-800',
#    'i3': '815-800'}},
#  {'nr': '126',
#   'o_legid': '4161',
#   'o_rcs_p': '108',
#   'o_rcs_e': '101',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['609-349'], 'i1': '609-349'}},
#  {'nr': '127',
#   'o_legid': '8848',
#   'o_rcs_p': '2701',
#   'o_rcs_e': '1989',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['815-698'], 'i1': '815-698'}},
#  {'nr': '128',
#   'o_legid': '14512',
#   'o_rcs_p': '1544',
#   'o_rcs_e': '772',
#   'o_dep_1_place': '485',
#   'path_indexes': {'o': ['815-700', '815-700'],
#    'i1': '815-700',
#    'i2': '815-700'}},
#  {'nr': '129',
#   'o_legid': '6109',
#   'o_rcs_p': '671',
#   'o_rcs_e': '367',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['128-628', '174-628'],
#    'i1': '128-628',
#    'i2': '174-628'}},
#  {'nr': '130',
#   'o_legid': '3809',
#   'o_rcs_p': '1318',
#   'o_rcs_e': '391',
#   'o_dep_1_place': '281',
#   'path_indexes': {'o': ['815-113', '700-113'],
#    'i1': '815-113',
#    'i2': '700-113'}},
#  {'nr': '131',
#   'o_legid': '10261',
#   'o_rcs_p': '2865',
#   'o_rcs_e': '2839',
#   'o_dep_1_place': '798',
#   'path_indexes': {'o': ['233-233', '243-233', '371-233'],
#    'i1': '233-233',
#    'i2': '243-233',
#    'i3': '371-233'}},
#  {'nr': '132',
#   'o_legid': '3178',
#   'o_rcs_p': '8788',
#   'o_rcs_e': '5738',
#   'o_dep_1_place': '476',
#   'path_indexes': {'o': ['700-441', '299-441'],
#    'i1': '700-441',
#    'i2': '299-441'}},
#  {'nr': '133',
#   'o_legid': '1199',
#   'o_rcs_p': '203',
#   'o_rcs_e': '193',
#   'o_dep_1_place': '173',
#   'path_indexes': {'o': ['349-456', '597-456', '413-456'],
#    'i1': '349-456',
#    'i2': '597-456',
#    'i3': '413-456'}},
#  {'nr': '134',
#   'o_legid': '3223',
#   'o_rcs_p': '399',
#   'o_rcs_e': '85',
#   'o_dep_1_place': '431',
#   'path_indexes': {'o': ['700-700'], 'i1': '700-700'}},
#  {'nr': '135',
#   'o_legid': '11178',
#   'o_rcs_p': '560',
#   'o_rcs_e': '117',
#   'o_dep_1_place': '349',
#   'path_indexes': {'o': ['441-468'], 'i1': '441-468'}},
#  {'nr': '136',
#   'o_legid': '9439',
#   'o_rcs_p': '194',
#   'o_rcs_e': '188',
#   'o_dep_1_place': '614',
#   'path_indexes': {'o': ['815-815', '128-815'],
#    'i1': '815-815',
#    'i2': '128-815'}},
#  {'nr': '137',
#   'o_legid': '9260',
#   'o_rcs_p': '1465',
#   'o_rcs_e': '486',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['216-561', '456-561', '233-561'],
#    'i1': '216-561',
#    'i2': '456-561',
#    'i3': '233-561'}},
#  {'nr': '138',
#   'o_legid': '2414',
#   'o_rcs_p': '3118',
#   'o_rcs_e': '2711',
#   'o_dep_1_place': '411',
#   'path_indexes': {'o': ['700-700', '166-700', '456-700'],
#    'i1': '700-700',
#    'i2': '166-700',
#    'i3': '456-700'}},
#  {'nr': '139',
#   'o_legid': '10735',
#   'o_rcs_p': '1597',
#   'o_rcs_e': '497',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['456-403', '815-403', '411-403'],
#    'i1': '456-403',
#    'i2': '815-403',
#    'i3': '411-403'}},
#  {'nr': '140',
#   'o_legid': '12065',
#   'o_rcs_p': '1575',
#   'o_rcs_e': '1549',
#   'o_dep_1_place': '597',
#   'path_indexes': {'o': ['609-349', '128-349', '308-349'],
#    'i1': '609-349',
#    'i2': '128-349',
#    'i3': '308-349'}},
#  {'nr': '141',
#   'o_legid': '10358',
#   'o_rcs_p': '3090',
#   'o_rcs_e': '2055',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['431-441', '476-441', '371-441'],
#    'i1': '431-441',
#    'i2': '476-441',
#    'i3': '371-441'}},
#  {'nr': '142',
#   'o_legid': '4568',
#   'o_rcs_p': '2938',
#   'o_rcs_e': '2572',
#   'o_dep_1_place': '548',
#   'path_indexes': {'o': ['700-128', '128-128'],
#    'i1': '700-128',
#    'i2': '128-128'}},
#  {'nr': '143',
#   'o_legid': '13717',
#   'o_rcs_p': '401',
#   'o_rcs_e': '350',
#   'o_dep_1_place': '411',
#   'path_indexes': {'o': ['134-317'], 'i1': '134-317'}},
#  {'nr': '144',
#   'o_legid': '11310',
#   'o_rcs_p': '4857',
#   'o_rcs_e': '4234',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['256-538', '727-538'],
#    'i1': '256-538',
#    'i2': '727-538'}},
#  {'nr': '145',
#   'o_legid': '9558',
#   'o_rcs_p': '1017',
#   'o_rcs_e': '582',
#   'o_dep_1_place': '349',
#   'path_indexes': {'o': ['187-671', '456-671'],
#    'i1': '187-671',
#    'i2': '456-671'}},
#  {'nr': '146',
#   'o_legid': '6727',
#   'o_rcs_p': '249',
#   'o_rcs_e': '177',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['815-610', '152-610'],
#    'i1': '815-610',
#    'i2': '152-610'}},
#  {'nr': '147',
#   'o_legid': '2772',
#   'o_rcs_p': '1520',
#   'o_rcs_e': '1001',
#   'o_dep_1_place': '349',
#   'path_indexes': {'o': ['216-144', '700-144'],
#    'i1': '216-144',
#    'i2': '700-144'}},
#  {'nr': '148',
#   'o_legid': '12939',
#   'o_rcs_p': '740',
#   'o_rcs_e': '246',
#   'o_dep_1_place': '308',
#   'path_indexes': {'o': ['671-597'], 'i1': '671-597'}},
#  {'nr': '149',
#   'o_legid': '14375',
#   'o_rcs_p': '1388',
#   'o_rcs_e': '1024',
#   'o_dep_1_place': '485',
#   'path_indexes': {'o': ['815-700'], 'i1': '815-700'}},
#  {'nr': '150',
#   'o_legid': '3381',
#   'o_rcs_p': '1312',
#   'o_rcs_e': '157',
#   'o_dep_1_place': '144',
#   'path_indexes': {'o': ['388-490'], 'i1': '388-490'}},
#  {'nr': '151',
#   'o_legid': '3647',
#   'o_rcs_p': '231',
#   'o_rcs_e': '212',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['431-485', '614-485', '597-485'],
#    'i1': '431-485',
#    'i2': '614-485',
#    'i3': '597-485'}},
#  {'nr': '152',
#   'o_legid': '2803',
#   'o_rcs_p': '322',
#   'o_rcs_e': '294',
#   'o_dep_1_place': '166',
#   'path_indexes': {'o': ['101-476'], 'i1': '101-476'}},
#  {'nr': '153',
#   'o_legid': '4271',
#   'o_rcs_p': '1406',
#   'o_rcs_e': '331',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['515-609'], 'i1': '515-609'}},
#  {'nr': '154',
#   'o_legid': '11110',
#   'o_rcs_p': '248',
#   'o_rcs_e': '124',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['614-485'], 'i1': '614-485'}},
#  {'nr': '155',
#   'o_legid': '4266',
#   'o_rcs_p': '92',
#   'o_rcs_e': '64',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['476-485'], 'i1': '476-485'}},
#  {'nr': '156',
#   'o_legid': '3505',
#   'o_rcs_p': '198',
#   'o_rcs_e': '180',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['476-485'], 'i1': '476-485'}},
#  {'nr': '157',
#   'o_legid': '6296',
#   'o_rcs_p': '3241',
#   'o_rcs_e': '3052',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['413-206', '815-206'],
#    'i1': '413-206',
#    'i2': '815-206'}},
#  {'nr': '158',
#   'o_legid': '638',
#   'o_rcs_p': '165',
#   'o_rcs_e': '147',
#   'o_dep_1_place': '308',
#   'path_indexes': {'o': ['233-485', '571-485', '727-485'],
#    'i1': '233-485',
#    'i2': '571-485',
#    'i3': '727-485'}},
#  {'nr': '159',
#   'o_legid': '4593',
#   'o_rcs_p': '1195',
#   'o_rcs_e': '44',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['476-609'], 'i1': '476-609'}},
#  {'nr': '160',
#   'o_legid': '14532',
#   'o_rcs_p': '1184',
#   'o_rcs_e': '732',
#   'o_dep_1_place': '485',
#   'path_indexes': {'o': ['750-700', '815-700'],
#    'i1': '750-700',
#    'i2': '815-700'}},
#  {'nr': '161',
#   'o_legid': '12601',
#   'o_rcs_p': '2358',
#   'o_rcs_e': '2102',
#   'o_dep_1_place': '349',
#   'path_indexes': {'o': ['671-609', '671-609', '548-609'],
#    'i1': '671-609',
#    'i2': '671-609',
#    'i3': '548-609'}},
#  {'nr': '162',
#   'o_legid': '8004',
#   'o_rcs_p': '145',
#   'o_rcs_e': '43',
#   'o_dep_1_place': '281',
#   'path_indexes': {'o': ['485-134', '809-134'],
#    'i1': '485-134',
#    'i2': '809-134'}},
#  {'nr': '163',
#   'o_legid': '569',
#   'o_rcs_p': '321',
#   'o_rcs_e': '3',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['101-413', '299-413', '753-413'],
#    'i1': '101-413',
#    'i2': '299-413',
#    'i3': '753-413'}},
#  {'nr': '164',
#   'o_legid': '12728',
#   'o_rcs_p': '2052',
#   'o_rcs_e': '230',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['671-349', '485-349', '281-349'],
#    'i1': '671-349',
#    'i2': '485-349',
#    'i3': '281-349'}},
#  {'nr': '165',
#   'o_legid': '10742',
#   'o_rcs_p': '1183',
#   'o_rcs_e': '618',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['128-671', '128-671'],
#    'i1': '128-671',
#    'i2': '128-671'}},
#  {'nr': '166',
#   'o_legid': '11321',
#   'o_rcs_p': '699',
#   'o_rcs_e': '628',
#   'o_dep_1_place': '485',
#   'path_indexes': {'o': ['456-238', '815-238', '815-238'],
#    'i1': '456-238',
#    'i2': '815-238',
#    'i3': '815-238'}},
#  {'nr': '167',
#   'o_legid': '3784',
#   'o_rcs_p': '1121',
#   'o_rcs_e': '102',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['262-609'], 'i1': '262-609'}},
#  {'nr': '168',
#   'o_legid': '14040',
#   'o_rcs_p': '410',
#   'o_rcs_e': '214',
#   'o_dep_1_place': '609',
#   'path_indexes': {'o': ['134-211'], 'i1': '134-211'}},
#  {'nr': '169',
#   'o_legid': '13190',
#   'o_rcs_p': '718',
#   'o_rcs_e': '292',
#   'o_dep_1_place': '485',
#   'path_indexes': {'o': ['377-649', '377-649'],
#    'i1': '377-649',
#    'i2': '377-649'}},
#  {'nr': '170',
#   'o_legid': '11502',
#   'o_rcs_p': '1459',
#   'o_rcs_e': '1236',
#   'o_dep_1_place': '800',
#   'path_indexes': {'o': ['128-610', '128-610'],
#    'i1': '128-610',
#    'i2': '128-610'}},
#  {'nr': '171',
#   'o_legid': '560',
#   'o_rcs_p': '951',
#   'o_rcs_e': '124',
#   'o_dep_1_place': '391',
#   'path_indexes': {'o': ['413-287', '326-287'],
#    'i1': '413-287',
#    'i2': '326-287'}},
#  {'nr': '172',
#   'o_legid': '13350',
#   'o_rcs_p': '1712',
#   'o_rcs_e': '1697',
#   'o_dep_1_place': '441',
#   'path_indexes': {'o': ['153-388'], 'i1': '153-388'}},
#  {'nr': '173',
#   'o_legid': '558',
#   'o_rcs_p': '807',
#   'o_rcs_e': '296',
#   'o_dep_1_place': '770',
#   'path_indexes': {'o': ['671-628', '609-628', '456-628'],
#    'i1': '671-628',
#    'i2': '609-628',
#    'i3': '456-628'}},
#  {'nr': '174',
#   'o_legid': '5222',
#   'o_rcs_p': '1466',
#   'o_rcs_e': '1392',
#   'o_dep_1_place': '770',
#   'path_indexes': {'o': ['456-423', '671-423'],
#    'i1': '456-423',
#    'i2': '671-423'}},
#  {'nr': '175',
#   'o_legid': '8826',
#   'o_rcs_p': '1518',
#   'o_rcs_e': '667',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['815-403', '609-403', '610-403'],
#    'i1': '815-403',
#    'i2': '609-403',
#    'i3': '610-403'}},
#  {'nr': '176',
#   'o_legid': '9338',
#   'o_rcs_p': '512',
#   'o_rcs_e': '60',
#   'o_dep_1_place': '610',
#   'path_indexes': {'o': ['476-349', '485-349'],
#    'i1': '476-349',
#    'i2': '485-349'}},
#  {'nr': '177',
#   'o_legid': '1372',
#   'o_rcs_p': '35112',
#   'o_rcs_e': '34137',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['476-698', '233-698', '614-698'],
#    'i1': '476-698',
#    'i2': '233-698',
#    'i3': '614-698'}},
#  {'nr': '178',
#   'o_legid': '10072',
#   'o_rcs_p': '1110',
#   'o_rcs_e': '69',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['216-609'], 'i1': '216-609'}},
#  {'nr': '179',
#   'o_legid': '1323',
#   'o_rcs_p': '1119',
#   'o_rcs_e': '513',
#   'o_dep_1_place': '524',
#   'path_indexes': {'o': ['281-361', '815-361', '597-361'],
#    'i1': '281-361',
#    'i2': '815-361',
#    'i3': '597-361'}},
#  {'nr': '180',
#   'o_legid': '10123',
#   'o_rcs_p': '5272',
#   'o_rcs_e': '3230',
#   'o_dep_1_place': '628',
#   'path_indexes': {'o': ['700-128'], 'i1': '700-128'}},
#  {'nr': '181',
#   'o_legid': '12175',
#   'o_rcs_p': '742',
#   'o_rcs_e': '546',
#   'o_dep_1_place': '809',
#   'path_indexes': {'o': ['403-349', '490-349', '770-349'],
#    'i1': '403-349',
#    'i2': '490-349',
#    'i3': '770-349'}},
#  {'nr': '182',
#   'o_legid': '5867',
#   'o_rcs_p': '105',
#   'o_rcs_e': '140',
#   'o_dep_1_place': '548',
#   'path_indexes': {'o': ['286-308'], 'i1': '286-308'}},
#  {'nr': '183',
#   'o_legid': '2147',
#   'o_rcs_p': '1328',
#   'o_rcs_e': '736',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['476-561', '485-561', '128-561'],
#    'i1': '476-561',
#    'i2': '485-561',
#    'i3': '128-561'}},
#  {'nr': '184',
#   'o_legid': '7095',
#   'o_rcs_p': '1512',
#   'o_rcs_e': '1',
#   'o_dep_1_place': '144',
#   'path_indexes': {'o': ['349-721'], 'i1': '349-721'}},
#  {'nr': '185',
#   'o_legid': '544',
#   'o_rcs_p': '1475',
#   'o_rcs_e': '1284',
#   'o_dep_1_place': '555',
#   'path_indexes': {'o': ['690-356', '815-356', '371-356'],
#    'i1': '690-356',
#    'i2': '815-356',
#    'i3': '371-356'}},
#  {'nr': '186',
#   'o_legid': '10700',
#   'o_rcs_p': '8573',
#   'o_rcs_e': '1883',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['411-441', '700-441'],
#    'i1': '411-441',
#    'i2': '700-441'}},
#  {'nr': '187',
#   'o_legid': '6912',
#   'o_rcs_p': '175',
#   'o_rcs_e': '263',
#   'o_dep_1_place': '610',
#   'path_indexes': {'o': ['485-485', '476-485', '281-485'],
#    'i1': '485-485',
#    'i2': '476-485',
#    'i3': '281-485'}},
#  {'nr': '188',
#   'o_legid': '12062',
#   'o_rcs_p': '7478',
#   'o_rcs_e': '6989',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['413-144', '411-144', '238-144'],
#    'i1': '413-144',
#    'i2': '411-144',
#    'i3': '238-144'}},
#  {'nr': '189',
#   'o_legid': '11778',
#   'o_rcs_p': '2038',
#   'o_rcs_e': '1769',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['815-299', '815-299', '431-299'],
#    'i1': '815-299',
#    'i2': '815-299',
#    'i3': '431-299'}},
#  {'nr': '190',
#   'o_legid': '4438',
#   'o_rcs_p': '4739',
#   'o_rcs_e': '4583',
#   'o_dep_1_place': '671',
#   'path_indexes': {'o': ['610-174', '349-174'],
#    'i1': '610-174',
#    'i2': '349-174'}},
#  {'nr': '191',
#   'o_legid': '14585',
#   'o_rcs_p': '1635',
#   'o_rcs_e': '1600',
#   'o_dep_1_place': '371',
#   'path_indexes': {'o': ['815-411', '555-411'],
#    'i1': '815-411',
#    'i2': '555-411'}},
#  {'nr': '192',
#   'o_legid': '10111',
#   'o_rcs_p': '608',
#   'o_rcs_e': '363',
#   'o_dep_1_place': '236',
#   'path_indexes': {'o': ['798-485'], 'i1': '798-485'}},
#  {'nr': '193',
#   'o_legid': '1079',
#   'o_rcs_p': '4700',
#   'o_rcs_e': '4535',
#   'o_dep_1_place': '371',
#   'path_indexes': {'o': ['555-721', '663-721', '555-721'],
#    'i1': '555-721',
#    'i2': '663-721',
#    'i3': '555-721'}},
#  {'nr': '194',
#   'o_legid': '5862',
#   'o_rcs_p': '2129',
#   'o_rcs_e': '1857',
#   'o_dep_1_place': '256',
#   'path_indexes': {'o': ['485-423', '431-423', '101-423'],
#    'i1': '485-423',
#    'i2': '431-423',
#    'i3': '101-423'}},
#  {'nr': '195',
#   'o_legid': '12913',
#   'o_rcs_p': '5447',
#   'o_rcs_e': '5290',
#   'o_dep_1_place': '671',
#   'path_indexes': {'o': ['476-426', '476-426', '700-426'],
#    'i1': '476-426',
#    'i2': '476-426',
#    'i3': '700-426'}},
#  {'nr': '196',
#   'o_legid': '4855',
#   'o_rcs_p': '3661',
#   'o_rcs_e': '3376',
#   'o_dep_1_place': '187',
#   'path_indexes': {'o': ['349-293'], 'i1': '349-293'}},
#  {'nr': '197',
#   'o_legid': '4096',
#   'o_rcs_p': '831',
#   'o_rcs_e': '163',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['614-610'], 'i1': '614-610'}},
#  {'nr': '198',
#   'o_legid': '1437',
#   'o_rcs_p': '779',
#   'o_rcs_e': '181',
#   'o_dep_1_place': '571',
#   'path_indexes': {'o': ['441-361'], 'i1': '441-361'}},
#  {'nr': '199',
#   'o_legid': '8265',
#   'o_rcs_p': '347',
#   'o_rcs_e': '122',
#   'o_dep_1_place': '431',
#   'path_indexes': {'o': ['700-113', '690-113'],
#    'i1': '700-113',
#    'i2': '690-113'}},
#  {'nr': '200',
#   'o_legid': '460',
#   'o_rcs_p': '913',
#   'o_rcs_e': '79',
#   'o_dep_1_place': '789',
#   'path_indexes': {'o': ['238-128', '571-128'],
#    'i1': '238-128',
#    'i2': '571-128'}},
#  {'nr': '201',
#   'o_legid': '6968',
#   'o_rcs_p': '1196',
#   'o_rcs_e': '1318',
#   'o_dep_1_place': '576',
#   'path_indexes': {'o': ['476-144', '778-144', '456-144'],
#    'i1': '476-144',
#    'i2': '778-144',
#    'i3': '456-144'}},
#  {'nr': '202',
#   'o_legid': '6290',
#   'o_rcs_p': '496',
#   'o_rcs_e': '316',
#   'o_dep_1_place': '431',
#   'path_indexes': {'o': ['700-149'], 'i1': '700-149'}},
#  {'nr': '203',
#   'o_legid': '2281',
#   'o_rcs_p': '1902',
#   'o_rcs_e': '183',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['485-597', '349-597', '485-597'],
#    'i1': '485-597',
#    'i2': '349-597',
#    'i3': '485-597'}},
#  {'nr': '204',
#   'o_legid': '11706',
#   'o_rcs_p': '1732',
#   'o_rcs_e': '1552',
#   'o_dep_1_place': '809',
#   'path_indexes': {'o': ['770-327'], 'i1': '770-327'}},
#  {'nr': '205',
#   'o_legid': '1276',
#   'o_rcs_p': '94',
#   'o_rcs_e': '40',
#   'o_dep_1_place': '610',
#   'path_indexes': {'o': ['128-134'], 'i1': '128-134'}},
#  {'nr': '206',
#   'o_legid': '436',
#   'o_rcs_p': '4345',
#   'o_rcs_e': '4300',
#   'o_dep_1_place': '371',
#   'path_indexes': {'o': ['555-809', '815-809'],
#    'i1': '555-809',
#    'i2': '815-809'}},
#  {'nr': '207',
#   'o_legid': '10714',
#   'o_rcs_p': '2644',
#   'o_rcs_e': '1940',
#   'o_dep_1_place': '134',
#   'path_indexes': {'o': ['809-609'], 'i1': '809-609'}},
#  {'nr': '208',
#   'o_legid': '8515',
#   'o_rcs_p': '214',
#   'o_rcs_e': '160',
#   'o_dep_1_place': '377',
#   'path_indexes': {'o': ['485-485', '485-485', '485-485'],
#    'i1': '485-485',
#    'i2': '485-485',
#    'i3': '485-485'}},
#  {'nr': '209',
#   'o_legid': '7924',
#   'o_rcs_p': '5047',
#   'o_rcs_e': '3267',
#   'o_dep_1_place': '281',
#   'path_indexes': {'o': ['413-123'], 'i1': '413-123'}},
#  {'nr': '210',
#   'o_legid': '11764',
#   'o_rcs_p': '34522',
#   'o_rcs_e': '33572',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['403-698', '597-698'],
#    'i1': '403-698',
#    'i2': '597-698'}},
#  {'nr': '211',
#   'o_legid': '508',
#   'o_rcs_p': '1075',
#   'o_rcs_e': '368',
#   'o_dep_1_place': '391',
#   'path_indexes': {'o': ['490-287', '815-287', '257-287'],
#    'i1': '490-287',
#    'i2': '815-287',
#    'i3': '257-287'}},
#  {'nr': '212',
#   'o_legid': '5547',
#   'o_rcs_p': '371',
#   'o_rcs_e': '163',
#   'o_dep_1_place': '609',
#   'path_indexes': {'o': ['815-398', '349-398', '815-398'],
#    'i1': '815-398',
#    'i2': '349-398',
#    'i3': '815-398'}},
#  {'nr': '213',
#   'o_legid': '13868',
#   'o_rcs_p': '214',
#   'o_rcs_e': '177',
#   'o_dep_1_place': '727',
#   'path_indexes': {'o': ['700-101', '411-101'],
#    'i1': '700-101',
#    'i2': '411-101'}},
#  {'nr': '214',
#   'o_legid': '5900',
#   'o_rcs_p': '5547',
#   'o_rcs_e': '4580',
#   'o_dep_1_place': '456',
#   'path_indexes': {'o': ['128-349', '173-349', '349-349'],
#    'i1': '128-349',
#    'i2': '173-349',
#    'i3': '349-349'}},
#  {'nr': '215',
#   'o_legid': '9448',
#   'o_rcs_p': '10287',
#   'o_rcs_e': '9632',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['783-628', '413-628'],
#    'i1': '783-628',
#    'i2': '413-628'}},
#  {'nr': '216',
#   'o_legid': '4078',
#   'o_rcs_p': '670',
#   'o_rcs_e': '75',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['700-524'], 'i1': '700-524'}},
#  {'nr': '217',
#   'o_legid': '7172',
#   'o_rcs_p': '7390',
#   'o_rcs_e': '6062',
#   'o_dep_1_place': '233',
#   'path_indexes': {'o': ['456-698', '149-698'],
#    'i1': '456-698',
#    'i2': '149-698'}},
#  {'nr': '218',
#   'o_legid': '9755',
#   'o_rcs_p': '1366',
#   'o_rcs_e': '325',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['614-671', '431-671'],
#    'i1': '614-671',
#    'i2': '431-671'}},
#  {'nr': '219',
#   'o_legid': '7787',
#   'o_rcs_p': '23277',
#   'o_rcs_e': '21204',
#   'o_dep_1_place': '233',
#   'path_indexes': {'o': ['538-308'], 'i1': '538-308'}},
#  {'nr': '220',
#   'o_legid': '4177',
#   'o_rcs_p': '1948',
#   'o_rcs_e': '269',
#   'o_dep_1_place': '783',
#   'path_indexes': {'o': ['128-256'], 'i1': '128-256'}},
#  {'nr': '221',
#   'o_legid': '7674',
#   'o_rcs_p': '1020',
#   'o_rcs_e': '155',
#   'o_dep_1_place': '256',
#   'path_indexes': {'o': ['431-609', '700-609'],
#    'i1': '431-609',
#    'i2': '700-609'}},
#  {'nr': '222',
#   'o_legid': '10926',
#   'o_rcs_p': '148',
#   'o_rcs_e': '62',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['555-128', '128-128', '538-128'],
#    'i1': '555-128',
#    'i2': '128-128',
#    'i3': '538-128'}},
#  {'nr': '223',
#   'o_legid': '7273',
#   'o_rcs_p': '622',
#   'o_rcs_e': '432',
#   'o_dep_1_place': '134',
#   'path_indexes': {'o': ['391-812'], 'i1': '391-812'}},
#  {'nr': '224',
#   'o_legid': '13028',
#   'o_rcs_p': '2019',
#   'o_rcs_e': '1876',
#   'o_dep_1_place': '671',
#   'path_indexes': {'o': ['527-187', '403-187', '815-187'],
#    'i1': '527-187',
#    'i2': '403-187',
#    'i3': '815-187'}},
#  {'nr': '225',
#   'o_legid': '13913',
#   'o_rcs_p': '36978',
#   'o_rcs_e': '37206',
#   'o_dep_1_place': '233',
#   'path_indexes': {'o': ['371-700', '456-700'],
#    'i1': '371-700',
#    'i2': '456-700'}},
#  {'nr': '226',
#   'o_legid': '2718',
#   'o_rcs_p': '3020',
#   'o_rcs_e': '3020',
#   'o_dep_1_place': '140',
#   'path_indexes': {'o': ['485-700', '493-700', '815-700'],
#    'i1': '485-700',
#    'i2': '493-700',
#    'i3': '815-700'}},
#  {'nr': '227',
#   'o_legid': '12386',
#   'o_rcs_p': '252',
#   'o_rcs_e': '84',
#   'o_dep_1_place': '281',
#   'path_indexes': {'o': ['700-667', '485-667', '815-667'],
#    'i1': '700-667',
#    'i2': '485-667',
#    'i3': '815-667'}},
#  {'nr': '228',
#   'o_legid': '13833',
#   'o_rcs_p': '411',
#   'o_rcs_e': '100',
#   'o_dep_1_place': '398',
#   'path_indexes': {'o': ['628-778'], 'i1': '628-778'}},
#  {'nr': '229',
#   'o_legid': '7301',
#   'o_rcs_p': '3192',
#   'o_rcs_e': '2402',
#   'o_dep_1_place': '527',
#   'path_indexes': {'o': ['815-597', '134-597', '815-597'],
#    'i1': '815-597',
#    'i2': '134-597',
#    'i3': '815-597'}},
#  {'nr': '230',
#   'o_legid': '3815',
#   'o_rcs_p': '4577',
#   'o_rcs_e': '4475',
#   'o_dep_1_place': '671',
#   'path_indexes': {'o': ['815-635'], 'i1': '815-635'}},
#  {'nr': '231',
#   'o_legid': '13969',
#   'o_rcs_p': '5898',
#   'o_rcs_e': '5303',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['815-628', '134-628', '610-628'],
#    'i1': '815-628',
#    'i2': '134-628',
#    'i3': '610-628'}},
#  {'nr': '232',
#   'o_legid': '13194',
#   'o_rcs_p': '2575',
#   'o_rcs_e': '1746',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['128-597', '281-597', '610-597'],
#    'i1': '128-597',
#    'i2': '281-597',
#    'i3': '610-597'}},
#  {'nr': '233',
#   'o_legid': '12133',
#   'o_rcs_p': '2304',
#   'o_rcs_e': '2293',
#   'o_dep_1_place': '671',
#   'path_indexes': {'o': ['815-349'], 'i1': '815-349'}},
#  {'nr': '234',
#   'o_legid': '2648',
#   'o_rcs_p': '135',
#   'o_rcs_e': '159',
#   'o_dep_1_place': '391',
#   'path_indexes': {'o': ['815-134'], 'i1': '815-134'}},
#  {'nr': '235',
#   'o_legid': '8687',
#   'o_rcs_p': '855',
#   'o_rcs_e': '157',
#   'o_dep_1_place': '308',
#   'path_indexes': {'o': ['597-597', '233-597'],
#    'i1': '597-597',
#    'i2': '233-597'}},
#  {'nr': '236',
#   'o_legid': '11993',
#   'o_rcs_p': '2802',
#   'o_rcs_e': '829',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['366-257', '411-257'],
#    'i1': '366-257',
#    'i2': '411-257'}},
#  {'nr': '237',
#   'o_legid': '818',
#   'o_rcs_p': '765',
#   'o_rcs_e': '210',
#   'o_dep_1_place': '308',
#   'path_indexes': {'o': ['485-597', '548-597', '671-597'],
#    'i1': '485-597',
#    'i2': '548-597',
#    'i3': '671-597'}},
#  {'nr': '238',
#   'o_legid': '10644',
#   'o_rcs_p': '53',
#   'o_rcs_e': '32',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['609-527', '431-527'],
#    'i1': '609-527',
#    'i2': '431-527'}},
#  {'nr': '239',
#   'o_legid': '170',
#   'o_rcs_p': '438',
#   'o_rcs_e': '34',
#   'o_dep_1_place': '403',
#   'path_indexes': {'o': ['216-710', '527-710', '815-710'],
#    'i1': '216-710',
#    'i2': '527-710',
#    'i3': '815-710'}},
#  {'nr': '240',
#   'o_legid': '9546',
#   'o_rcs_p': '305',
#   'o_rcs_e': '163',
#   'o_dep_1_place': '485',
#   'path_indexes': {'o': ['377-609', '815-609', '609-609'],
#    'i1': '377-609',
#    'i2': '815-609',
#    'i3': '609-609'}},
#  {'nr': '241',
#   'o_legid': '2565',
#   'o_rcs_p': '132',
#   'o_rcs_e': '62',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['431-140', '128-140', '327-140'],
#    'i1': '431-140',
#    'i2': '128-140',
#    'i3': '327-140'}},
#  {'nr': '242',
#   'o_legid': '5392',
#   'o_rcs_p': '3069',
#   'o_rcs_e': '2287',
#   'o_dep_1_place': '527',
#   'path_indexes': {'o': ['597-671'], 'i1': '597-671'}},
#  {'nr': '243',
#   'o_legid': '5210',
#   'o_rcs_p': '1459',
#   'o_rcs_e': '757',
#   'o_dep_1_place': '206',
#   'path_indexes': {'o': ['700-538'], 'i1': '700-538'}},
#  {'nr': '244',
#   'o_legid': '6614',
#   'o_rcs_p': '4466',
#   'o_rcs_e': '4343',
#   'o_dep_1_place': '281',
#   'path_indexes': {'o': ['700-187', '524-187'],
#    'i1': '700-187',
#    'i2': '524-187'}},
#  {'nr': '245',
#   'o_legid': '10444',
#   'o_rcs_p': '715',
#   'o_rcs_e': '100',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['256-774'], 'i1': '256-774'}},
#  {'nr': '246',
#   'o_legid': '6291',
#   'o_rcs_p': '1571',
#   'o_rcs_e': '807',
#   'o_dep_1_place': '485',
#   'path_indexes': {'o': ['815-700', '609-700', '456-700'],
#    'i1': '815-700',
#    'i2': '609-700',
#    'i3': '456-700'}},
#  {'nr': '247',
#   'o_legid': '415',
#   'o_rcs_p': '18996',
#   'o_rcs_e': '17471',
#   'o_dep_1_place': '476',
#   'path_indexes': {'o': ['721-128', '815-128', '815-128'],
#    'i1': '721-128',
#    'i2': '815-128',
#    'i3': '815-128'}},
#  {'nr': '248',
#   'o_legid': '541',
#   'o_rcs_p': '2393',
#   'o_rcs_e': '241',
#   'o_dep_1_place': '391',
#   'path_indexes': {'o': ['815-287', '815-287'],
#    'i1': '815-287',
#    'i2': '815-287'}},
#  {'nr': '249',
#   'o_legid': '3566',
#   'o_rcs_p': '582',
#   'o_rcs_e': '461',
#   'o_dep_1_place': '261',
#   'path_indexes': {'o': ['441-286'], 'i1': '441-286'}},
# ...
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['431-700'], 'i1': '431-700'}},
#  {'nr': '919',
#   'o_legid': '1414',
#   'o_rcs_p': '791',
#   'o_rcs_e': '263',
#   'o_dep_1_place': '571',
#   'path_indexes': {'o': ['789-361', '628-361'],
#    'i1': '789-361',
#    'i2': '628-361'}},
#  {'nr': '920',
#   'o_legid': '14323',
#   'o_rcs_p': '3812',
#   'o_rcs_e': '3077',
#   'o_dep_1_place': '398',
#   'path_indexes': {'o': ['233-561', '770-561'],
#    'i1': '233-561',
#    'i2': '770-561'}},
#  {'nr': '921',
#   'o_legid': '7251',
#   'o_rcs_p': '878',
#   'o_rcs_e': '935',
#   'o_dep_1_place': '233',
#   'path_indexes': {'o': ['515-398', '798-398'],
#    'i1': '515-398',
#    'i2': '798-398'}},
#  {'nr': '922',
#   'o_legid': '2700',
#   'o_rcs_p': '6665',
#   'o_rcs_e': '5823',
#   'o_dep_1_place': '456',
#   'path_indexes': {'o': ['349-770', '349-770', '128-770'],
#    'i1': '349-770',
#    'i2': '349-770',
#    'i3': '128-770'}},
#  {'nr': '923',
#   'o_legid': '86',
#   'o_rcs_p': '1610',
#   'o_rcs_e': '1240',
#   'o_dep_1_place': '671',
#   'path_indexes': {'o': ['299-609', '349-609'],
#    'i1': '299-609',
#    'i2': '349-609'}},
#  {'nr': '924',
#   'o_legid': '12010',
#   'o_rcs_p': '4901',
#   'o_rcs_e': '4528',
#   'o_dep_1_place': '113',
#   'path_indexes': {'o': ['349-700'], 'i1': '349-700'}},
#  {'nr': '925',
#   'o_legid': '13505',
#   'o_rcs_p': '10734',
#   'o_rcs_e': '9821',
#   'o_dep_1_place': '485',
#   'path_indexes': {'o': ['815-108', '815-108', '815-108'],
#    'i1': '815-108',
#    'i2': '815-108',
#    'i3': '815-108'}},
#  {'nr': '926',
#   'o_legid': '10340',
#   'o_rcs_p': '10119',
#   'o_rcs_e': '8697',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['610-187', '610-187', '579-187'],
#    'i1': '610-187',
#    'i2': '610-187',
#    'i3': '579-187'}},
#  {'nr': '927',
#   'o_legid': '10781',
#   'o_rcs_p': '1217',
#   'o_rcs_e': '59',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['485-112', '431-112'],
#    'i1': '485-112',
#    'i2': '431-112'}},
#  {'nr': '928',
#   'o_legid': '9788',
#   'o_rcs_p': '673',
#   'o_rcs_e': '99',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['555-527', '174-527'],
#    'i1': '555-527',
#    'i2': '174-527'}},
#  {'nr': '929',
#   'o_legid': '9682',
#   'o_rcs_p': '1310',
#   'o_rcs_e': '424',
#   'o_dep_1_place': '349',
#   'path_indexes': {'o': ['671-628', '485-628'],
#    'i1': '671-628',
#    'i2': '485-628'}},
#  {'nr': '930',
#   'o_legid': '952',
#   'o_rcs_p': '2332',
#   'o_rcs_e': '1803',
#   'o_dep_1_place': '671',
#   'path_indexes': {'o': ['349-349', '571-349'],
#    'i1': '349-349',
#    'i2': '571-349'}},
#  {'nr': '931',
#   'o_legid': '732',
#   'o_rcs_p': '1560',
#   'o_rcs_e': '1190',
#   'o_dep_1_place': '671',
#   'path_indexes': {'o': ['128-609', '700-609'],
#    'i1': '128-609',
#    'i2': '700-609'}},
#  {'nr': '932',
#   'o_legid': '1815',
#   'o_rcs_p': '2855',
#   'o_rcs_e': '2750',
#   'o_dep_1_place': '690',
#   'path_indexes': {'o': ['308-555'], 'i1': '308-555'}},
#  {'nr': '933',
#   'o_legid': '9648',
#   'o_rcs_p': '3725',
#   'o_rcs_e': '2941',
#   'o_dep_1_place': '456',
#   'path_indexes': {'o': ['128-770', '128-770'],
#    'i1': '128-770',
#    'i2': '128-770'}},
#  {'nr': '934',
#   'o_legid': '7395',
#   'o_rcs_p': '3134',
#   'o_rcs_e': '2988',
#   'o_dep_1_place': '431',
#   'path_indexes': {'o': ['149-256', '256-256'],
#    'i1': '149-256',
#    'i2': '256-256'}},
#  {'nr': '935',
#   'o_legid': '4459',
#   'o_rcs_p': '3480',
#   'o_rcs_e': '3327',
#   'o_dep_1_place': '671',
#   'path_indexes': {'o': ['571-257'], 'i1': '571-257'}},
#  {'nr': '936',
#   'o_legid': '6001',
#   'o_rcs_p': '225',
#   'o_rcs_e': '108',
#   'o_dep_1_place': '228',
#   'path_indexes': {'o': ['609-783', '597-783', '597-783'],
#    'i1': '609-783',
#    'i2': '597-783',
#    'i3': '597-783'}},
#  {'nr': '937',
#   'o_legid': '9277',
#   'o_rcs_p': '2816',
#   'o_rcs_e': '2288',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['815-753', '233-753'],
#    'i1': '815-753',
#    'i2': '233-753'}},
#  {'nr': '938',
#   'o_legid': '10012',
#   'o_rcs_p': '187',
#   'o_rcs_e': '150',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['614-485', '614-485', '597-485'],
#    'i1': '614-485',
#    'i2': '614-485',
#    'i3': '597-485'}},
#  {'nr': '939',
#   'o_legid': '3513',
#   'o_rcs_p': '2202',
#   'o_rcs_e': '1685',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['113-281', '281-281', '431-281'],
#    'i1': '113-281',
#    'i2': '281-281',
#    'i3': '431-281'}},
#  {'nr': '940',
#   'o_legid': '13294',
#   'o_rcs_p': '662',
#   'o_rcs_e': '322',
#   'o_dep_1_place': '441',
#   'path_indexes': {'o': ['128-296', '236-296'],
#    'i1': '128-296',
#    'i2': '236-296'}},
#  {'nr': '941',
#   'o_legid': '13345',
#   'o_rcs_p': '1848',
#   'o_rcs_e': '1633',
#   'o_dep_1_place': '441',
#   'path_indexes': {'o': ['349-327', '341-327', '128-327'],
#    'i1': '349-327',
#    'i2': '341-327',
#    'i3': '128-327'}},
#  {'nr': '942',
#   'o_legid': '301',
#   'o_rcs_p': '5468',
#   'o_rcs_e': '4561',
#   'o_dep_1_place': '456',
#   'path_indexes': {'o': ['349-727', '349-727', '349-727'],
#    'i1': '349-727',
#    'i2': '349-727',
#    'i3': '349-727'}},
#  {'nr': '943',
#   'o_legid': '7161',
#   'o_rcs_p': '1667',
#   'o_rcs_e': '655',
#   'o_dep_1_place': '413',
#   'path_indexes': {'o': ['398-423', '128-423'],
#    'i1': '398-423',
#    'i2': '128-423'}},
#  {'nr': '944',
#   'o_legid': '2004',
#   'o_rcs_p': '1076',
#   'o_rcs_e': '976',
#   'o_dep_1_place': '113',
#   'path_indexes': {'o': ['206-700', '411-700', '485-700'],
#    'i1': '206-700',
#    'i2': '411-700',
#    'i3': '485-700'}},
#  {'nr': '945',
#   'o_legid': '9822',
#   'o_rcs_p': '659',
#   'o_rcs_e': '62',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['281-524', '485-524'],
#    'i1': '281-524',
#    'i2': '485-524'}},
#  {'nr': '946',
#   'o_legid': '4761',
#   'o_rcs_p': '43',
#   'o_rcs_e': '35',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['614-485'], 'i1': '614-485'}},
#  {'nr': '947',
#   'o_legid': '807',
#   'o_rcs_p': '2279',
#   'o_rcs_e': '2061',
#   'o_dep_1_place': '671',
#   'path_indexes': {'o': ['184-308'], 'i1': '184-308'}},
#  {'nr': '948',
#   'o_legid': '1136',
#   'o_rcs_p': '747',
#   'o_rcs_e': '175',
#   'o_dep_1_place': '770',
#   'path_indexes': {'o': ['441-144', '700-144'],
#    'i1': '441-144',
#    'i2': '700-144'}},
#  {'nr': '949',
#   'o_legid': '9248',
#   'o_rcs_p': '2181',
#   'o_rcs_e': '1483',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['128-485'], 'i1': '128-485'}},
#  {'nr': '950',
#   'o_legid': '11834',
#   'o_rcs_p': '35758',
#   'o_rcs_e': '33546',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['476-742', '243-742', '476-742'],
#    'i1': '476-742',
#    'i2': '243-742',
#    'i3': '476-742'}},
#  {'nr': '951',
#   'o_legid': '2693',
#   'o_rcs_p': '1094',
#   'o_rcs_e': '361',
#   'o_dep_1_place': '456',
#   'path_indexes': {'o': ['128-128', '398-128', '349-128'],
#    'i1': '128-128',
#    'i2': '398-128',
#    'i3': '349-128'}},
#  {'nr': '952',
#   'o_legid': '10557',
#   'o_rcs_p': '191',
#   'o_rcs_e': '84',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['815-485'], 'i1': '815-485'}},
#  {'nr': '953',
#   'o_legid': '11574',
#   'o_rcs_p': '162',
#   'o_rcs_e': '127',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['431-610'], 'i1': '431-610'}},
#  {'nr': '954',
#   'o_legid': '9995',
#   'o_rcs_p': '479',
#   'o_rcs_e': '142',
#   'o_dep_1_place': '411',
#   'path_indexes': {'o': ['166-317', '700-317'],
#    'i1': '166-317',
#    'i2': '700-317'}},
#  {'nr': '955',
#   'o_legid': '10634',
#   'o_rcs_p': '1391',
#   'o_rcs_e': '216',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['233-710', '281-710'],
#    'i1': '233-710',
#    'i2': '281-710'}},
#  {'nr': '956',
#   'o_legid': '8306',
#   'o_rcs_p': '244',
#   'o_rcs_e': '48',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['609-413', '609-413'],
#    'i1': '609-413',
#    'i2': '609-413'}},
#  {'nr': '957',
#   'o_legid': '8711',
#   'o_rcs_p': '1335',
#   'o_rcs_e': '360',
#   'o_dep_1_place': '308',
#   'path_indexes': {'o': ['671-256', '671-256'],
#    'i1': '671-256',
#    'i2': '671-256'}},
#  {'nr': '958',
#   'o_legid': '11517',
#   'o_rcs_p': '227',
#   'o_rcs_e': '125',
#   'o_dep_1_place': '800',
#   'path_indexes': {'o': ['361-388', '361-388'],
#    'i1': '361-388',
#    'i2': '361-388'}},
#  {'nr': '959',
#   'o_legid': '2497',
#   'o_rcs_p': '1005',
#   'o_rcs_e': '519',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['727-196'], 'i1': '727-196'}},
#  {'nr': '960',
#   'o_legid': '12401',
#   'o_rcs_p': '740',
#   'o_rcs_e': '296',
#   'o_dep_1_place': '281',
#   'path_indexes': {'o': ['256-257', '257-257', '206-257'],
#    'i1': '256-257',
#    'i2': '257-257',
#    'i3': '206-257'}},
#  {'nr': '961',
#   'o_legid': '12721',
#   'o_rcs_p': '1901',
#   'o_rcs_e': '913',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['308-441'], 'i1': '308-441'}},
#  {'nr': '962',
#   'o_legid': '10225',
#   'o_rcs_p': '1383',
#   'o_rcs_e': '1372',
#   'o_dep_1_place': '798',
#   'path_indexes': {'o': ['349-243'], 'i1': '349-243'}},
#  {'nr': '963',
#   'o_legid': '2420',
#   'o_rcs_p': '3466',
#   'o_rcs_e': '3263',
#   'o_dep_1_place': '476',
#   'path_indexes': {'o': ['299-206'], 'i1': '299-206'}},
#  {'nr': '964',
#   'o_legid': '11119',
#   'o_rcs_p': '30',
#   'o_rcs_e': '33',
#   'o_dep_1_place': '134',
#   'path_indexes': {'o': ['128-610', '128-610'],
#    'i1': '128-610',
#    'i2': '128-610'}},
#  {'nr': '965',
#   'o_legid': '9765',
#   'o_rcs_p': '416',
#   'o_rcs_e': '468',
#   'o_dep_1_place': '216',
#   'path_indexes': {'o': ['166-603', '815-603'],
#    'i1': '166-603',
#    'i2': '815-603'}},
#  {'nr': '966',
#   'o_legid': '2592',
#   'o_rcs_p': '1104',
#   'o_rcs_e': '84',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['134-609'], 'i1': '134-609'}},
#  {'nr': '967',
#   'o_legid': '4091',
#   'o_rcs_p': '232',
#   'o_rcs_e': '55',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['538-485', '476-485'],
#    'i1': '538-485',
#    'i2': '476-485'}},
#  {'nr': '968',
#   'o_legid': '10553',
#   'o_rcs_p': '30',
#   'o_rcs_e': '43',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['485-485', '597-485', '431-485'],
#    'i1': '485-485',
#    'i2': '597-485',
#    'i3': '431-485'}},
#  {'nr': '969',
#   'o_legid': '14184',
#   'o_rcs_p': '1289',
#   'o_rcs_e': '735',
#   'o_dep_1_place': '299',
#   'path_indexes': {'o': ['815-753', '815-753'],
#    'i1': '815-753',
#    'i2': '815-753'}},
#  {'nr': '970',
#   'o_legid': '6030',
#   'o_rcs_p': '2676',
#   'o_rcs_e': '2443',
#   'o_dep_1_place': '413',
#   'path_indexes': {'o': ['815-667', '128-667'],
#    'i1': '815-667',
#    'i2': '128-667'}},
#  {'nr': '971',
#   'o_legid': '12906',
#   'o_rcs_p': '2180',
#   'o_rcs_e': '2087',
#   'o_dep_1_place': '671',
#   'path_indexes': {'o': ['658-698'], 'i1': '658-698'}},
#  {'nr': '972',
#   'o_legid': '4215',
#   'o_rcs_p': '460',
#   'o_rcs_e': '45',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['614-610', '614-610', '597-610'],
#    'i1': '614-610',
#    'i2': '614-610',
#    'i3': '597-610'}},
#  {'nr': '973',
#   'o_legid': '14009',
#   'o_rcs_p': '905',
#   'o_rcs_e': '266',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['411-476', '166-476', '700-476'],
#    'i1': '411-476',
#    'i2': '166-476',
#    'i3': '700-476'}},
#  {'nr': '974',
#   'o_legid': '2973',
#   'o_rcs_p': '1009',
#   'o_rcs_e': '85',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['128-431'], 'i1': '128-431'}},
#  {'nr': '975',
#   'o_legid': '14411',
#   'o_rcs_p': '631',
#   'o_rcs_e': '512',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['281-628', '635-628', '456-628'],
#    'i1': '281-628',
#    'i2': '635-628',
#    'i3': '456-628'}},
#  {'nr': '976',
#   'o_legid': '3891',
#   'o_rcs_p': '216',
#   'o_rcs_e': '318',
#   'o_dep_1_place': '770',
#   'path_indexes': {'o': ['815-256', '815-256'],
#    'i1': '815-256',
#    'i2': '815-256'}},
#  {'nr': '977',
#   'o_legid': '8373',
#   'o_rcs_p': '4294',
#   'o_rcs_e': '2766',
#   'o_dep_1_place': '236',
#   'path_indexes': {'o': ['609-403'], 'i1': '609-403'}},
#  {'nr': '978',
#   'o_legid': '11956',
#   'o_rcs_p': '1389',
#   'o_rcs_e': '1292',
#   'o_dep_1_place': '349',
#   'path_indexes': {'o': ['398-597', '485-597', '671-597'],
#    'i1': '398-597',
#    'i2': '485-597',
#    'i3': '671-597'}},
#  {'nr': '979',
#   'o_legid': '8042',
#   'o_rcs_p': '3054',
#   'o_rcs_e': '2919',
#   'o_dep_1_place': '609',
#   'path_indexes': {'o': ['671-485'], 'i1': '671-485'}},
#  {'nr': '980',
#   'o_legid': '6367',
#   'o_rcs_p': '832',
#   'o_rcs_e': '379',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['815-485'], 'i1': '815-485'}},
#  {'nr': '981',
#   'o_legid': '4405',
#   'o_rcs_p': '4721',
#   'o_rcs_e': '4564',
#   'o_dep_1_place': '671',
#   'path_indexes': {'o': ['815-206', '398-206'],
#    'i1': '815-206',
#    'i2': '398-206'}},
#  {'nr': '982',
#   'o_legid': '13836',
#   'o_rcs_p': '36283',
#   'o_rcs_e': '35315',
#   'o_dep_1_place': '233',
#   'path_indexes': {'o': ['815-113'], 'i1': '815-113'}},
#  {'nr': '983',
#   'o_legid': '6484',
#   'o_rcs_p': '1970',
#   'o_rcs_e': '794',
#   'o_dep_1_place': '233',
#   'path_indexes': {'o': ['371-635', '789-635'],
#    'i1': '371-635',
#    'i2': '789-635'}},
#  {'nr': '984',
#   'o_legid': '12744',
#   'o_rcs_p': '1184',
#   'o_rcs_e': '781',
#   'o_dep_1_place': '349',
#   'path_indexes': {'o': ['671-144'], 'i1': '671-144'}},
#  {'nr': '985',
#   'o_legid': '6539',
#   'o_rcs_p': '1869',
#   'o_rcs_e': '1299',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['256-128', '456-128', '815-128'],
#    'i1': '256-128',
#    'i2': '456-128',
#    'i3': '815-128'}},
#  {'nr': '986',
#   'o_legid': '830',
#   'o_rcs_p': '2304',
#   'o_rcs_e': '2150',
#   'o_dep_1_place': '671',
#   'path_indexes': {'o': ['700-206', '700-206', '700-206'],
#    'i1': '700-206',
#    'i2': '700-206',
#    'i3': '700-206'}},
#  {'nr': '987',
#   'o_legid': '3461',
#   'o_rcs_p': '185',
#   'o_rcs_e': '185',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['614-527', '431-527', '476-527'],
#    'i1': '614-527',
#    'i2': '431-527',
#    'i3': '476-527'}},
#  {'nr': '988',
#   'o_legid': '13603',
#   'o_rcs_p': '373',
#   'o_rcs_e': '264',
#   'o_dep_1_place': '153',
#   'path_indexes': {'o': ['299-597', '815-597'],
#    'i1': '299-597',
#    'i2': '815-597'}},
#  {'nr': '989',
#   'o_legid': '214',
#   'o_rcs_p': '468',
#   'o_rcs_e': '252',
#   'o_dep_1_place': '476',
#   'path_indexes': {'o': ['815-576', '128-576', '815-576'],
#    'i1': '815-576',
#    'i2': '128-576',
#    'i3': '815-576'}},
#  {'nr': '990',
#   'o_legid': '12354',
#   'o_rcs_p': '250',
#   'o_rcs_e': '142',
#   'o_dep_1_place': '281',
#   'path_indexes': {'o': ['700-166', '614-166', '391-166'],
#    'i1': '700-166',
#    'i2': '614-166',
#    'i3': '391-166'}},
#  {'nr': '991',
#   'o_legid': '5686',
#   'o_rcs_p': '3978',
#   'o_rcs_e': '3168',
#   'o_dep_1_place': '174',
#   'path_indexes': {'o': ['809-426'], 'i1': '809-426'}},
#  {'nr': '992',
#   'o_legid': '7446',
#   'o_rcs_p': '1635',
#   'o_rcs_e': '1613',
#   'o_dep_1_place': '609',
#   'path_indexes': {'o': ['734-527', '349-527', '206-527'],
#    'i1': '734-527',
#    'i2': '349-527',
#    'i3': '206-527'}},
#  {'nr': '993',
#   'o_legid': '10876',
#   'o_rcs_p': '2160',
#   'o_rcs_e': '1486',
#   'o_dep_1_place': '815',
#   'path_indexes': {'o': ['233-571'], 'i1': '233-571'}},
#  {'nr': '994',
#   'o_legid': '9033',
#   'o_rcs_p': '1200',
#   'o_rcs_e': '475',
#   'o_dep_1_place': '128',
#   'path_indexes': {'o': ['609-152'], 'i1': '609-152'}},
#  {'nr': '995',
#   'o_legid': '5465',
#   'o_rcs_p': '939',
#   'o_rcs_e': '325',
#   'o_dep_1_place': '238',
#   'path_indexes': {'o': ['349-727', '128-727', '128-727'],
#    'i1': '349-727',
#    'i2': '128-727',
#    'i3': '128-727'}},
#  {'nr': '996',
#   'o_legid': '7110',
#   'o_rcs_p': '118',
#   'o_rcs_e': '57',
#   'o_dep_1_place': '783',
#   'path_indexes': {'o': ['349-128', '349-128'],
#    'i1': '349-128',
#    'i2': '349-128'}},
#  {'nr': '997',
#   'o_legid': '13131',
#   'o_rcs_p': '1117',
#   'o_rcs_e': '399',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['815-174', '431-174', '456-174'],
#    'i1': '815-174',
#    'i2': '431-174',
#    'i3': '456-174'}},
#  {'nr': '998',
#   'o_legid': '3568',
#   'o_rcs_p': '1354',
#   'o_rcs_e': '1032',
#   'o_dep_1_place': '700',
#   'path_indexes': {'o': ['281-561', '456-561', '485-561'],
#    'i1': '281-561',
#    'i2': '456-561',
#    'i3': '485-561'}},
#  {'nr': '999',
#   'o_legid': '7947',
#   'o_rcs_p': '655',
#   'o_rcs_e': '142',
#   'o_dep_1_place': '281',
#   'path_indexes': {'o': ['700-700', '490-700'],
#    'i1': '700-700',
#    'i2': '490-700'}},
#  {'nr': '1000',
#   'o_legid': '13918',
#   'o_rcs_p': '2684',
#   'o_rcs_e': '2410',
#   'o_dep_1_place': '206',
#   'path_indexes': {'o': ['815-700', '671-700', '700-700'],
#    'i1': '815-700',
#    'i2': '671-700',
#    'i3': '700-700'}},
#  ...]

# %%
# (n:TransferPoint)-[r:RECEPTION]-(m:DepartureWarehouse) RCS outbound

sub_dict = df.loc[(df[f'o_legid'] != '?') & (df[f'o_legid'].notna()),
                  ['nr', 'o_legid', 'o_rcs_p', 'o_rcs_e', 'o_dep_1_place', 'path_indexes']].to_dict('records')
gds.run_cypher('''
    UNWIND $relMaps AS relMap
    WITH toInteger(relMap.nr) AS shipmentId,
        toInteger(relMap.o_dep_1_place) AS airportId,
        toInteger(relMap.o_legid) AS legId,
        toInteger(relMap.o_rcs_e) AS effectiveMinutes,
        toInteger(relMap.o_rcs_p) AS plannedMinutes,
        relMap.path_indexes.o AS pathIndex
    MATCH(n1:TransferPoint {airportId: airportId})
    MATCH(n2:DepartureWarehouse {airportId: airportId})
    MERGE(n1)-[r:RECEPTION {shipmentId: shipmentId, legId: legId, legNumber: -1}]->(n2)
    ON CREATE SET r.plannedMinutes=plannedMinutes,
        r.effectiveMinutes=effectiveMinutes,
        r.pathIndex = pathIndex
    RETURN count(r)
''', params={'relMaps':sub_dict})
# Out:
#    count(r)
# 0      3942

# %%
# (:DepartureWarehouse)-[r:DEPARTURE]-(:DeparturePoint) DEP1 inbound
for l in LEGS:
    print(f'== LEG {l} ======================')
    for s in SEGMENTS:
        print(f'-- SEGMENT {s} ----------------------')
        source_label = 'DepartureWarehouse'
        if s > 1:
            source_label = 'ArrivalWarehouse'
        sub_dict = df.loc[(df[f'i{l}_dep_{s}_place'] != '?') & (df[f'i{l}_legid'].notna()),
            ['nr', f'i{l}_legid', f'i{l}_dep_{s}_p', f'i{l}_dep_{s}_e', f'i{l}_dep_{s}_place', 'path_indexes']]\
            .to_dict('records')
        res = gds.run_cypher(f'''
            UNWIND $relMaps AS relMap
            WITH toInteger(relMap.nr) AS shipmentId,
                toInteger(relMap.i{l}_dep_{s}_place) AS airportId,
                toInteger(relMap.i{l}_legid) AS legId,
                toInteger(relMap.i{l}_dep_{s}_e) AS effectiveMinutes,
                toInteger(relMap.i{l}_dep_{s}_p) AS plannedMinutes,
                relMap.path_indexes.i{l} AS pathIndex
            MATCH(n1:{source_label} {{airportId: airportId}})
            MATCH(n2:DeparturePoint {{airportId: airportId}})
            MERGE(n1)-[r:DEPARTURE {{shipmentId: shipmentId, legId: legId, legNumber: $legNumber, segmentNumber: $segmentNumber}}]->(n2)
            ON CREATE SET r.plannedMinutes=plannedMinutes,
                r.effectiveMinutes=effectiveMinutes,
                r.pathIndex = pathIndex
            RETURN count(r)
        ''', params={'relMaps':sub_dict, 'legNumber':l, 'segmentNumber':s})
        print(res)
# Out:
# == LEG 1 ======================
# -- SEGMENT 1 ----------------------
#    count(r)
# 0      3942
# -- SEGMENT 2 ----------------------
#    count(r)
# 0      1195
# -- SEGMENT 3 ----------------------
#    count(r)
# 0        23
# == LEG 2 ======================
# -- SEGMENT 1 ----------------------
#    count(r)
# 0      2624
# -- SEGMENT 2 ----------------------
#    count(r)
# 0       791
# -- SEGMENT 3 ----------------------
#    count(r)
# 0        14
# == LEG 3 ======================
# -- SEGMENT 1 ----------------------
#    count(r)
# 0      1366
# -- SEGMENT 2 ----------------------
#    count(r)
# 0       391
# -- SEGMENT 3 ----------------------
#    count(r)
# 0         8

# %%
# (:DepartureWarehouse)-[r:DEPARTURE]-(:DeparturePoint) DEP1 outbound
for s in SEGMENTS:
    source_label = 'DepartureWarehouse'
    if s > 1:
        source_label = 'ArrivalWarehouse'
    print(f'-- SEGMENT {s} ----------------------')
    sub_dict = df.loc[(df[f'o_dep_{s}_place'] != '?') & (df[f'o_legid'].notna()),
                      ['nr', f'o_legid', f'o_dep_{s}_p', f'o_dep_{s}_e', f'o_dep_{s}_place', 'path_indexes']]\
        .to_dict('records')
    res = gds.run_cypher(f'''
        UNWIND $relMaps AS relMap
        WITH toInteger(relMap.nr) AS shipmentId,
            toInteger(relMap.o_dep_{s}_place) AS airportId,
            toInteger(relMap.o_legid) AS legId,
            toInteger(relMap.o_dep_{s}_e) AS effectiveMinutes,
            toInteger(relMap.o_dep_{s}_p) AS plannedMinutes,
            relMap.path_indexes.o AS pathIndex
        MATCH(n1:{source_label} {{airportId: airportId}})
        MATCH(n2:DeparturePoint {{airportId: airportId}})
        MERGE(n1)-[r:DEPARTURE {{shipmentId: shipmentId, legId: legId, legNumber: $legNumber, segmentNumber: $segmentNumber}}]->(n2)
        ON CREATE SET r.plannedMinutes=plannedMinutes,
            r.effectiveMinutes=effectiveMinutes,
            r.pathIndex = pathIndex
        RETURN count(r)
    ''', params={'relMaps':sub_dict, 'legNumber':-1, 'segmentNumber':s})
    print(res)
# Out:
# -- SEGMENT 1 ----------------------
#    count(r)
# 0      3942
# -- SEGMENT 2 ----------------------
#    count(r)
# 0      1845
# -- SEGMENT 3 ----------------------
#    count(r)
# 0        26

# %%
# (:DeparturePoint)-[r:TRANSPORT]-(:ArrivalWarehouse) inbound
for l in LEGS:
    print(f'== LEG {l} ======================')
    for s in SEGMENTS:
        print(f'-- SEGMENT {s} ----------------------')
        sub_dict = df.loc[(df[f'i{l}_rcf_{s}_place'] != '?') & (df[f'i{l}_legid'].notna()),
                          ['nr', f'i{l}_legid', f'i{l}_rcf_{s}_p', f'i{l}_rcf_{s}_e', f'i{l}_dep_{s}_place', f'i{l}_rcf_{s}_place', 'path_indexes']]\
            .to_dict('records')
        res = gds.run_cypher(f'''
            UNWIND $relMaps AS relMap
            WITH toInteger(relMap.nr) AS shipmentId,
                toInteger(relMap.i{l}_dep_{s}_place) AS fromAirportId,
                toInteger(relMap.i{l}_rcf_{s}_place) AS toAirportId,
                toInteger(relMap.i{l}_legid) AS legId,
                toInteger(relMap.i{l}_rcf_{s}_e) AS effectiveMinutes,
                toInteger(relMap.i{l}_rcf_{s}_p) AS plannedMinutes,
                relMap.path_indexes.i{l} AS pathIndex
            MATCH(n1:DeparturePoint {{airportId: fromAirportId}})
            MATCH(n2:ArrivalWarehouse {{airportId: toAirportId}})
            MERGE(n1)-[r:TRANSPORT {{shipmentId: shipmentId, legId: legId, legNumber: $legNumber, segmentNumber: $segmentNumber}}]->(n2)
            ON CREATE SET r.plannedMinutes=plannedMinutes,
                r.effectiveMinutes=effectiveMinutes,
                r.pathIndex = pathIndex
            RETURN count(r)
        ''', params={'relMaps':sub_dict, 'legNumber':l, 'segmentNumber':s})
        print(res)
# Out:
# == LEG 1 ======================
# -- SEGMENT 1 ----------------------
#    count(r)
# 0      3942
# -- SEGMENT 2 ----------------------
#    count(r)
# 0      1195
# -- SEGMENT 3 ----------------------
#    count(r)
# 0        23
# == LEG 2 ======================
# -- SEGMENT 1 ----------------------
#    count(r)
# 0      2624
# -- SEGMENT 2 ----------------------
#    count(r)
# 0       791
# -- SEGMENT 3 ----------------------
#    count(r)
# 0        14
# == LEG 3 ======================
# -- SEGMENT 1 ----------------------
#    count(r)
# 0      1366
# -- SEGMENT 2 ----------------------
#    count(r)
# 0       391
# -- SEGMENT 3 ----------------------
#    count(r)
# 0         8

# %%
# (:DeparturePoint)-[r:TRANSPORT]-(:ArrivalWarehouse) RCF outbound
for s in SEGMENTS:
    print(f'-- SEGMENT {s} ----------------------')
    sub_dict = df.loc[(df[f'o_rcf_{s}_place'] != '?') & (df[f'o_legid'].notna()),
                      ['nr', f'o_legid', f'o_rcf_{s}_p', f'o_rcf_{s}_e',  f'o_dep_{s}_place', f'o_rcf_{s}_place', 'path_indexes']]\
        .to_dict('records')
    res = gds.run_cypher(f'''
        UNWIND $relMaps AS relMap
        WITH toInteger(relMap.nr) AS shipmentId,
            toInteger(relMap.o_dep_{s}_place) AS fromAirportId,
            toInteger(relMap.o_rcf_{s}_place) AS toAirportId,
            toInteger(relMap.o_legid) AS legId,
            toInteger(relMap.o_rcf_{s}_e) AS effectiveMinutes,
            toInteger(relMap.o_rcf_{s}_p) AS plannedMinutes,
            relMap.path_indexes.o AS pathIndex
        MATCH(n1:DeparturePoint {{airportId: fromAirportId}})
        MATCH(n2:ArrivalWarehouse {{airportId: toAirportId}})
        MERGE(n1)-[r:TRANSPORT {{shipmentId: shipmentId, legId: legId, legNumber: $legNumber, segmentNumber: $segmentNumber}}]->(n2)
        ON CREATE SET r.plannedMinutes=plannedMinutes,
            r.effectiveMinutes=effectiveMinutes,
            r.pathIndex = pathIndex
        RETURN count(r)
    ''', params={'relMaps':sub_dict, 'legNumber':-1, 'segmentNumber':s})
    print(res)
# Out:
# -- SEGMENT 1 ----------------------
#    count(r)
# 0      3942
# -- SEGMENT 2 ----------------------
#    count(r)
# 0      1845
# -- SEGMENT 3 ----------------------
#    count(r)
# 0        26

# %%
# (:ArrivalWarehouse)-[r:DELIVERY]-(:TransferPoint) DLV inbound
for l in LEGS:
    sub_dict = df.loc[(df[f'i{l}_legid'] != '?') & (df[f'i{l}_legid'].notna()),
                      ['nr', f'i{l}_legid', f'i{l}_dlv_p', f'i{l}_dlv_e', 'last_i_rcf_place', 'path_indexes']].to_dict('records')
    res = gds.run_cypher(f'''
        UNWIND $relMaps AS relMap
        WITH toInteger(relMap.nr) AS shipmentId,
            toInteger(relMap.last_i_rcf_place) AS airportId,
            toInteger(relMap.i{l}_legid) AS legId,
            toInteger(relMap.i{l}_dlv_e) AS effectiveMinutes,
            toInteger(relMap.i{l}_dlv_p) AS plannedMinutes,
            relMap.path_indexes.i{l} AS pathIndex
        MATCH(n1:ArrivalWarehouse {{airportId: airportId}})
        MATCH(n2:TransferPoint {{airportId: airportId}})
        MERGE(n1)-[r:DELIVERY {{shipmentId: shipmentId, legId: legId, legNumber: $legNumber}}]->(n2)
        ON CREATE SET r.plannedMinutes=plannedMinutes,
            r.effectiveMinutes=effectiveMinutes,
            r.pathIndex = pathIndex
        RETURN count(r)
    ''', params={'relMaps':sub_dict, 'legNumber':l})
    print(res)
# Out:
#    count(r)
# 0      3942
#    count(r)
# 0      2624
#    count(r)
# 0      1366

# %%
# (:ArrivalWarehouse)-[r:DELIVERY]-(:Destination) DLV outbound
sub_dict = df.loc[(df[f'o_legid'] != '?') & (df[f'o_legid'].notna()),
                  ['nr', 'o_legid', f'o_dlv_p', f'o_dlv_e', 'last_o_rcf_place', 'path_indexes']].to_dict('records')
res = gds.run_cypher('''
    UNWIND $relMaps AS relMap
    WITH toInteger(relMap.nr) AS shipmentId,
        toInteger(relMap.last_o_rcf_place) AS airportId,
        toInteger(relMap.o_legid) AS legId,
        toInteger(relMap.o_dlv_e) AS effectiveMinutes,
        toInteger(relMap.o_dlv_p) AS plannedMinutes,
        relMap.path_indexes.o AS pathIndex
    MATCH(n1:ArrivalWarehouse {airportId: airportId})
    MATCH(n2:Destination {airportId: airportId})
    MERGE(n1)-[r:DELIVERY {shipmentId: shipmentId, legId: legId, legNumber: $legNumber}]->(n2)
    ON CREATE SET r.plannedMinutes=plannedMinutes,
        r.effectiveMinutes=effectiveMinutes,
        r.pathIndex = pathIndex
    RETURN count(r)
''', params={'relMaps':sub_dict, 'legNumber':-1})
print(res)
# Out:
#    count(r)
# 0      3942
